# %%
# %load_ext autoreload
# %autoreload 2

import os 
import sys

project_dir_path = '/home/onoue/ws/lukasiewicz_1'
sys.path.append(project_dir_path)

print(sys.path)


from src.setup_problem_loss import Setup
from src.misc import visualize_result

import numpy as np
import pandas as pd
import cvxpy as cp

from sklearn.metrics import log_loss

from src.misc import *
# Out:
# ['/home/onoue/ws/lukasiewicz_1/notebooks/toy_problem', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/onoue/ws/lukasiewicz_1/myenv/lib/python3.10/site-packages', '/home/onoue/ws/lukasiewicz_1']

# %% [markdown]
# # No constraints

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.009016990661621094 seconds!
#
# Loading rules ...
# Done in 6.580352783203125e-05 seconds!
#
# Identifying predicates ...
# Done in 0.00022029876708984375 seconds!
#
# Constructing objective function ...
# Done in 0.001340627670288086 seconds!
#
# Constructing constraints ...
# Done in 0.02002739906311035 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 03:41:52 PM: Your problem has 23 variables, 0 constraints, and 0 parameters.
# (CVXPY) Nov 26 03:41:52 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 03:41:52 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 03:41:52 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:41:52 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 03:41:52 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 03:41:52 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 03:41:52 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 03:41:52 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 03:41:52 PM: Applying reduction ECOS
# (CVXPY) Nov 26 03:41:52 PM: Finished problem compilation (took 2.432e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:41:52 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -8.739e-01  +2e+02  8e-01  5e-02  1e+00  8e+00    ---    ---    1  1  - |  -  -
#  1  -3.423e-01  -3.425e-01  +2e+00  2e-02  7e-04  3e-02  1e-01  0.9858  1e-03   1  1  1 |  0  0
#  2  -1.428e-02  -1.430e-02  +2e-01  2e-03  5e-05  2e-03  9e-03  0.9285  5e-04   1  1  1 |  0  0
#  3  -6.776e-03  -6.525e-03  +3e-02  4e-04  9e-06  6e-04  2e-03  0.8588  6e-02   1  1  1 |  0  0
#  4  -6.362e-04  -4.591e-04  +1e-02  1e-04  3e-06  3e-04  5e-04  0.8249  2e-01   1  1  2 |  0  0
#  5  -5.867e-04  -5.283e-04  +2e-03  3e-05  7e-07  8e-05  1e-04  0.9088  2e-01   1  1  1 |  0  0
#  6  -1.862e-05  -9.626e-06  +3e-04  5e-06  9e-08  1e-05  2e-05  0.9688  1e-01   1  1  1 |  0  0
#  7  -4.796e-06  -4.114e-06  +2e-05  3e-07  7e-09  9e-07  1e-06  0.9612  4e-02   1  1  1 |  0  0
#  8  -3.717e-07  -2.747e-07  +3e-06  5e-08  1e-09  1e-07  2e-07  0.9057  5e-02   1  1  1 |  0  0
#  9  -2.084e-07  -1.804e-07  +1e-06  1e-08  3e-10  4e-08  5e-08  0.8142  1e-01   2  1  1 |  0  0
# 10  -1.561e-08  -7.492e-09  +3e-07  4e-09  8e-11  1e-08  1e-08  0.8681  2e-01   1  1  1 |  0  0
# 11  -1.244e-08  -1.100e-08  +5e-08  7e-10  1e-11  2e-09  3e-09  0.9672  1e-01   2  1  1 |  0  0
# 12  -2.669e-10  -1.816e-10  +3e-09  4e-11  8e-13  1e-10  2e-10  0.9843  4e-02   2  1  1 |  0  0
#
# OPTIMAL (within feastol=3.9e-11, reltol=1.1e+01, abstol=3.0e-09).
# Runtime: 0.000237 seconds.
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:41:52 PM: Problem status: optimal
# (CVXPY) Nov 26 03:41:52 PM: Optimal value: 0.000e+00
# (CVXPY) Nov 26 03:41:52 PM: Compilation took 2.432e-02 seconds
# (CVXPY) Nov 26 03:41:52 PM: Solver (including time spent in interface) took 1.054e-03 seconds
# /home/onoue/ws/lukasiewicz_1/src/misc.py:169: RuntimeWarning: invalid value encountered in scalar divide
#   w = np.array([-w1/w2, -b/w2 + 0.5/w2]).reshape(-1,1)
# /home/onoue/ws/lukasiewicz_1/src/misc.py:169: RuntimeWarning: divide by zero encountered in scalar divide
#   w = np.array([-w1/w2, -b/w2 + 0.5/w2]).reshape(-1,1)

# %% [markdown]
# # Pointwise + Logical + Consistency

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.012186050415039062 seconds!
#
# Loading rules ...
# Done in 0.000110626220703125 seconds!
#
# Identifying predicates ...
# Done in 0.00033926963806152344 seconds!
#
# Constructing objective function ...
# Done in 0.002813577651977539 seconds!
#
# Constructing constraints ...
# Done in 0.02599954605102539 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 04:55:39 PM: Your problem has 23 variables, 96 constraints, and 0 parameters.
# (CVXPY) Nov 26 04:55:39 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 04:55:39 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 04:55:39 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:55:39 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 04:55:39 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 04:55:39 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 04:55:39 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 04:55:39 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 04:55:39 PM: Applying reduction ECOS
# (CVXPY) Nov 26 04:55:39 PM: Finished problem compilation (took 1.945e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:55:39 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +2.871e+01  -4.881e+01  +6e+02  5e-01  8e-01  1e+00  5e+00    ---    ---    1  1  - |  -  -
#  1  +1.438e+01  -5.647e+00  +3e+02  1e-01  2e-01  9e-01  2e+00  0.6623  1e-01   1  1  1 |  0  0
#  2  +1.554e+01  -3.018e+00  +2e+02  1e-01  2e-01  9e-01  2e+00  0.2606  7e-01   2  2  2 |  0  0
#  3  +1.439e+01  +6.636e+00  +1e+02  5e-02  7e-02  5e-01  9e-01  0.9890  5e-01   2  1  1 |  0  0
#  4  +1.879e+01  +1.699e+01  +3e+01  1e-02  2e-02  1e-01  2e-01  0.8793  1e-01   2  2  2 |  0  0
#  5  +1.970e+01  +1.913e+01  +9e+00  3e-03  5e-03  3e-02  7e-02  0.8808  2e-01   2  2  2 |  0  0
#  6  +2.027e+01  +2.017e+01  +1e+00  5e-04  7e-04  5e-03  1e-02  0.8722  5e-02   2  1  1 |  0  0
#  7  +2.035e+01  +2.034e+01  +1e-01  5e-05  7e-05  4e-04  1e-03  0.9237  3e-02   2  1  1 |  0  0
#  8  +2.036e+01  +2.036e+01  +6e-03  2e-06  3e-06  2e-05  6e-05  0.9748  2e-02   2  1  1 |  0  0
#  9  +2.036e+01  +2.036e+01  +1e-04  4e-08  5e-08  3e-07  9e-07  0.9843  1e-04   2  1  1 |  0  0
# 10  +2.036e+01  +2.036e+01  +8e-06  3e-09  4e-09  2e-08  7e-08  0.9266  5e-03   2  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:55:39 PM: Problem status: optimal
# (CVXPY) Nov 26 04:55:39 PM: Optimal value: 2.036e+01
# 11  +2.036e+01  +2.036e+01  +1e-07  5e-11  7e-11  4e-10  1e-09  0.9890  7e-03   2  1  1 |  0  0
#
# OPTIMAL (within feastol=7.2e-11, reltol=6.8e-09, abstol=1.4e-07).
# Runtime: 0.001030 seconds.
#
# (CVXPY) Nov 26 04:55:39 PM: Compilation took 1.945e-01 seconds
# (CVXPY) Nov 26 04:55:39 PM: Solver (including time spent in interface) took 1.734e-03 seconds

# %% [markdown]
# # Pointwise + Logical

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.009677410125732422 seconds!
#
# Loading rules ...
# Done in 7.05718994140625e-05 seconds!
#
# Identifying predicates ...
# Done in 0.00023627281188964844 seconds!
#
# Constructing objective function ...
# Done in 0.0017249584197998047 seconds!
#
# Constructing constraints ...
# Done in 0.019677400588989258 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 03:38:56 PM: Your problem has 23 variables, 36 constraints, and 0 parameters.
# (CVXPY) Nov 26 03:38:56 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 03:38:56 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 03:38:56 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:38:56 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 03:38:56 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 03:38:56 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 03:38:56 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 03:38:56 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 03:38:56 PM: Applying reduction ECOS
# (CVXPY) Nov 26 03:38:56 PM: Finished problem compilation (took 7.028e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:38:56 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +1.736e+01  +7.010e+01  +7e+02  6e-01  1e+00  1e+00  1e+01    ---    ---    1  1  - |  -  -
#  1  +2.156e+01  +4.215e+01  +4e+02  2e-01  6e-01  2e+00  7e+00  0.5743  2e-01   2  1  1 |  0  0
#  2  +1.483e+01  +2.859e+01  +2e+02  7e-02  3e-01  3e+00  4e+00  0.9622  6e-01   2  1  1 |  0  0
#  3  +1.608e+01  +1.885e+01  +6e+01  1e-02  6e-02  7e-01  1e+00  0.8536  1e-01   2  1  1 |  0  0
#  4  +1.668e+01  +1.772e+01  +3e+01  5e-03  2e-02  2e-01  5e-01  0.7294  2e-01   2  2  2 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:38:56 PM: Problem status: optimal
# (CVXPY) Nov 26 03:38:56 PM: Optimal value: 1.706e+01
#  5  +1.694e+01  +1.723e+01  +7e+00  1e-03  6e-03  6e-02  1e-01  0.7835  9e-02   2  1  2 |  0  0
#  6  +1.701e+01  +1.715e+01  +4e+00  6e-04  3e-03  2e-02  7e-02  0.8608  4e-01   2  1  1 |  0  0
#  7  +1.706e+01  +1.710e+01  +1e+00  2e-04  9e-04  5e-03  2e-02  0.7544  7e-02   2  1  1 |  0  0
#  8  +1.705e+01  +1.707e+01  +4e-01  6e-05  3e-04  1e-03  8e-03  0.9890  4e-01   2  1  1 |  0  0
#  9  +1.706e+01  +1.706e+01  +2e-02  3e-06  1e-05  6e-05  3e-04  0.9623  2e-03   3  1  1 |  0  0
# 10  +1.706e+01  +1.706e+01  +2e-04  3e-08  1e-07  6e-07  3e-06  0.9890  1e-04   2  1  1 |  0  0
# 11  +1.706e+01  +1.706e+01  +3e-06  4e-10  2e-09  9e-09  5e-08  0.9851  1e-04   2  1  1 |  0  0
# 12  +1.706e+01  +1.706e+01  +1e-07  2e-11  8e-11  3e-10  2e-09  0.9646  2e-04   2  1  1 |  0  0
#
# OPTIMAL (within feastol=7.7e-11, reltol=5.8e-09, abstol=9.9e-08).
# Runtime: 0.000399 seconds.
#
# (CVXPY) Nov 26 03:38:56 PM: Compilation took 7.028e-02 seconds
# (CVXPY) Nov 26 03:38:56 PM: Solver (including time spent in interface) took 4.559e-04 seconds

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.007719278335571289 seconds!
#
# Loading rules ...
# Done in 6.103515625e-05 seconds!
#
# Identifying predicates ...
# Done in 0.00023698806762695312 seconds!
#
# Constructing objective function ...
# Done in 0.0014810562133789062 seconds!
#
# Constructing constraints ...
# Done in 0.019380807876586914 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 04:51:47 PM: Your problem has 23 variables, 36 constraints, and 0 parameters.
# (CVXPY) Nov 26 04:51:47 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 04:51:47 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 04:51:47 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:51:47 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 04:51:47 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 04:51:47 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 04:51:47 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 04:51:47 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 04:51:47 PM: Applying reduction ECOS
# (CVXPY) Nov 26 04:51:47 PM: Finished problem compilation (took 7.520e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:51:47 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +1.758e+02  +6.068e+02  +6e+03  6e-01  1e+00  1e+00  1e+02    ---    ---    1  1  - |  -  -
#  1  +1.779e+02  +3.319e+02  +3e+03  2e-01  6e-01  7e+00  5e+01  0.6289  1e-01   2  1  2 |  0  0
#  2  +6.389e+01  +2.194e+02  +2e+03  9e-02  6e-01  2e+01  4e+01  0.6195  6e-01   2  2  2 |  0  0
#  3  +4.468e+01  +1.462e+02  +1e+03  6e-02  4e-01  2e+01  2e+01  0.6184  5e-01   2  2  2 |  0  0
#  4  +4.197e+01  +6.121e+01  +3e+02  9e-03  7e-02  3e+00  5e+00  0.8188  3e-02   2  2  2 |  0  0
#  5  +2.844e+01  +3.475e+01  +1e+02  2e-03  2e-02  7e-01  2e+00  0.8906  4e-01   2  2  2 |  0  0
#  6  +2.647e+01  +2.833e+01  +4e+01  6e-04  6e-03  2e-01  7e-01  0.6886  4e-02   2  2  2 |  0  0
#  7  +2.761e+01  +2.822e+01  +1e+01  2e-04  2e-03  8e-02  2e-01  0.8052  2e-01   2  2  2 |  0  0
#  8  +2.722e+01  +2.738e+01  +4e+00  5e-05  5e-04  2e-02  7e-02  0.9890  3e-01   2  1  1 |  0  0
#  9  +2.720e+01  +2.722e+01  +4e-01  6e-06  6e-05  2e-03  7e-03  0.8996  4e-03   2  1  1 |  0  0
# 10  +2.720e+01  +2.720e+01  +2e-02  3e-07  3e-06  9e-05  3e-04  0.9890  4e-02   2  1  1 |  0  0
# 11  +2.720e+01  +2.720e+01  +3e-04  4e-09  4e-08  1e-06  5e-06  0.9861  1e-04   1  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:51:47 PM: Problem status: optimal
# 12  +2.720e+01  +2.720e+01  +7e-06  1e-10  1e-09  3e-08  1e-07  0.9743  1e-04   2  1  1 |  0  0
# 13  +2.720e+01  +2.720e+01  +2e-07  1e-11  3e-11  9e-10  4e-09  0.9720  4e-04   3  2  1 |  0  0
#
# OPTIMAL (within feastol=2.8e-11, reltol=7.2e-09, abstol=2.0e-07).
# Runtime: 0.000468 seconds.
#
# (CVXPY) Nov 26 04:51:47 PM: Optimal value: 2.720e+01
# (CVXPY) Nov 26 04:51:47 PM: Compilation took 7.520e-02 seconds
# (CVXPY) Nov 26 04:51:47 PM: Solver (including time spent in interface) took 7.074e-04 seconds

# %% [markdown]
# # Logical + Consistency

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.014595508575439453 seconds!
#
# Loading rules ...
# Done in 0.00016045570373535156 seconds!
#
# Identifying predicates ...
# Done in 0.0006365776062011719 seconds!
#
# Constructing objective function ...
# Done in 0.002938508987426758 seconds!
#
# Constructing constraints ...
# Done in 0.025932788848876953 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 04:53:00 PM: Your problem has 23 variables, 84 constraints, and 0 parameters.
# (CVXPY) Nov 26 04:53:00 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 04:53:00 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 04:53:00 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:53:00 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 04:53:00 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 04:53:00 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 04:53:00 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 04:53:00 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 04:53:00 PM: Applying reduction ECOS
# (CVXPY) Nov 26 04:53:00 PM: Finished problem compilation (took 1.765e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:53:00 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  -7.976e-03  -3.988e+01  +4e+02  5e-01  4e-01  1e+00  3e+00    ---    ---    1  1  - |  -  -
#  1  -7.232e+00  -1.062e+01  +5e+01  7e-02  3e-02  1e-01  4e-01  0.8922  2e-02   1  1  1 |  0  0
#  2  -4.025e+00  -6.014e+00  +3e+01  4e-02  2e-02  1e-01  3e-01  0.6443  4e-01   2  2  2 |  0  0
#  3  -6.320e-01  -9.955e-01  +5e+00  8e-03  3e-03  2e-02  5e-02  0.8089  6e-03   1  1  2 |  0  0
#  4  -6.083e-01  -9.634e-01  +5e+00  7e-03  3e-03  2e-02  5e-02  0.1035  8e-01   1  2  2 |  0  0
#  5  -3.395e-01  -5.054e-01  +3e+00  4e-03  1e-03  9e-03  2e-02  0.7903  3e-01   1  2  1 |  0  0
#  6  -2.052e-01  -3.147e-01  +2e+00  2e-03  8e-04  6e-03  2e-02  0.6247  5e-01   1  2  2 |  0  0
#  7  -8.068e-02  -1.233e-01  +7e-01  9e-04  3e-04  2e-03  6e-03  0.6866  1e-01   1  2  2 |  0  0
#  8  -4.251e-02  -6.183e-02  +3e-01  4e-04  1e-04  1e-03  3e-03  0.9653  4e-01   1  1  1 |  0  0
#  9  -1.356e-02  -2.263e-02  +1e-01  2e-04  7e-05  5e-04  1e-03  0.8953  4e-01   1  2  2 |  0  0
# 10  -5.181e-03  -7.657e-03  +4e-02  5e-05  2e-05  1e-04  4e-04  0.9636  2e-01   1  1  1 |  0  0
# 11  -1.540e-03  -2.666e-03  +2e-02  2e-05  8e-06  6e-05  2e-04  0.8485  4e-01   1  2  2 |  0  0
# 12  -4.514e-04  -6.856e-04  +4e-03  5e-06  2e-06  1e-05  4e-05  0.9493  2e-01   1  1  1 |  0  0
# 13  -1.247e-04  -2.075e-04  +1e-03  2e-06  6e-07  4e-06  1e-05  0.8253  2e-01   1  1  1 |  0  0
# 14  -6.079e-05  -1.032e-04  +7e-04  8e-07  3e-07  2e-06  6e-06  0.7237  3e-01   1  1  1 |  0  0
# 15  -2.494e-05  -3.782e-05  +2e-04  3e-07  9e-08  6e-07  2e-06  0.7803  1e-01   1  1  1 |  0  0
# 16  -7.425e-06  -1.299e-05  +9e-05  1e-07  4e-08  3e-07  9e-07  0.8522  3e-01   1  1  1 |  0  0
# 17  -3.039e-06  -5.039e-06  +3e-05  4e-08  1e-08  1e-07  3e-07  0.8188  2e-01   1  1  1 |  0  0
# 18  -1.096e-06  -1.623e-06  +8e-06  1e-08  4e-09  3e-08  8e-08  0.8135  9e-02   2  1  1 |  0  0
# 19  -5.045e-07  -8.360e-07  +5e-06  7e-09  2e-09  2e-08  5e-08  0.6902  5e-01   2  1  1 |  0  0
# 20  -1.110e-07  -1.839e-07  +1e-06  1e-09  5e-10  4e-09  1e-08  0.8611  9e-02   1  1  1 |  0  0
# 21  -6.166e-08  -9.135e-08  +5e-07  6e-10  2e-10  1e-09  5e-09  0.7512  2e-01   1  1  1 |  0  0
# 22  -1.694e-08  -3.071e-08  +2e-07  3e-10  1e-10  7e-10  2e-09  0.8846  4e-01   2  1  1 |  0  0
# 23  -6.903e-09  -1.026e-08  +5e-08  7e-11  2e-11  2e-10  5e-10  0.9887  2e-01   1  1  1 |  0  0
# 24  -1.614e-09  -2.869e-09  +2e-08  2e-11  9e-12  6e-11  2e-10  0.8456  3e-01   2  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:53:00 PM: Problem status: optimal
# 25  -5.402e-10  -8.065e-10  +4e-09  5e-12  2e-12  1e-11  4e-11  0.9363  2e-01   2  1  1 |  0  0
#
# OPTIMAL (within feastol=5.2e-12, reltol=7.9e+00, abstol=4.2e-09).
# Runtime: 0.001582 seconds.
#
# (CVXPY) Nov 26 04:53:00 PM: Optimal value: 2.276e-10
# (CVXPY) Nov 26 04:53:00 PM: Compilation took 1.765e-01 seconds
# (CVXPY) Nov 26 04:53:00 PM: Solver (including time spent in interface) took 2.257e-03 seconds

# %% [markdown]
# # Pointwise + Consistency

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.0068662166595458984 seconds!
#
# Loading rules ...
# Done in 5.984306335449219e-05 seconds!
#
# Identifying predicates ...
# Done in 0.00021266937255859375 seconds!
#
# Constructing objective function ...
# Done in 0.001293182373046875 seconds!
#
# Constructing constraints ...
# Done in 0.016710281372070312 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 04:50:11 PM: Your problem has 23 variables, 72 constraints, and 0 parameters.
# (CVXPY) Nov 26 04:50:11 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 04:50:11 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 04:50:11 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:50:11 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 04:50:11 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 04:50:11 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 04:50:11 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 04:50:12 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 04:50:12 PM: Applying reduction ECOS
# (CVXPY) Nov 26 04:50:12 PM: Finished problem compilation (took 1.035e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:50:12 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +2.869e+01  -4.627e+01  +5e+02  5e-01  3e-01  1e+00  6e+00    ---    ---    1  1  - |  -  -
#  1  +1.220e+01  -4.000e+00  +2e+02  1e-01  5e-02  6e-01  2e+00  0.7216  7e-02   1  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:50:12 PM: Problem status: optimal
# (CVXPY) Nov 26 04:50:12 PM: Optimal value: 1.944e+01
#  2  +1.374e+01  +2.111e+00  +1e+02  8e-02  4e-02  6e-01  1e+00  0.5713  5e-01   2  2  2 |  0  0
#  3  +1.581e+01  +1.247e+01  +4e+01  2e-02  1e-02  2e-01  4e-01  0.8482  2e-01   2  2  1 |  0  0
#  4  +1.872e+01  +1.802e+01  +8e+00  4e-03  2e-03  4e-02  9e-02  0.9051  1e-01   2  2  2 |  0  0
#  5  +1.929e+01  +1.915e+01  +2e+00  8e-04  4e-04  8e-03  2e-02  0.8459  6e-02   2  2  2 |  0  0
#  6  +1.936e+01  +1.930e+01  +8e-01  4e-04  2e-04  4e-03  8e-03  0.7547  3e-01   2  1  1 |  0  0
#  7  +1.943e+01  +1.942e+01  +1e-01  5e-05  3e-05  5e-04  1e-03  0.8709  2e-02   2  1  1 |  0  0
#  8  +1.944e+01  +1.944e+01  +1e-02  5e-06  2e-06  5e-05  1e-04  0.9128  2e-03   2  1  1 |  0  0
#  9  +1.944e+01  +1.944e+01  +1e-03  5e-07  3e-07  5e-06  1e-05  0.9678  7e-02   2  1  1 |  0  0
# 10  +1.944e+01  +1.944e+01  +9e-05  4e-08  2e-08  4e-07  1e-06  0.9113  1e-03   2  1  1 |  0  0
# 11  +1.944e+01  +1.944e+01  +1e-05  5e-09  3e-09  5e-08  1e-07  0.9640  8e-02   2  1  1 |  0  0
# 12  +1.944e+01  +1.944e+01  +9e-07  5e-1(CVXPY) Nov 26 04:50:12 PM: Compilation took 1.035e-01 seconds
# 0  2e-10  4e-09  1e-08  0.9114  1e-03   2  1  1 |  0  0
# 13  +1.944e+01  +1.944e+01  +1e-07  5e-11  3e-11  5e-10  1e-09  0.9625  8e-02   2  1  1 |  0  0
#
# OPTIMAL (within feastol=5.3e-11, reltol=5.6e-09, abstol=1.1e-07).
# Runtime: 0.000471 seconds.
#
# (CVXPY) Nov 26 04:50:12 PM: Solver (including time spent in interface) took 5.453e-04 seconds

# %% [markdown]
# # Pointwise のみ

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.013776063919067383 seconds!
#
# Loading rules ...
# Done in 0.0002944469451904297 seconds!
#
# Identifying predicates ...
# Done in 0.00044727325439453125 seconds!
#
# Constructing objective function ...
# Done in 0.0017223358154296875 seconds!
#
# Constructing constraints ...
# Done in 0.01834726333618164 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 04:50:15 PM: Your problem has 23 variables, 72 constraints, and 0 parameters.
# (CVXPY) Nov 26 04:50:15 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 04:50:15 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 04:50:15 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:50:15 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 04:50:15 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 04:50:15 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 04:50:15 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 04:50:15 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 04:50:15 PM: Applying reduction ECOS
# (CVXPY) Nov 26 04:50:15 PM: Finished problem compilation (took 1.881e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:50:15 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +2.869e+01  -4.627e+01  +5e+02  5e-01  3e-01  1e+00  6e+00    ---    ---    1  1  - |  -  -
#  1  +1.220e+01  -4.000e+00  +2e+02  1e-01  5e-02  6e-01  2e+00  0.7216  7e-02   1  1  1 |  0  0
#  2  +1.374e+01  +2.111e+00  +1e+02  8e-02  4e-02  6e-01  1e+00  0.5713  5e-01   2  2  2 |  0  0
#  3  +1.581e+01  +1.247e+01  +4e+01  2e-02  1e-02  2e-01  4e-01  0.8482  2e-01   2  2  1 |  0  0
#  4  +1.872e+01  +1.802e+01  +8e+00  4e-03  2e-03  4e-02  9e-02  0.9051  1e-01   2  2  2 |  0  0
#  5  +1.929e+01  +1.915e+01  +2e+00  8e-04  4e-04  8e-03  2e-02  0.8459  6e-02   2  2  2 |  0  0
#  6  +1.936e+01  +1.930e+01  +8e-01  4e-04  2e-04  4e-03  8e-03  0.7547  3e-01   2  1  1 |  0  0
#  7  +1.943e+01  +1.942e+01  +1e-01  5e-05  3e-05  5e-04  1e-03  0.8709  2e-02   2  1  1 |  0  0
#  8  +1.944e+01  +1.944e+01  +1e-02  5e-06  2e-06  5e-05  1e-04  0.9128  2e-03   2  1  1 |  0  0
#  9  +1.944e+01  +1.944e+01  +1e-03  5e-07  3e-07  5e-06  1e-05  0.9678  7e-02   2  1  1 |  0  0
# 10  +1.944e+01  +1.944e+01  +9e-05  4e-08  2e-08  4e-07  1e-06  0.9113  1e-03   2  1  1 |  0  0
# 11  +1.944e+01  +1.944e+01  +1e-05  5e-09  3e-09  5e-08  1e-07  0.9640  8e-02   2  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:50:15 PM: Problem status: optimal
# 12  +1.944e+01  +1.944e+01  +9e-07  5e-10  2e-10  4e-09  1e-08  0.9114  1e-03   2  1  1 |  0  0
# 13  +1.944e+01  +1.944e+01  +1e-07  5e-11  3e-11  5e-10  1e-09  0.9625  8e-02   2  1  1 |  0  0
#
# OPTIMAL (within feastol=5.3e-11, reltol=5.6e-09, abstol=1.1e-07).
# Runtime: 0.000527 seconds.
#
# (CVXPY) Nov 26 04:50:15 PM: Optimal value: 1.944e+01
# (CVXPY) Nov 26 04:50:15 PM: Compilation took 1.881e-01 seconds
# (CVXPY) Nov 26 04:50:15 PM: Solver (including time spent in interface) took 7.188e-04 seconds

# %% [markdown]
# # Logical のみ

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.01047515869140625 seconds!
#
# Loading rules ...
# Done in 0.00014901161193847656 seconds!
#
# Identifying predicates ...
# Done in 0.0002498626708984375 seconds!
#
# Constructing objective function ...
# Done in 0.001743316650390625 seconds!
#
# Constructing constraints ...
# Done in 0.018620729446411133 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 04:51:03 PM: Your problem has 23 variables, 24 constraints, and 0 parameters.
# (CVXPY) Nov 26 04:51:03 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 04:51:03 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 04:51:03 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:51:03 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 04:51:03 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 04:51:03 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 04:51:03 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 04:51:03 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 04:51:03 PM: Applying reduction ECOS
# (CVXPY) Nov 26 04:51:03 PM: Finished problem compilation (took 5.605e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:51:03 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -1.194e+00  +2e+02  9e-01  4e-01  1e+00  5e+00    ---    ---    1  1  - |  -  -
#  1  -3.790e-01  -4.264e-01  +2e+01  7e-02  2e-02  9e-02  3e-01  0.9290  6e-03   1  1  1 |  0  0
#  2  -1.090e-01  -1.073e-01  +1e+00  7e-03  1e-03  1e-02  2e-02  0.9746  4e-02   1  2  2 |  0  0
#  3  -3.237e-02  -3.169e-02  +3e-01  2e-03  4e-04  3e-03  6e-03  0.8186  1e-01   1  2  2 |  0  0
#  4  -8.241e-03  -7.771e-03  +1e-01  1e-03  2e-04  2e-03  3e-03  0.8321  4e-01   1  2  2 |  0  0
#  5  -7.891e-03  -7.695e-03  +5e-02  6e-04  6e-05  6e-04  1e-03  0.8195  3e-01   1  1  1 |  0  0
#  6  -6.853e-04  -6.065e-04  +2e-02  2e-04  3e-05  2e-04  5e-04  0.9653  4e-01   1  2  2 |  0  0
#  7  -5.120e-04  -4.981e-04  +4e-03  4e-05  4e-06  4e-05  8e-05  0.9890  2e-01   1  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 04:51:03 PM: Problem status: optimal
# (CVXPY) Nov 26 04:51:03 PM: Optimal value: 3.874e-10
#  8  -4.581e-05  -4.393e-05  +5e-04  6e-06  6e-07  6e-06  1e-05  0.9024  4e-02   1  1  1 |  0  0
#  9  -2.509e-05  -2.443e-05  +2e-04  2e-06  2e-07  2e-06  4e-06  0.8025  2e-01   1  1  1 |  0  0
# 10  -3.705e-06  -3.461e-06  +7e-05  8e-07  8e-08  8e-07  2e-06  0.8182  2e-01   1  1  1 |  0  0
# 11  -4.076e-06  -3.990e-06  +2e-05  3e-07  3e-08  3e-07  5e-07  0.9530  3e-01   2  1  1 |  0  0
# 12  -2.379e-07  -2.214e-07  +5e-06  5e-08  5e-09  5e-08  1e-07  0.9869  2e-01   1  1  1 |  0  0
# 13  -1.326e-07  -1.294e-07  +9e-07  1e-08  1e-09  1e-08  2e-08  0.9144  1e-01   2  1  1 |  0  0
# 14  -1.228e-08  -1.151e-08  +2e-07  2e-09  3e-10  2e-09  5e-09  0.8910  2e-01   2  1  1 |  0  0
# 15  -8.690e-09  -8.490e-09  +6e-08  6e-10  7e-11  6e-10  1e-09  0.8969  2e-01   2  1  1 |  0  0
# 16  -7.382e-10  -6.868e-10  +1e-08  2e-10  2e-11  2e-10  3e-10  0.9175  2e-01   2  1  1 |  0  0
# 17  -5.239e-10  -5.119e-10  +3e-09  4e-11  4e-12  4e-11  8e-11  0.9230  2e-01   2  1  1 |  0  0
#
# OPTIMAL (within feastol=3.8e-11, reltol(CVXPY) Nov 26 04:51:03 PM: Compilation took 5.605e-02 seconds
# =6.3e+00, abstol=3.3e-09).
# Runtime: 0.000452 seconds.
#
# (CVXPY) Nov 26 04:51:03 PM: Solver (including time spent in interface) took 9.058e-04 seconds

# %% [markdown]
# # Consistency のみ

# %%
from src.setup_problem_tmp import Setup

file_names_dict = {
    "supervised": ["L_p1", "L_p2", "L_p3"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = os.path.join(project_dir_path, "inputs/toy_data_loss")

problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)
# objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)

visualize_result(problem_instance)
# Out:
# Loading data ...
# Done in 0.007058143615722656 seconds!
#
# Loading rules ...
# Done in 8.96453857421875e-05 seconds!
#
# Identifying predicates ...
# Done in 0.00024318695068359375 seconds!
#
# Constructing objective function ...
# Done in 0.003202676773071289 seconds!
#
# Constructing constraints ...
# Done in 0.017367124557495117 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Nov 26 03:21:17 PM: Your problem has 23 variables, 60 constraints, and 0 parameters.
# (CVXPY) Nov 26 03:21:17 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Nov 26 03:21:17 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Nov 26 03:21:17 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:21:17 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Nov 26 03:21:17 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Nov 26 03:21:17 PM: Applying reduction Dcp2Cone
# (CVXPY) Nov 26 03:21:17 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Nov 26 03:21:17 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Nov 26 03:21:17 PM: Applying reduction ECOS
# (CVXPY) Nov 26 03:21:17 PM: Finished problem compilation (took 9.899e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:21:17 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -3.087e+01  +3e+02  5e-01  5e-02  1e+00  4e+00    ---    ---    1  1  - |  -  -
#  1  -8.028e+00  -9.843e+00  +2e+01  5e-02  3e-03  5e-02  3e-01  0.9304  7e-03   1  1  1 |  0  0
#  2  -2.738e+00  -3.440e+00  +9e+00  2e-02  1e-03  5e-02  1e-01  0.8090  3e-01   2  2  2 |  0  0
#  3  -9.901e-01  -1.259e+00  +4e+00  7e-03  4e-04  2e-02  4e-02  0.7120  2e-01   1  2  2 |  0  0
#  4  -7.597e-01  -9.747e-01  +3e+00  6e-03  3e-04  2e-02  4e-02  0.3803  5e-01   1  2  2 |  0  0
#  5  -2.403e-01  -3.068e-01  +9e-01  2e-03  1e-04  6e-03  1e-02  0.9485  3e-01   1  2  1 |  0  0
#  6  -1.062e-01  -1.413e-01  +5e-01  1e-03  5e-05  3e-03  6e-03  0.7435  4e-01   1  2  2 |  0  0
#  7  -4.126e-02  -5.312e-02  +2e-01  3e-04  2e-05  1e-03  2e-03  0.9049  3e-01   1  1  1 |  0  0
#  8  -1.119e-02  -1.536e-02  +6e-02  1e-04  6e-06  3e-04  7e-04  0.9654  3e-01   1  2  2 |  0  0
#  9  -4.229e-03  -5.520e-03  +2e-02  3e-05  2e-06  1e-04  2e-04  0.8357  2e-01   1  1  1 |  0  0
# 10  -1.288e-03  -1.758e-03  +7e-03  1e-05  7e-07  4e-05  8e-05  0.9372  3e-01   1  1  2 |  0  0
# 11  -3.231e-04  -4.254e-04  +1e-03  3e-06  1e-07  8e-06  2e-05  0.9690  2e-01   1  1  1 |  0  0
# 12  -9.271e-05  -1.236e-04  +4e-04  8e-07  4e-08  3e-06  5e-06  0.8438  2e-01   1  1  1 |  0  0
# 13  -3.665e-05  -5.083e-05  +2e-04  4e-07  2e-08  1e-06  2e-06  0.7318  3e-01   1  1  1 |  0  0
# 14  -2.001e-05  -2.605e-05  +9e-05  2e-07  9e-09  5e-07  1e-06  0.9345  4e-01   1  1  1 |  0  0
# 15  -4.351e-06  -6.006e-06  +2e-05  4e-08  2e-09  1e-07  3e-07  0.9890  3e-01   1  1  1 |  0  0
# 16  -1.149e-06  -1.522e-06  +5e-06  9e-09  5e-10  3e-08  7e-08  0.8578  1e-01   1  1  1 |  0  0
# 17  -4.612e-07  -6.289e-07  +2e-06  4e-09  2e-10  1e-08  3e-08  0.7380  3e-01   1  1  1 |  0  0
# 18  -2.184e-07  -2.864e-07  +1e-06  2e-09  1e-10  6e-09  1e-08  0.8848  3e-01   2  1  1 |  0  0
# 19  -5.676e-08  -7.862e-08  +3e-07  6e-10  3e-11  2e-09  4e-09  0.9818  3e-01   2  1  1 |  0  0
# 20  -1.494e-08  -1.962e-08  +7e-08  1e-10  7e-12  4e-10  8e-10  0.9608  2e-01   1  1  1 |  0  0
# 21  -3.087e-09  -4.226e-09  +2e-08  3e-11  2e-12  9e-11  2e-10  0.8917  2e-01   2  1  1 |  0  0
# 22  -1.395e-09  -1.872e-09  +7e-09  1e-11  7e-13  4e-11  8e-11  0.9654  4e-01   2  1  1 |  0  0
#
# OPTIMAL (within feastol=1.2e-11, reltol=4.8e+00, abstol=6.7e-09).
# Runtime: 0.000749 seconds.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Nov 26 03:21:17 PM: Problem status: optimal
#
# (CVXPY) Nov 26 03:21:17 PM: Optimal value: 4.786e-10
# (CVXPY) Nov 26 03:21:17 PM: Compilation took 9.899e-02 seconds
# (CVXPY) Nov 26 03:21:17 PM: Solver (including time spent in interface) took 1.137e-03 seconds
