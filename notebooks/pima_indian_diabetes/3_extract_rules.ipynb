# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from src.rulefit import RuleFit, RuleFitClassifier

# %% [markdown]
# # RuleFit

# %% [markdown]
# __train_test_split__ の際に分割されたデータのインデックスがほしい

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = data.drop(["Outcome"], axis=1)
y = data["Outcome"]

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

train_index = X_train.index
test_index = X_test.index

import os
project_dir_path = "/home/onoue/ws/lukasiewicz_1/"
data_dir_path = "inputs/pima_indian_diabetes"
save_dir_path = os.path.join(project_dir_path, data_dir_path)

file_path_1 = os.path.join(save_dir_path, 'train_index.csv')
pd.DataFrame(train_index).to_csv(file_path_1)

file_path_2 = os.path.join(save_dir_path, 'test_index.csv')
pd.DataFrame(test_index).to_csv(file_path_2)



X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

# SVM（線形カーネル）のモデルを作成
svm_linear = SVC(kernel='linear')

# モデルを訓練
svm_linear.fit(X_train, y_train)

# テストデータで予測
y_pred_linear = svm_linear.predict(X_test)

# Accuracyを計算
accuracy_linear = accuracy_score(y_test, y_pred_linear)

# Confusion Matrixを計算
cm_linear = confusion_matrix(y_test, y_pred_linear)

# Classification Reportを出力
report_linear = classification_report(y_test, y_pred_linear)

# 結果を出力
print("SVM (Linear Kernel) Accuracy:", accuracy_linear)
print()
print()
print("SVM (Linear Kernel) Confusion Matrix:\n", cm_linear)
print()
print()
print("SVM (Linear Kernel) Classification Report:\n", report_linear)
# Out:
# SVM (Linear Kernel) Accuracy: 0.7761194029850746
#
#
# SVM (Linear Kernel) Confusion Matrix:
#  [[82  8]
#  [22 22]]
#
#
# SVM (Linear Kernel) Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85        90
#            1       0.73      0.50      0.59        44
#
#     accuracy                           0.78       134
#    macro avg       0.76      0.71      0.72       134
# weighted avg       0.77      0.78      0.76       134

# %%
# SVM（RBFカーネル）のモデルを作成
svm_rbf = SVC(kernel='rbf')

# モデルを訓練
svm_rbf.fit(X_train, y_train)

# テストデータで予測
y_pred_rbf = svm_rbf.predict(X_test)

# Accuracyを計算
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)

# Confusion Matrixを計算
cm_rbf = confusion_matrix(y_test, y_pred_rbf)

# Classification Reportを出力
report_rbf = classification_report(y_test, y_pred_rbf)

# 結果を出力
print("SVM (RBF Kernel) Accuracy:", accuracy_rbf)
print()
print()
print("SVM (RBF Kernel) Confusion Matrix:\n", cm_rbf)
print()
print()
print("SVM (RBF Kernel) Classification Report:\n", report_rbf)
# Out:
# SVM (RBF Kernel) Accuracy: 0.7835820895522388
#
#
# SVM (RBF Kernel) Confusion Matrix:
#  [[79 11]
#  [18 26]]
#
#
# SVM (RBF Kernel) Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84        90
#            1       0.70      0.59      0.64        44
#
#     accuracy                           0.78       134
#    macro avg       0.76      0.73      0.74       134
# weighted avg       0.78      0.78      0.78       134

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(rfmode=rfmode,
                       tree_generator=tree_generator,
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)
print(rf)
# y_pred = rf.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred)
# conf_matrix = confusion_matrix(y_test, y_pred)
# class_report = classification_report(y_test, y_pred)

# # Print the results
# print("離散データ（one-hot encoding）")
# print("---------------------------")
# print()
# print("Accuracy:", accuracy)
# print()
# print()
# print("Confusion Matrix:\n", conf_matrix)
# print()
# print()
# print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=552,
#                                                         random_state=593))
# RuleFitClassifier(random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=552,
#                                                         random_state=593))

# %%
rf.tree_generator
# Out:
# RandomForestClassifier(max_leaf_nodes=5, n_estimators=552, random_state=593)

# %%
feature_names
# Out:
# ['Pregnancies_Low',
#  'Pregnancies_Medium',
#  'Pregnancies_High',
#  'Glucose_Low',
#  'Glucose_Medium',
#  'Glucose_High',
#  'BloodPressure_Low',
#  'BloodPressure_Medium',
#  'BloodPressure_High',
#  'SkinThickness_Low',
#  'SkinThickness_Medium',
#  'SkinThickness_High',
#  'BMI_Low',
#  'BMI_Medium',
#  'BMI_High',
#  'DiabetesPedigreeFunction_Low',
#  'DiabetesPedigreeFunction_Medium',
#  'DiabetesPedigreeFunction_High',
#  'Age_Low',
#  'Age_Medium',
#  'Age_High']

# %%
rules_df = rf.get_rules(exclude_zero_coef=True)

pd.set_option("display.max_colwidth", 999) #ruleが長すぎて表示が省略される場合用
pd.set_option("display.max_rows", 999) 
rules_df
# Out:
#                                                                                                                                                             rule  \
# 63                                                                                                          Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5
# 126                                                                                                 Glucose_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5
# 129                                                                                                                      Pregnancies_High <= 0.5 & Age_Low > 0.5
# 146                                                                                                                          Glucose_High <= 0.5 & BMI_Low > 0.5
# 173                                                                                                     DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low > 0.5
# 174  Glucose_High <= 0.5 & Age_Medium <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_Low <= 0.5
# 185                                                                                              Glucose_High <= 0.5 & Age_Low <= 0.5 & Pregnancies_Medium > 0.5
# 189                                                                                              Age_Medium <= 0.5 & BMI_Low > 0.5 & BloodPressure_Medium <= 0.5
# 259                                                                                    BMI_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 301                                    Glucose_Low <= 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BMI_High <= 0.5 & Age_Medium <= 0.5
# 389                                                                                                       DiabetesPedigreeFunction_Low <= 0.5 & BMI_Medium > 0.5
# 395                                                                                         Glucose_High <= 0.5 & BloodPressure_Medium > 0.5 & Age_Medium <= 0.5
# 426                                                                                       Age_Low <= 0.5 & BloodPressure_Low <= 0.5 & SkinThickness_Medium > 0.5
# 453                                                                                                                Glucose_High <= 0.5 & Pregnancies_High <= 0.5
# 461                                                                                              Glucose_High <= 0.5 & SkinThickness_High <= 0.5 & Age_Low > 0.5
# 466                                                                                            BMI_Low <= 0.5 & Glucose_High > 0.5 & BloodPressure_Medium <= 0.5
# 501                                                                                                       Age_Medium <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 502                                                                                               Age_Low <= 0.5 & Glucose_Low <= 0.5 & BloodPressure_Low <= 0.5
# 517                                                                                                                   BMI_Low <= 0.5 & Pregnancies_Medium <= 0.5
# 519                                                                                          BMI_Medium <= 0.5 & Glucose_Low <= 0.5 & SkinThickness_Medium > 0.5
# 528                                                                                                        Glucose_High <= 0.5 & BMI_High <= 0.5 & BMI_Low > 0.5
# 554                                                                                              Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 566                                                                 BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Glucose_Low <= 0.5 & BMI_Medium <= 0.5
# 570                                                                                                      BMI_Low > 0.5 & Pregnancies_Low > 0.5 & Age_High <= 0.5
# 576                                                                                                    Glucose_High <= 0.5 & BMI_Medium <= 0.5 & BMI_High <= 0.5
# 586                                                                                     Glucose_High <= 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Low <= 0.5
# 588                                                                                                                          BMI_Low <= 0.5 & Glucose_Low <= 0.5
# 599                                                                             BMI_Medium > 0.5 & DiabetesPedigreeFunction_Low > 0.5 & SkinThickness_Low <= 0.5
# 623                                                                                                                     Age_Low > 0.5 & SkinThickness_Low <= 0.5
# 640                    Glucose_Low <= 0.5 & Glucose_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Medium <= 0.5 & SkinThickness_Low > 0.5
# 657                                                                                          BloodPressure_High <= 0.5 & BMI_Medium <= 0.5 & Glucose_High <= 0.5
# 700                                                                                          Glucose_High <= 0.5 & BMI_High <= 0.5 & BloodPressure_Medium <= 0.5
# 709                                                                                                BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 711                                                                                                            BloodPressure_Low > 0.5 & SkinThickness_Low > 0.5
# 824                                                                                              Glucose_High > 0.5 & BMI_Low <= 0.5 & SkinThickness_High <= 0.5
# 832                                                                  BMI_Low <= 0.5 & Pregnancies_High <= 0.5 & SkinThickness_Medium > 0.5 & Glucose_High <= 0.5
# 858                                                                                    Age_Medium <= 0.5 & BloodPressure_Low <= 0.5 & BloodPressure_Medium > 0.5
# 947                                                                                               BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 949                                                                                                  Glucose_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5
#
#      type      coef   support  importance
# 63   rule  0.072451  0.211144    0.029569
# 126  rule -0.184762  0.603499    0.090380
# 129  rule -0.024991  0.645533    0.011955
# 146  rule -0.032622  0.296830    0.014904
# 173  rule -1.053859  0.211765    0.430564
# 174  rule -0.084519  0.127536    0.028193
# 185  rule -0.101664  0.093567    0.029607
# 189  rule -0.058031  0.134328    0.019789
# 259  rule  0.033293  0.242604    0.014271
# 301  rule -0.046830  0.468208    0.023368
# 389  rule  0.271984  0.228070    0.114121
# 395  rule -0.027888  0.404692    0.013688
# 426  rule  0.086044  0.151335    0.030836
# 453  rule -0.279236  0.727536    0.124323
# 461  rule -0.031549  0.540936    0.015722
# 466  rule  0.807529  0.054217    0.182861
# 501  rule -0.079493  0.471976    0.039684
# 502  rule  0.024861  0.233038    0.010511
# 517  rule  0.120147  0.441441    0.059660
# 519  rule  0.371285  0.103245    0.112974
# 528  rule -0.066505  0.286533    0.030070
# 554  rule  0.076427  0.288690    0.034633
# 566  rule  0.028562  0.050746    0.006269
# 570  rule -0.199681  0.205970    0.080753
# 576  rule -0.000139  0.311377    0.000064
# 586  rule -0.165944  0.561960    0.082333
# 588  rule  0.683217  0.557185    0.339367
# 599  rule -0.067005  0.215569    0.027554
# 623  rule -0.040328  0.386905    0.019641
# 640  rule  0.038188  0.087719    0.010803
# 657  rule -0.417229  0.328402    0.195944
# 700  rule -0.730058  0.245562    0.314232
# 709  rule -0.074895  0.527778    0.037390
# 711  rule -0.126450  0.105556    0.038854
# 824  rule  0.047226  0.139942    0.016384
# 832  rule -0.037716  0.228070    0.015825
# 858  rule -0.101913  0.494186    0.050953
# 947  rule  0.011838  0.285303    0.005345
# 949  rule -0.797830  0.524781    0.398425

# %%
# src に入れたい

class ArrangeRules:
    def __init__(self, rules_df, feature_names=None, conclusion_name=None):
        self.rules_df = rules_df
        self.feature_names = feature_names

        if not conclusion_name:
            self.conclusion_name = 'Outcome'
        else:
            self.conclusion_name = conclusion_name

        self.rules_extracted = None
        self.rules_additional = None
        self.KB = None

    def extract_rules_from_df(self):
        rules_list = self.rules_df['rule'].to_list()
        coef_list  = self.rules_df['coef'].to_list()

        rules_list = [rule.split(' ') for rule in rules_list]

        self.rules_extracted = []
        for rule, coef in zip(rules_list, coef_list):

            # '&' を目印にして複数のリストに分割する
            sublists = []
            current_sublist = []
            for item in rule:
                if item != '&':
                    current_sublist.append(item)
                else:
                    sublists.append(current_sublist)
                    current_sublist = []

            # ループ終了後に最後のサブリストを追加
            sublists.append(current_sublist)

            rule_new = []
            cnt = 0
            for sublist in sublists:
                if len(sublist) <= 1:
                    rule_new.append(sublist[0])
                else:
                    if sublist[1] in ['<', '<=']:
                        rule_new.append('¬')
                        rule_new.append(sublist[0])
                    else:
                        rule_new.append(sublist[0])
                
                cnt +=1
                if cnt < len(sublists):
                    rule_new.append('⊗')
                else:
                    rule_new.append('→')

                    # coef == 0 の rule は除外されているため
                    if coef > 0:
                        rule_new.append(self.conclusion_name)
                    elif coef < 0:
                        rule_new.append('¬')
                        rule_new.append(self.conclusion_name)

            self.rules_extracted.append(rule_new)

        return self.rules_extracted

    def generate_rules_from_df(self):
        if self.feature_names:
            tmp_dict = {}
            for item in self.feature_names:
                key, value = item.rsplit('_', 1)
                if key not in tmp_dict:
                    tmp_dict[key] = []

                tmp_dict[key].append(item)
            
            self.rules_additional = list(tmp_dict.values())
            self.rules_additional = [' ⊕ '.join(rule) for rule in self.rules_additional]
            self.rules_additional = [rule.split(' ') for rule in self.rules_additional]

            return self.rules_additional

        else:
            return []


    def construct_KB(self):
        rules_extracted = self.extract_rules_from_df()
        rules_additional = self.generate_rules_from_df()

        self.KB = rules_extracted + rules_additional
        return self.KB
    
    def save_KB_as_txt(self, file_name):
        if self.KB:
            rules = [' '.join(rule) for rule in self.KB]

        with open(file_name, 'w') as file:
            for item in rules:
                file.write("%s\n" % item)

# %%
rule_processor = ArrangeRules(rules_df, 
                              feature_names=feature_names, 
                              conclusion_name="Outcome")
KB = rule_processor.construct_KB()
rule_processor.save_KB_as_txt("./data/rules.txt")

# %%
for rule in KB:
    print(rule)
# Out:
# ['¬', 'Glucose_Low', '⊗', '¬', 'Age_Low', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '→', '¬', 'Outcome']
# ['¬', 'Pregnancies_High', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_High', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Medium', '⊗', '¬', 'SkinThickness_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Low', '⊗', 'Pregnancies_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'BMI_Low', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'DiabetesPedigreeFunction_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_Low', '⊗', 'BMI_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BloodPressure_Medium', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Low', '⊗', '¬', 'BloodPressure_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'SkinThickness_High', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'Glucose_High', '⊗', '¬', 'BloodPressure_Medium', '→', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['¬', 'Age_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'BloodPressure_Low', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_Medium', '→', 'Outcome']
# ['¬', 'BMI_Medium', '⊗', '¬', 'Glucose_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['¬', 'Pregnancies_Medium', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'BMI_Medium', '→', 'Outcome']
# ['BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'Age_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_Medium', '⊗', '¬', 'BMI_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '→', 'Outcome']
# ['BMI_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'SkinThickness_Medium', '⊗', 'SkinThickness_Low', '→', 'Outcome']
# ['¬', 'BloodPressure_High', '⊗', '¬', 'BMI_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['BloodPressure_Low', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', '¬', 'SkinThickness_High', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_High', '⊗', 'SkinThickness_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', '¬', 'BloodPressure_Low', '⊗', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['Pregnancies_Low', '⊕', 'Pregnancies_Medium', '⊕', 'Pregnancies_High']
# ['Glucose_Low', '⊕', 'Glucose_Medium', '⊕', 'Glucose_High']
# ['BloodPressure_Low', '⊕', 'BloodPressure_Medium', '⊕', 'BloodPressure_High']
# ['SkinThickness_Low', '⊕', 'SkinThickness_Medium', '⊕', 'SkinThickness_High']
# ['BMI_Low', '⊕', 'BMI_Medium', '⊕', 'BMI_High']
# ['DiabetesPedigreeFunction_Low', '⊕', 'DiabetesPedigreeFunction_Medium', '⊕', 'DiabetesPedigreeFunction_High']
# ['Age_Low', '⊕', 'Age_Medium', '⊕', 'Age_High']

# %% [markdown]
# # max_iter=50 としたものも採用して比較してみる

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(max_rules=50,
                       rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(max_rules=50, random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=13,
#                                                         random_state=54))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7761194029850746
#
#
# Confusion Matrix:
#  [[73 17]
#  [13 31]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        90
#            1       0.65      0.70      0.67        44
#
#     accuracy                           0.78       134
#    macro avg       0.75      0.76      0.75       134
# weighted avg       0.78      0.78      0.78       134

# %%
rules_df = rf.get_rules(exclude_zero_coef=True)
rules_df
# Out:
#                                                                                              rule  \
# 1                                                                              Pregnancies_Medium
# 2                                                                                Pregnancies_High
# 3                                                                                     Glucose_Low
# 5                                                                                    Glucose_High
# 7                                                                            BloodPressure_Medium
# 8                                                                              BloodPressure_High
# 11                                                                             SkinThickness_High
# 12                                                                                        BMI_Low
# 13                                                                                     BMI_Medium
# 15                                                                   DiabetesPedigreeFunction_Low
# 17                                                                  DiabetesPedigreeFunction_High
# 21                                                                            Glucose_High <= 0.5
# 22                                                                             Glucose_High > 0.5
# 23                                   BMI_High <= 0.5 & Pregnancies_Low <= 0.5 & BMI_Medium <= 0.5
# 26                   BMI_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5 & Glucose_Low <= 0.5
# 29                                 BMI_High > 0.5 & Glucose_Low <= 0.5 & BloodPressure_High > 0.5
# 30                                                             BMI_High > 0.5 & Glucose_Low > 0.5
# 32                              Glucose_High <= 0.5 & Age_Medium <= 0.5 & BloodPressure_Low > 0.5
# 36                                                                  Age_Low > 0.5 & BMI_Low > 0.5
# 40                                                                                  BMI_Low > 0.5
# 42                                  Age_Low <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low > 0.5
# 43                                                       Age_Low <= 0.5 & SkinThickness_Low > 0.5
# 44                      Age_Low > 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & Glucose_High <= 0.5
# 48                                                              Age_Low > 0.5 & Glucose_Low > 0.5
# 50                    BMI_Low <= 0.5 & DiabetesPedigreeFunction_Medium > 0.5 & Glucose_Low <= 0.5
# 52                                                                              Age_Medium <= 0.5
# 57                       BMI_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5
# 58                                                                BMI_High <= 0.5 & BMI_Low > 0.5
# 60  BMI_High > 0.5 & BloodPressure_High <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Low <= 0.5
# 63                                           Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5
# 65                                     Glucose_Low <= 0.5 & Age_Low > 0.5 & Glucose_Medium <= 0.5
# 67                                                                              Glucose_Low > 0.5
#
#       type      coef   support  importance
# 1   linear -0.481035  1.000000    0.207774
# 2   linear  0.136026  1.000000    0.040943
# 3   linear -0.187261  1.000000    0.076873
# 5   linear  0.181535  1.000000    0.071525
# 7   linear  0.124705  1.000000    0.059211
# 8   linear -0.205998  1.000000    0.077339
# 11  linear -0.186036  1.000000    0.053121
# 12  linear -0.091690  1.000000    0.043059
# 13  linear  0.174153  1.000000    0.086727
# 15  linear -0.367591  1.000000    0.176650
# 17  linear  0.281324  1.000000    0.079569
# 21    rule -0.206923  0.804094    0.082127
# 22    rule  1.024102  0.195906    0.406463
# 23    rule  0.636929  0.105422    0.195599
# 26    rule -0.962730  0.340361    0.456171
# 29    rule  0.889653  0.021084    0.127813
# 30    rule -0.595959  0.024096    0.091389
# 32    rule -0.232689  0.129909    0.078231
# 36    rule -0.281861  0.244957    0.121217
# 40    rule -0.582851  0.297059    0.266341
# 42    rule  0.079174  0.023256    0.011933
# 43    rule -0.378200  0.165698    0.140618
# 44    rule -0.101686  0.209302    0.041367
# 48    rule -1.069032  0.166667    0.398405
# 50    rule  0.460576  0.166154    0.171435
# 52    rule -0.030684  0.762463    0.013058
# 57    rule  0.129468  0.272455    0.057642
# 58    rule -0.163340  0.344311    0.077610
# 60    rule -0.996665  0.047904    0.212851
# 63    rule  0.720004  0.211144    0.293848
# 65    rule  0.257249  0.090909    0.073954
# 67    rule -0.986815  0.231672    0.416337

# %%
rule_processor = ArrangeRules(rules_df, 
                              feature_names=feature_names, 
                              conclusion_name="Outcome")
KB = rule_processor.construct_KB()
rule_processor.save_KB_as_txt("./data/rules_max_50.txt")

for rule in KB:
    print(rule)
# Out:
# ['Pregnancies_Medium', '→', '¬', 'Outcome']
# ['Pregnancies_High', '→', 'Outcome']
# ['Glucose_Low', '→', '¬', 'Outcome']
# ['Glucose_High', '→', 'Outcome']
# ['BloodPressure_Medium', '→', 'Outcome']
# ['BloodPressure_High', '→', '¬', 'Outcome']
# ['SkinThickness_High', '→', '¬', 'Outcome']
# ['BMI_Low', '→', '¬', 'Outcome']
# ['BMI_Medium', '→', 'Outcome']
# ['DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['DiabetesPedigreeFunction_High', '→', 'Outcome']
# ['¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['Glucose_High', '→', 'Outcome']
# ['¬', 'BMI_High', '⊗', '¬', 'Pregnancies_Low', '⊗', '¬', 'BMI_Medium', '→', 'Outcome']
# ['¬', 'BMI_High', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '⊗', '¬', 'Glucose_Low', '→', '¬', 'Outcome']
# ['BMI_High', '⊗', '¬', 'Glucose_Low', '⊗', 'BloodPressure_High', '→', 'Outcome']
# ['BMI_High', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Medium', '⊗', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['BMI_Low', '→', '¬', 'Outcome']
# ['¬', 'Age_Low', '⊗', '¬', 'SkinThickness_Low', '⊗', 'Glucose_Low', '→', 'Outcome']
# ['¬', 'Age_Low', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'Glucose_Low', '→', 'Outcome']
# ['¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_High', '⊗', '¬', 'BMI_Low', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '→', 'Outcome']
# ['¬', 'BMI_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['BMI_High', '⊗', '¬', 'BloodPressure_High', '⊗', 'Pregnancies_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Age_Low', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', 'Age_Low', '⊗', '¬', 'Glucose_Medium', '→', 'Outcome']
# ['Glucose_Low', '→', '¬', 'Outcome']
# ['Pregnancies_Low', '⊕', 'Pregnancies_Medium', '⊕', 'Pregnancies_High']
# ['Glucose_Low', '⊕', 'Glucose_Medium', '⊕', 'Glucose_High']
# ['BloodPressure_Low', '⊕', 'BloodPressure_Medium', '⊕', 'BloodPressure_High']
# ['SkinThickness_Low', '⊕', 'SkinThickness_Medium', '⊕', 'SkinThickness_High']
# ['BMI_Low', '⊕', 'BMI_Medium', '⊕', 'BMI_High']
# ['DiabetesPedigreeFunction_Low', '⊕', 'DiabetesPedigreeFunction_Medium', '⊕', 'DiabetesPedigreeFunction_High']
# ['Age_Low', '⊕', 'Age_Medium', '⊕', 'Age_High']
