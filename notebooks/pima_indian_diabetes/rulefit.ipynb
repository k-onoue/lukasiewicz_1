# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from rulefit import RuleFit, RuleFitClassifier

# %% [markdown]
# # RuleFit

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=552,
#                                                         random_state=593))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7388059701492538
#
#
# Confusion Matrix:
#  [[72 18]
#  [17 27]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80        90
#            1       0.60      0.61      0.61        44
#
#     accuracy                           0.74       134
#    macro avg       0.70      0.71      0.71       134
# weighted avg       0.74      0.74      0.74       134

# %%
feature_names
# Out:
# ['Pregnancies_Low',
#  'Pregnancies_Medium',
#  'Pregnancies_High',
#  'Glucose_Low',
#  'Glucose_Medium',
#  'Glucose_High',
#  'BloodPressure_Low',
#  'BloodPressure_Medium',
#  'BloodPressure_High',
#  'SkinThickness_Low',
#  'SkinThickness_Medium',
#  'SkinThickness_High',
#  'BMI_Low',
#  'BMI_Medium',
#  'BMI_High',
#  'DiabetesPedigreeFunction_Low',
#  'DiabetesPedigreeFunction_Medium',
#  'DiabetesPedigreeFunction_High',
#  'Age_Low',
#  'Age_Medium',
#  'Age_High']

# %%
rules = rf.get_rules(exclude_zero_coef=True)

pd.set_option("display.max_colwidth", 999) #ruleが長すぎて表示が省略される場合用
pd.set_option("display.max_rows", 999) 
rules
# Out:
#                                                                                                                                                             rule  \
# 63                                                                                                          Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5
# 126                                                                                                 Glucose_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5
# 129                                                                                                                      Pregnancies_High <= 0.5 & Age_Low > 0.5
# 146                                                                                                                          Glucose_High <= 0.5 & BMI_Low > 0.5
# 172                                                                                                     DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low > 0.5
# 173  Glucose_High <= 0.5 & Age_Medium <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_Low <= 0.5
# 184                                                                                              Glucose_High <= 0.5 & Age_Low <= 0.5 & Pregnancies_Medium > 0.5
# 188                                                                                              Age_Medium <= 0.5 & BMI_Low > 0.5 & BloodPressure_Medium <= 0.5
# 258                                                                                    BMI_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 300                                    Glucose_Low <= 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BMI_High <= 0.5 & Age_Medium <= 0.5
# 388                                                                                                       DiabetesPedigreeFunction_Low <= 0.5 & BMI_Medium > 0.5
# 394                                                                                         Glucose_High <= 0.5 & BloodPressure_Medium > 0.5 & Age_Medium <= 0.5
# 425                                                                                       Age_Low <= 0.5 & BloodPressure_Low <= 0.5 & SkinThickness_Medium > 0.5
# 452                                                                                                                Glucose_High <= 0.5 & Pregnancies_High <= 0.5
# 465                                                                                            BMI_Low <= 0.5 & Glucose_High > 0.5 & BloodPressure_Medium <= 0.5
# 500                                                                                                       Age_Medium <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 513                                                                                              Age_Low > 0.5 & Glucose_High <= 0.5 & Pregnancies_Medium <= 0.5
# 518                                                                                                                   BMI_Low <= 0.5 & Pregnancies_Medium <= 0.5
# 520                                                                                          BMI_Medium <= 0.5 & Glucose_Low <= 0.5 & SkinThickness_Medium > 0.5
# 554                                                                                              Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 566                                                                 BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Glucose_Low <= 0.5 & BMI_Medium <= 0.5
# 570                                                                                                      BMI_Low > 0.5 & Pregnancies_Low > 0.5 & Age_High <= 0.5
# 575                                                                                                    Glucose_High <= 0.5 & BMI_Medium <= 0.5 & BMI_High <= 0.5
# 585                                                                                     Glucose_High <= 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Low <= 0.5
# 587                                                                                                                          BMI_Low <= 0.5 & Glucose_Low <= 0.5
# 598                                                                             BMI_Medium > 0.5 & DiabetesPedigreeFunction_Low > 0.5 & SkinThickness_Low <= 0.5
# 620                                                                                                                     Age_Low > 0.5 & SkinThickness_Low <= 0.5
# 637                    Glucose_Low <= 0.5 & Glucose_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Medium <= 0.5 & SkinThickness_Low > 0.5
# 653                                                                                          BloodPressure_High <= 0.5 & BMI_Medium <= 0.5 & Glucose_High <= 0.5
# 696                                                                                          Glucose_High <= 0.5 & BMI_High <= 0.5 & BloodPressure_Medium <= 0.5
# 705                                                                                                BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 707                                                                                                            BloodPressure_Low > 0.5 & SkinThickness_Low > 0.5
# 820                                                                                              Glucose_High > 0.5 & BMI_Low <= 0.5 & SkinThickness_High <= 0.5
# 829                                                                  BMI_Low <= 0.5 & Pregnancies_High <= 0.5 & SkinThickness_Medium > 0.5 & Glucose_High <= 0.5
# 855                                                                                    Age_Medium <= 0.5 & BloodPressure_Low <= 0.5 & BloodPressure_Medium > 0.5
# 944                                                                                               BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 946                                                                                                  Glucose_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5
#
#      type      coef   support  importance
# 63   rule  0.072857  0.211144    0.029735
# 126  rule -0.187202  0.603499    0.091574
# 129  rule -0.063791  0.645533    0.030515
# 146  rule -0.015909  0.296830    0.007268
# 172  rule -1.055592  0.211765    0.431272
# 173  rule -0.088789  0.127536    0.029618
# 184  rule -0.092192  0.093567    0.026849
# 188  rule -0.050446  0.134328    0.017202
# 258  rule  0.032057  0.242604    0.013741
# 300  rule -0.049542  0.468208    0.024721
# 388  rule  0.271040  0.228070    0.113725
# 394  rule -0.033914  0.404692    0.016646
# 425  rule  0.093391  0.151335    0.033469
# 452  rule -0.285412  0.727536    0.127073
# 465  rule  0.807363  0.054217    0.182823
# 500  rule -0.073840  0.471976    0.036862
# 513  rule -0.086796  0.500000    0.043398
# 518  rule  0.121918  0.441441    0.060540
# 520  rule  0.364949  0.103245    0.111046
# 554  rule  0.081165  0.288690    0.036780
# 566  rule  0.026485  0.050746    0.005813
# 570  rule -0.196337  0.205970    0.079400
# 575  rule -0.081853  0.311377    0.037903
# 585  rule -0.166127  0.561960    0.082423
# 587  rule  0.696920  0.557185    0.346173
# 598  rule -0.068963  0.215569    0.028359
# 620  rule -0.026193  0.386905    0.012757
# 637  rule  0.032636  0.087719    0.009232
# 653  rule -0.414162  0.328402    0.194504
# 696  rule -0.729914  0.245562    0.314170
# 705  rule -0.061291  0.527778    0.030598
# 707  rule -0.121675  0.105556    0.037387
# 820  rule  0.041911  0.139942    0.014540
# 829  rule -0.052138  0.228070    0.021876
# 855  rule -0.097686  0.494186    0.048840
# 944  rule  0.022158  0.285303    0.010006
# 946  rule -0.715195  0.524781    0.357158

# %%
def create_KB(rules_df, conclusion_name='Outcome'):
    rules_list = rules_df['rule'].to_list()
    coef_list  = rules_df['coef'].to_list()

    rules_list = [rule.split(' ') for rule in rules_list]

    KB = []
    for rule, coef in zip(rules_list, coef_list):

        # '&' を目印にして複数のリストに分割する
        sublists = []
        current_sublist = []
        for item in rule:
            if item != '&':
                current_sublist.append(item)
            else:
                sublists.append(current_sublist)
                current_sublist = []

        # ループ終了後に最後のサブリストを追加
        sublists.append(current_sublist)

        rule_new = []
        cnt = 0
        for sublist in sublists:
            if len(sublist) <= 1:
                rule_new.append(sublist[0])
            else:
                if sublist[1] in ['<', '<=']:
                    rule_new.append('¬')
                    rule_new.append(sublist[0])
                else:
                    rule_new.append(sublist[0])
            
            cnt +=1
            if cnt < len(sublists):
                rule_new.append('⊗')
            else:
                rule_new.append('→')

                # coef == 0 の rule は除外されているため
                if coef > 0:
                    rule_new.append(conclusion_name)
                elif coef < 0:
                    rule_new.append('¬')
                    rule_new.append(conclusion_name)

        KB.append(rule_new)

    return KB

# %%
KB = create_KB(rules)

for formula in KB:
    print(formula)
# Out:
# ['¬', 'Glucose_Low', '⊗', '¬', 'Age_Low', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '→', '¬', 'Outcome']
# ['¬', 'Pregnancies_High', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_High', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Medium', '⊗', '¬', 'SkinThickness_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Low', '⊗', 'Pregnancies_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'BMI_Low', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'DiabetesPedigreeFunction_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_Low', '⊗', 'BMI_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BloodPressure_Medium', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Low', '⊗', '¬', 'BloodPressure_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'Glucose_High', '⊗', '¬', 'BloodPressure_Medium', '→', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_Medium', '→', 'Outcome']
# ['¬', 'BMI_Medium', '⊗', '¬', 'Glucose_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Pregnancies_Medium', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'BMI_Medium', '→', 'Outcome']
# ['BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'Age_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_Medium', '⊗', '¬', 'BMI_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '→', 'Outcome']
# ['BMI_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'SkinThickness_Medium', '⊗', 'SkinThickness_Low', '→', 'Outcome']
# ['¬', 'BloodPressure_High', '⊗', '¬', 'BMI_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['BloodPressure_Low', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', '¬', 'SkinThickness_High', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_High', '⊗', 'SkinThickness_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', '¬', 'BloodPressure_Low', '⊗', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '→', '¬', 'Outcome']

# %%
rules
# Out:
#                                                                                                                                                             rule  \
# 63                                                                                                          Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5
# 126                                                                                                 Glucose_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5
# 129                                                                                                                      Pregnancies_High <= 0.5 & Age_Low > 0.5
# 146                                                                                                                          Glucose_High <= 0.5 & BMI_Low > 0.5
# 172                                                                                                     DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low > 0.5
# 173  Glucose_High <= 0.5 & Age_Medium <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_Low <= 0.5
# 184                                                                                              Glucose_High <= 0.5 & Age_Low <= 0.5 & Pregnancies_Medium > 0.5
# 188                                                                                              Age_Medium <= 0.5 & BMI_Low > 0.5 & BloodPressure_Medium <= 0.5
# 258                                                                                    BMI_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 300                                    Glucose_Low <= 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BMI_High <= 0.5 & Age_Medium <= 0.5
# 388                                                                                                       DiabetesPedigreeFunction_Low <= 0.5 & BMI_Medium > 0.5
# 394                                                                                         Glucose_High <= 0.5 & BloodPressure_Medium > 0.5 & Age_Medium <= 0.5
# 425                                                                                       Age_Low <= 0.5 & BloodPressure_Low <= 0.5 & SkinThickness_Medium > 0.5
# 452                                                                                                                Glucose_High <= 0.5 & Pregnancies_High <= 0.5
# 465                                                                                            BMI_Low <= 0.5 & Glucose_High > 0.5 & BloodPressure_Medium <= 0.5
# 500                                                                                                       Age_Medium <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 513                                                                                              Age_Low > 0.5 & Glucose_High <= 0.5 & Pregnancies_Medium <= 0.5
# 518                                                                                                                   BMI_Low <= 0.5 & Pregnancies_Medium <= 0.5
# 520                                                                                          BMI_Medium <= 0.5 & Glucose_Low <= 0.5 & SkinThickness_Medium > 0.5
# 554                                                                                              Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 566                                                                 BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Glucose_Low <= 0.5 & BMI_Medium <= 0.5
# 570                                                                                                      BMI_Low > 0.5 & Pregnancies_Low > 0.5 & Age_High <= 0.5
# 575                                                                                                    Glucose_High <= 0.5 & BMI_Medium <= 0.5 & BMI_High <= 0.5
# 585                                                                                     Glucose_High <= 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Low <= 0.5
# 587                                                                                                                          BMI_Low <= 0.5 & Glucose_Low <= 0.5
# 598                                                                             BMI_Medium > 0.5 & DiabetesPedigreeFunction_Low > 0.5 & SkinThickness_Low <= 0.5
# 620                                                                                                                     Age_Low > 0.5 & SkinThickness_Low <= 0.5
# 637                    Glucose_Low <= 0.5 & Glucose_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Medium <= 0.5 & SkinThickness_Low > 0.5
# 653                                                                                          BloodPressure_High <= 0.5 & BMI_Medium <= 0.5 & Glucose_High <= 0.5
# 696                                                                                          Glucose_High <= 0.5 & BMI_High <= 0.5 & BloodPressure_Medium <= 0.5
# 705                                                                                                BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 707                                                                                                            BloodPressure_Low > 0.5 & SkinThickness_Low > 0.5
# 820                                                                                              Glucose_High > 0.5 & BMI_Low <= 0.5 & SkinThickness_High <= 0.5
# 829                                                                  BMI_Low <= 0.5 & Pregnancies_High <= 0.5 & SkinThickness_Medium > 0.5 & Glucose_High <= 0.5
# 855                                                                                    Age_Medium <= 0.5 & BloodPressure_Low <= 0.5 & BloodPressure_Medium > 0.5
# 944                                                                                               BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 946                                                                                                  Glucose_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5
#
#      type      coef   support  importance
# 63   rule  0.072857  0.211144    0.029735
# 126  rule -0.187202  0.603499    0.091574
# 129  rule -0.063791  0.645533    0.030515
# 146  rule -0.015909  0.296830    0.007268
# 172  rule -1.055592  0.211765    0.431272
# 173  rule -0.088789  0.127536    0.029618
# 184  rule -0.092192  0.093567    0.026849
# 188  rule -0.050446  0.134328    0.017202
# 258  rule  0.032057  0.242604    0.013741
# 300  rule -0.049542  0.468208    0.024721
# 388  rule  0.271040  0.228070    0.113725
# 394  rule -0.033914  0.404692    0.016646
# 425  rule  0.093391  0.151335    0.033469
# 452  rule -0.285412  0.727536    0.127073
# 465  rule  0.807363  0.054217    0.182823
# 500  rule -0.073840  0.471976    0.036862
# 513  rule -0.086796  0.500000    0.043398
# 518  rule  0.121918  0.441441    0.060540
# 520  rule  0.364949  0.103245    0.111046
# 554  rule  0.081165  0.288690    0.036780
# 566  rule  0.026485  0.050746    0.005813
# 570  rule -0.196337  0.205970    0.079400
# 575  rule -0.081853  0.311377    0.037903
# 585  rule -0.166127  0.561960    0.082423
# 587  rule  0.696920  0.557185    0.346173
# 598  rule -0.068963  0.215569    0.028359
# 620  rule -0.026193  0.386905    0.012757
# 637  rule  0.032636  0.087719    0.009232
# 653  rule -0.414162  0.328402    0.194504
# 696  rule -0.729914  0.245562    0.314170
# 705  rule -0.061291  0.527778    0.030598
# 707  rule -0.121675  0.105556    0.037387
# 820  rule  0.041911  0.139942    0.014540
# 829  rule -0.052138  0.228070    0.021876
# 855  rule -0.097686  0.494186    0.048840
# 944  rule  0.022158  0.285303    0.010006
# 946  rule -0.715195  0.524781    0.357158

# %%
class ArrangeRules:
    def __init__(self, rules_df, feature_names=None, conclusion_name=None):
        self.rules_df = rules_df
        self.feature_names = feature_names

        if not conclusion_name:
            self.conclusion_name = 'Outcome'
        else:
            self.conclusion_name = conclusion_name

        self.rules_extracted = None
        self.rules_additional = None
        self.KB = None

    def extract_rules_from_df(self):
        rules_list = self.rules_df['rule'].to_list()
        coef_list  = self.rules_df['coef'].to_list()

        rules_list = [rule.split(' ') for rule in rules_list]

        self.rules_extracted = []
        for rule, coef in zip(rules_list, coef_list):

            # '&' を目印にして複数のリストに分割する
            sublists = []
            current_sublist = []
            for item in rule:
                if item != '&':
                    current_sublist.append(item)
                else:
                    sublists.append(current_sublist)
                    current_sublist = []

            # ループ終了後に最後のサブリストを追加
            sublists.append(current_sublist)

            rule_new = []
            cnt = 0
            for sublist in sublists:
                if len(sublist) <= 1:
                    rule_new.append(sublist[0])
                else:
                    if sublist[1] in ['<', '<=']:
                        rule_new.append('¬')
                        rule_new.append(sublist[0])
                    else:
                        rule_new.append(sublist[0])
                
                cnt +=1
                if cnt < len(sublists):
                    rule_new.append('⊗')
                else:
                    rule_new.append('→')

                    # coef == 0 の rule は除外されているため
                    if coef > 0:
                        rule_new.append(self.conclusion_name)
                    elif coef < 0:
                        rule_new.append('¬')
                        rule_new.append(self.conclusion_name)

            self.rules_extracted.append(rule_new)

        return self.rules_extracted

    def generate_rules_from_df(self):
        if self.feature_names:
            tmp_dict = {}
            for item in self.feature_names:
                key, value = item.rsplit('_', 1)
                if key not in tmp_dict:
                    tmp_dict[key] = []

                tmp_dict[key].append(item)
            
            self.rules_additional = list(tmp_dict.values())
            self.rules_additional = [' ⊕ '.join(rule) for rule in self.rules_additional]
            self.rules_additional = [rule.split(' ') for rule in self.rules_additional]

            return self.rules_additional

        else:
            return []


    def construct_KB(self):
        rules_extracted = self.extract_rules_from_df()
        rules_additional = self.generate_rules_from_df()

        self.KB = rules_extracted + rules_additional
        return self.KB
    
    def save_KB_as_txt(self, file_name):
        if self.KB:
            rules = [' '.join(rule) for rule in self.KB]

        with open(file_name, 'w') as file:
            for item in rules:
                file.write("%s\n" % item)

# %%
rule_processor = ArrangeRules(rules, 
                              feature_names=feature_names, 
                              conclusion_name="Outcome")

KB = rule_processor.construct_KB()

import os
project_dir_path = './../../../lukasiewicz_1/'
file_name = os.path.join(project_dir_path, "rules.txt")
rule_processor.save_KB_as_txt(file_name)

# %%
for rule in KB:
    print(rule)
# Out:
# ['¬', 'Glucose_Low', '⊗', '¬', 'Age_Low', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '→', '¬', 'Outcome']
# ['¬', 'Pregnancies_High', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_High', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Medium', '⊗', '¬', 'SkinThickness_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Low', '⊗', 'Pregnancies_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'BMI_Low', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'DiabetesPedigreeFunction_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_Low', '⊗', 'BMI_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BloodPressure_Medium', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Low', '⊗', '¬', 'BloodPressure_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'Glucose_High', '⊗', '¬', 'BloodPressure_Medium', '→', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_Medium', '→', 'Outcome']
# ['¬', 'BMI_Medium', '⊗', '¬', 'Glucose_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Pregnancies_Medium', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'BMI_Medium', '→', 'Outcome']
# ['BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'Age_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_Medium', '⊗', '¬', 'BMI_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '→', 'Outcome']
# ['BMI_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'SkinThickness_Medium', '⊗', 'SkinThickness_Low', '→', 'Outcome']
# ['¬', 'BloodPressure_High', '⊗', '¬', 'BMI_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['BloodPressure_Low', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', '¬', 'SkinThickness_High', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_High', '⊗', 'SkinThickness_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', '¬', 'BloodPressure_Low', '⊗', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['Pregnancies_Low', '⊕', 'Pregnancies_Medium', '⊕', 'Pregnancies_High']
# ['Glucose_Low', '⊕', 'Glucose_Medium', '⊕', 'Glucose_High']
# ['BloodPressure_Low', '⊕', 'BloodPressure_Medium', '⊕', 'BloodPressure_High']
# ['SkinThickness_Low', '⊕', 'SkinThickness_Medium', '⊕', 'SkinThickness_High']
# ['BMI_Low', '⊕', 'BMI_Medium', '⊕', 'BMI_High']
# ['DiabetesPedigreeFunction_Low', '⊕', 'DiabetesPedigreeFunction_Medium', '⊕', 'DiabetesPedigreeFunction_High']
# ['Age_Low', '⊕', 'Age_Medium', '⊕', 'Age_High']

# %%
KB
# Out:
# [['¬',
#   'Glucose_Low',
#   '⊗',
#   '¬',
#   'Age_Low',
#   '⊗',
#   '¬',
#   'BMI_Low',
#   '→',
#   'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'DiabetesPedigreeFunction_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬', 'Pregnancies_High', '⊗', 'Age_Low', '→', '¬', 'Outcome'],
#  ['¬', 'Glucose_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome'],
#  ['¬',
#   'DiabetesPedigreeFunction_High',
#   '⊗',
#   'Glucose_Low',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'Age_Medium',
#   '⊗',
#   '¬',
#   'SkinThickness_Low',
#   '⊗',
#   '¬',
#   'Glucose_Low',
#   '⊗',
#   '¬',
#   'DiabetesPedigreeFunction_Medium',
#   '⊗',
#   '¬',
#   'BloodPressure_Low',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'Age_Low',
#   '⊗',
#   'Pregnancies_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Age_Medium',
#   '⊗',
#   'BMI_Low',
#   '⊗',
#   '¬',
#   'BloodPressure_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'BMI_Low',
#   '⊗',
#   '¬',
#   'Glucose_Low',
#   '⊗',
#   '¬',
#   'DiabetesPedigreeFunction_Low',
#   '→',
#   'Outcome'],
#  ['¬',
#   'Glucose_Low',
#   '⊗',
#   '¬',
#   'Pregnancies_High',
#   '⊗',
#   '¬',
#   'DiabetesPedigreeFunction_High',
#   '⊗',
#   '¬',
#   'BMI_High',
#   '⊗',
#   '¬',
#   'Age_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬', 'DiabetesPedigreeFunction_Low', '⊗', 'BMI_Medium', '→', 'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   'BloodPressure_Medium',
#   '⊗',
#   '¬',
#   'Age_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Age_Low',
#   '⊗',
#   '¬',
#   'BloodPressure_Low',
#   '⊗',
#   'SkinThickness_Medium',
#   '→',
#   'Outcome'],
#  ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '→', '¬', 'Outcome'],
#  ['¬',
#   'BMI_Low',
#   '⊗',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'BloodPressure_Medium',
#   '→',
#   'Outcome'],
#  ['¬', 'Age_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome'],
#  ['Age_Low',
#   '⊗',
#   '¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'Pregnancies_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_Medium', '→', 'Outcome'],
#  ['¬',
#   'BMI_Medium',
#   '⊗',
#   '¬',
#   'Glucose_Low',
#   '⊗',
#   'SkinThickness_Medium',
#   '→',
#   'Outcome'],
#  ['¬',
#   'Pregnancies_Medium',
#   '⊗',
#   '¬',
#   'DiabetesPedigreeFunction_Low',
#   '→',
#   'Outcome'],
#  ['¬',
#   'BMI_Low',
#   '⊗',
#   'DiabetesPedigreeFunction_Low',
#   '⊗',
#   '¬',
#   'Glucose_Low',
#   '⊗',
#   '¬',
#   'BMI_Medium',
#   '→',
#   'Outcome'],
#  ['BMI_Low',
#   '⊗',
#   'Pregnancies_Low',
#   '⊗',
#   '¬',
#   'Age_High',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'BMI_Medium',
#   '⊗',
#   '¬',
#   'BMI_High',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'Pregnancies_High',
#   '⊗',
#   '¬',
#   'BloodPressure_Low',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '→', 'Outcome'],
#  ['BMI_Medium',
#   '⊗',
#   'DiabetesPedigreeFunction_Low',
#   '⊗',
#   '¬',
#   'SkinThickness_Low',
#   '→',
#   '¬',
#   'Outcome'],
#  ['Age_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome'],
#  ['¬',
#   'Glucose_Low',
#   '⊗',
#   '¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'BMI_Low',
#   '⊗',
#   'Pregnancies_Low',
#   '⊗',
#   '¬',
#   'SkinThickness_Medium',
#   '⊗',
#   'SkinThickness_Low',
#   '→',
#   'Outcome'],
#  ['¬',
#   'BloodPressure_High',
#   '⊗',
#   '¬',
#   'BMI_Medium',
#   '⊗',
#   '¬',
#   'Glucose_High',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   '¬',
#   'BMI_High',
#   '⊗',
#   '¬',
#   'BloodPressure_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'BloodPressure_Low',
#   '⊗',
#   'DiabetesPedigreeFunction_Low',
#   '→',
#   '¬',
#   'Outcome'],
#  ['BloodPressure_Low', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome'],
#  ['Glucose_High',
#   '⊗',
#   '¬',
#   'BMI_Low',
#   '⊗',
#   '¬',
#   'SkinThickness_High',
#   '→',
#   'Outcome'],
#  ['¬',
#   'BMI_Low',
#   '⊗',
#   '¬',
#   'Pregnancies_High',
#   '⊗',
#   'SkinThickness_Medium',
#   '⊗',
#   '¬',
#   'Glucose_High',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'Age_Medium',
#   '⊗',
#   '¬',
#   'BloodPressure_Low',
#   '⊗',
#   'BloodPressure_Medium',
#   '→',
#   '¬',
#   'Outcome'],
#  ['¬',
#   'BloodPressure_Low',
#   '⊗',
#   '¬',
#   'DiabetesPedigreeFunction_Low',
#   '→',
#   'Outcome'],
#  ['¬',
#   'Glucose_High',
#   '⊗',
#   'Pregnancies_Low',
#   '⊗',
#   'Age_Low',
#   '→',
#   '¬',
#   'Outcome'],
#  'Pregnancies_Low ⊕ Pregnancies_Medium ⊕ Pregnancies_High',
#  'Glucose_Low ⊕ Glucose_Medium ⊕ Glucose_High',
#  'BloodPressure_Low ⊕ BloodPressure_Medium ⊕ BloodPressure_High',
#  'SkinThickness_Low ⊕ SkinThickness_Medium ⊕ SkinThickness_High',
#  'BMI_Low ⊕ BMI_Medium ⊕ BMI_High',
#  'DiabetesPedigreeFunction_Low ⊕ DiabetesPedigreeFunction_Medium ⊕ DiabetesPedigreeFunction_High',
#  'Age_Low ⊕ Age_Medium ⊕ Age_High']

# %%
os.listdir(project_dir_path)
# Out:
# ['notebooks',
#  'src',
#  'README.MD',
#  'log.md',
#  'myenv',
#  'inputs',
#  'images',
#  'docs',
#  '.git',
#  'requirements.txt',
#  '.gitignore']

# %%
tmp = [1, 2, 3]
a = []

tmp + a
# Out:
# [1, 2, 3]

# %%
a = {}
b = None

if a:
    print(a)
elif not a:
    print("-------------")

if b:
    print("-------------")
elif not b:
    print(b)
# Out:
# -------------
# None

# %% [markdown]
# # max_iter=50 としたものも採用して比較してみる

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(max_rules=50,
                       rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(max_rules=50, random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=13,
#                                                         random_state=54))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7761194029850746
#
#
# Confusion Matrix:
#  [[73 17]
#  [13 31]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        90
#            1       0.65      0.70      0.67        44
#
#     accuracy                           0.78       134
#    macro avg       0.75      0.76      0.75       134
# weighted avg       0.78      0.78      0.78       134

# %%
rules = rf.get_rules(exclude_zero_coef=True)
rules
# Out:
#                                                                                              rule  ... importance
# 1                                                                              Pregnancies_Medium  ...   0.207774
# 2                                                                                Pregnancies_High  ...   0.040943
# 3                                                                                     Glucose_Low  ...   0.076873
# 5                                                                                    Glucose_High  ...   0.071525
# 7                                                                            BloodPressure_Medium  ...   0.059211
# 8                                                                              BloodPressure_High  ...   0.077339
# 11                                                                             SkinThickness_High  ...   0.053121
# 12                                                                                        BMI_Low  ...   0.043059
# 13                                                                                     BMI_Medium  ...   0.086727
# 15                                                                   DiabetesPedigreeFunction_Low  ...   0.176650
# 17                                                                  DiabetesPedigreeFunction_High  ...   0.079569
# 21                                                                            Glucose_High <= 0.5  ...   0.082127
# 22                                                                             Glucose_High > 0.5  ...   0.406463
# 23                                   BMI_High <= 0.5 & Pregnancies_Low <= 0.5 & BMI_Medium <= 0.5  ...   0.195599
# 26                   BMI_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5 & Glucose_Low <= 0.5  ...   0.456171
# 29                                 BMI_High > 0.5 & Glucose_Low <= 0.5 & BloodPressure_High > 0.5  ...   0.127813
# 30                                                             BMI_High > 0.5 & Glucose_Low > 0.5  ...   0.091389
# 32                              Glucose_High <= 0.5 & Age_Medium <= 0.5 & BloodPressure_Low > 0.5  ...   0.078231
# 36                                                                  Age_Low > 0.5 & BMI_Low > 0.5  ...   0.121217
# 40                                                                                  BMI_Low > 0.5  ...   0.266341
# 42                                  Age_Low <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low > 0.5  ...   0.011933
# 43                                                       Age_Low <= 0.5 & SkinThickness_Low > 0.5  ...   0.140618
# 44                      Age_Low > 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & Glucose_High <= 0.5  ...   0.041367
# 48                                                              Age_Low > 0.5 & Glucose_Low > 0.5  ...   0.398405
# 50                    BMI_Low <= 0.5 & DiabetesPedigreeFunction_Medium > 0.5 & Glucose_Low <= 0.5  ...   0.171435
# 52                                                                              Age_Medium <= 0.5  ...   0.013058
# 57                       BMI_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5  ...   0.057642
# 58                                                                BMI_High <= 0.5 & BMI_Low > 0.5  ...   0.077610
# 60  BMI_High > 0.5 & BloodPressure_High <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Low <= 0.5  ...   0.212851
# 63                                           Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5  ...   0.293848
# 65                                     Glucose_Low <= 0.5 & Age_Low > 0.5 & Glucose_Medium <= 0.5  ...   0.073954
# 67                                                                              Glucose_Low > 0.5  ...   0.416337
#
# [32 rows x 5 columns]
