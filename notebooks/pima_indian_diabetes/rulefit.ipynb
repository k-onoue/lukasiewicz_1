# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from rulefit import RuleFit, RuleFitClassifier

# %% [markdown]
# # RuleFit

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=552,
#                                                         random_state=593))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7388059701492538
#
#
# Confusion Matrix:
#  [[72 18]
#  [17 27]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80        90
#            1       0.60      0.61      0.61        44
#
#     accuracy                           0.74       134
#    macro avg       0.70      0.71      0.71       134
# weighted avg       0.74      0.74      0.74       134

# %%
rules = rf.get_rules(exclude_zero_coef=True)

pd.set_option("display.max_colwidth", 999) #ruleが長すぎて表示が省略される場合用
pd.set_option("display.max_rows", 999) 
rules
# Out:
#                                                                                                                                                             rule  ... importance
# 63                                                                                                          Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5  ...   0.029774
# 126                                                                                                 Glucose_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5  ...   0.091401
# 129                                                                                                                      Pregnancies_High <= 0.5 & Age_Low > 0.5  ...   0.030914
# 173                                                                                                     DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low > 0.5  ...   0.431639
# 174  Glucose_High <= 0.5 & Age_Medium <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_Low <= 0.5  ...   0.029560
# 185                                                                                              Glucose_High <= 0.5 & Age_Low <= 0.5 & Pregnancies_Medium > 0.5  ...   0.026849
# 189                                                                                              Age_Medium <= 0.5 & BMI_Low > 0.5 & BloodPressure_Medium <= 0.5  ...   0.017096
# 259                                                                                    BMI_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5  ...   0.014575
# 301                                    Glucose_Low <= 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BMI_High <= 0.5 & Age_Medium <= 0.5  ...   0.025125
# 389                                                                                                       DiabetesPedigreeFunction_Low <= 0.5 & BMI_Medium > 0.5  ...   0.113602
# 394                                                                                         Glucose_High <= 0.5 & BloodPressure_Medium > 0.5 & Age_Medium <= 0.5  ...   0.017432
# 424                                                                                       Age_Low <= 0.5 & BloodPressure_Low <= 0.5 & SkinThickness_Medium > 0.5  ...   0.033545
# 450                                                                                                                Glucose_High <= 0.5 & Pregnancies_High <= 0.5  ...   0.126357
# 463                                                                                            BMI_Low <= 0.5 & Glucose_High > 0.5 & BloodPressure_Medium <= 0.5  ...   0.183231
# 498                                                                                                       Age_Medium <= 0.5 & DiabetesPedigreeFunction_Low > 0.5  ...   0.036634
# 510                                                                                              Age_Low > 0.5 & Glucose_High <= 0.5 & Pregnancies_Medium <= 0.5  ...   0.044518
# 515                                                                                                                   BMI_Low <= 0.5 & Pregnancies_Medium <= 0.5  ...   0.060867
# 517                                                                                          BMI_Medium <= 0.5 & Glucose_Low <= 0.5 & SkinThickness_Medium > 0.5  ...   0.111217
# 526                                                                                                        Glucose_High <= 0.5 & BMI_High <= 0.5 & BMI_Low > 0.5  ...   0.044454
# 552                                                                                              Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5  ...   0.036141
# 564                                                                 BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Glucose_Low <= 0.5 & BMI_Medium <= 0.5  ...   0.005937
# 568                                                                                                      BMI_Low > 0.5 & Pregnancies_Low > 0.5 & Age_High <= 0.5  ...   0.079340
# 584                                                                                     Glucose_High <= 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Low <= 0.5  ...   0.082387
# 586                                                                                                                          BMI_Low <= 0.5 & Glucose_Low <= 0.5  ...   0.345352
# 597                                                                             BMI_Medium > 0.5 & DiabetesPedigreeFunction_Low > 0.5 & SkinThickness_Low <= 0.5  ...   0.027991
# 621                                                                                                                     Age_Low > 0.5 & SkinThickness_Low <= 0.5  ...   0.012993
# 638                    Glucose_Low <= 0.5 & Glucose_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Medium <= 0.5 & SkinThickness_Low > 0.5  ...   0.008861
# 655                                                                                          BloodPressure_High <= 0.5 & BMI_Medium <= 0.5 & Glucose_High <= 0.5  ...   0.194830
# 698                                                                                          Glucose_High <= 0.5 & BMI_High <= 0.5 & BloodPressure_Medium <= 0.5  ...   0.313918
# 707                                                                                                BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5  ...   0.031028
# 709                                                                                                            BloodPressure_Low > 0.5 & SkinThickness_Low > 0.5  ...   0.037267
# 822                                                                                              Glucose_High > 0.5 & BMI_Low <= 0.5 & SkinThickness_High <= 0.5  ...   0.014501
# 830                                                                  BMI_Low <= 0.5 & Pregnancies_High <= 0.5 & SkinThickness_Medium > 0.5 & Glucose_High <= 0.5  ...   0.022478
# 856                                                                                    Age_Medium <= 0.5 & BloodPressure_Low <= 0.5 & BloodPressure_Medium > 0.5  ...   0.047381
# 944                                                                                               BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5  ...   0.009994
# 946                                                                                                  Glucose_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5  ...   0.355628
#
# [36 rows x 5 columns]

# %%
def create_KB(rules_df):
    rules = rules_df['rule'].to_list()
    coef  = rules_df['coef'].to_list()

    ``

# %% [markdown]
# # max_iter=50 としたものも採用して比較してみる

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(max_rules=50,
                       rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(max_rules=50, random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=13,
#                                                         random_state=54))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7761194029850746
#
#
# Confusion Matrix:
#  [[73 17]
#  [13 31]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        90
#            1       0.65      0.70      0.67        44
#
#     accuracy                           0.78       134
#    macro avg       0.75      0.76      0.75       134
# weighted avg       0.78      0.78      0.78       134

# %%
rules = rf.get_rules(exclude_zero_coef=True)
rules
# Out:
#                                                                                              rule  ... importance
# 1                                                                              Pregnancies_Medium  ...   0.207774
# 2                                                                                Pregnancies_High  ...   0.040943
# 3                                                                                     Glucose_Low  ...   0.076873
# 5                                                                                    Glucose_High  ...   0.071525
# 7                                                                            BloodPressure_Medium  ...   0.059211
# 8                                                                              BloodPressure_High  ...   0.077339
# 11                                                                             SkinThickness_High  ...   0.053121
# 12                                                                                        BMI_Low  ...   0.043059
# 13                                                                                     BMI_Medium  ...   0.086727
# 15                                                                   DiabetesPedigreeFunction_Low  ...   0.176650
# 17                                                                  DiabetesPedigreeFunction_High  ...   0.079569
# 21                                                                            Glucose_High <= 0.5  ...   0.082127
# 22                                                                             Glucose_High > 0.5  ...   0.406463
# 23                                   BMI_High <= 0.5 & Pregnancies_Low <= 0.5 & BMI_Medium <= 0.5  ...   0.195599
# 26                   BMI_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5 & Glucose_Low <= 0.5  ...   0.456171
# 29                                 BMI_High > 0.5 & Glucose_Low <= 0.5 & BloodPressure_High > 0.5  ...   0.127813
# 30                                                             BMI_High > 0.5 & Glucose_Low > 0.5  ...   0.091389
# 32                              Glucose_High <= 0.5 & Age_Medium <= 0.5 & BloodPressure_Low > 0.5  ...   0.078231
# 36                                                                  Age_Low > 0.5 & BMI_Low > 0.5  ...   0.121217
# 40                                                                                  BMI_Low > 0.5  ...   0.266341
# 42                                  Age_Low <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low > 0.5  ...   0.011933
# 43                                                       Age_Low <= 0.5 & SkinThickness_Low > 0.5  ...   0.140618
# 44                      Age_Low > 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & Glucose_High <= 0.5  ...   0.041367
# 48                                                              Age_Low > 0.5 & Glucose_Low > 0.5  ...   0.398405
# 50                    BMI_Low <= 0.5 & DiabetesPedigreeFunction_Medium > 0.5 & Glucose_Low <= 0.5  ...   0.171435
# 52                                                                              Age_Medium <= 0.5  ...   0.013058
# 57                       BMI_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5  ...   0.057642
# 58                                                                BMI_High <= 0.5 & BMI_Low > 0.5  ...   0.077610
# 60  BMI_High > 0.5 & BloodPressure_High <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Low <= 0.5  ...   0.212851
# 63                                           Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5  ...   0.293848
# 65                                     Glucose_Low <= 0.5 & Age_Low > 0.5 & Glucose_Medium <= 0.5  ...   0.073954
# 67                                                                              Glucose_Low > 0.5  ...   0.416337
#
# [32 rows x 5 columns]
