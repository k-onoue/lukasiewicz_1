# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report


import sys
project_dir_path = '/Users/keisukeonoue/ws/lukasiewicz_1/'
sys.path.append(project_dir_path)
from src.rulefit import RuleFit, RuleFitClassifier

# %% [markdown]
# # RuleFit

# %% [markdown]
# __train_test_split__ の際に分割されたデータのインデックスがほしい

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = data.drop(["Outcome"], axis=1)
y = data["Outcome"]

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

train_index = X_train.index
test_index = X_test.index

# import os
# project_dir_path = "/home/onoue/ws/lukasiewicz_1/"
# data_dir_path = "inputs/pima_indian_diabetes"
# save_dir_path = os.path.join(project_dir_path, data_dir_path)

# file_path_1 = os.path.join(save_dir_path, 'train_index.csv')
# pd.DataFrame(train_index).to_csv(file_path_1)

# file_path_2 = os.path.join(save_dir_path, 'test_index.csv')
# pd.DataFrame(test_index).to_csv(file_path_2)



X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(rfmode=rfmode,
                       tree_generator=tree_generator,
                       random_state=random_state,
                       exp_rand_tree_size=False)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)
print(rf)
y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(exp_rand_tree_size=False, random_state=42,
#                   tree_generator=RandomForestClassifier(random_state=42))
# RuleFitClassifier(exp_rand_tree_size=False, random_state=42,
#                   tree_generator=RandomForestClassifier(random_state=42))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7985074626865671
#
#
# Confusion Matrix:
#  [[77 13]
#  [14 30]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85        90
#            1       0.70      0.68      0.69        44
#
#     accuracy                           0.80       134
#    macro avg       0.77      0.77      0.77       134
# weighted avg       0.80      0.80      0.80       134

# %%
rules_df = rf.get_rules(exclude_zero_coef=True)

pd.set_option("display.max_colwidth", 999) #ruleが長すぎて表示が省略される場合用
pd.set_option("display.max_rows", 999) 
rules_df
# Out:
#                                                                                                                                                                                                                                                                     rule  \
# 0                                                                                                                                                                                                                                                        Pregnancies_Low
# 2                                                                                                                                                                                                                                                       Pregnancies_High
# 3                                                                                                                                                                                                                                                            Glucose_Low
# 5                                                                                                                                                                                                                                                           Glucose_High
# 12                                                                                                                                                                                                                                                               BMI_Low
# 13                                                                                                                                                                                                                                                            BMI_Medium
# 15                                                                                                                                                                                                                                          DiabetesPedigreeFunction_Low
# 18                                                                                                                                                                                                                                                               Age_Low
# 19                                                                                                                                                                                                                                                            Age_Medium
# 228                                                                                                                                             Pregnancies_Medium <= 0.5 & Glucose_High > 0.5 & BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & BMI_Medium > 0.5
# 320                                                                                                                     Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & Age_Medium > 0.5 & BloodPressure_Medium > 0.5 & BMI_Low <= 0.5 & Glucose_Medium > 0.5
# 435                                                      Glucose_High <= 0.5 & Glucose_Low <= 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & BloodPressure_Medium <= 0.5 & BloodPressure_Low <= 0.5 & Age_Low <= 0.5 & SkinThickness_Medium <= 0.5
# 1362   BMI_Low <= 0.5 & Glucose_Medium > 0.5 & Pregnancies_High <= 0.5 & SkinThickness_Low <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_High <= 0.5 & BMI_High <= 0.5 & BloodPressure_Low <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Medium > 0.5
# 1507                                                                                                 Glucose_Low <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BloodPressure_High > 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 1797                                                                                                                                                                                                 BMI_Medium > 0.5 & Glucose_High > 0.5 & BloodPressure_Medium <= 0.5
# 4563                                                                                                                                       BloodPressure_High <= 0.5 & Pregnancies_Low > 0.5 & BMI_High <= 0.5 & BMI_Medium <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 4642                                                                                                                           Glucose_Low <= 0.5 & Glucose_Medium <= 0.5 & BloodPressure_Medium <= 0.5 & Pregnancies_Medium <= 0.5 & Age_Medium <= 0.5 & BMI_Low <= 0.5
# 6484                                                                                                                 Glucose_High <= 0.5 & Pregnancies_Low <= 0.5 & Glucose_Medium > 0.5 & BloodPressure_High > 0.5 & Pregnancies_Medium > 0.5 & SkinThickness_Low > 0.5
# 6783                                                                                                                                                Glucose_High <= 0.5 & BMI_Low > 0.5 & Age_Low > 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & Pregnancies_Low > 0.5
# 8510                               Age_Medium <= 0.5 & Glucose_Low <= 0.5 & BMI_Medium > 0.5 & Pregnancies_High <= 0.5 & Glucose_Medium > 0.5 & Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & SkinThickness_Low <= 0.5 & BloodPressure_Low <= 0.5
# 9362                                                                                                                                                                                       Pregnancies_High > 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & BMI_Low <= 0.5
# 9494                                                                                                                                                             BMI_Low > 0.5 & Pregnancies_Low > 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & BloodPressure_High <= 0.5
# 9514                                                                                                                                                BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & Glucose_High <= 0.5 & Age_Low <= 0.5 & Pregnancies_High > 0.5
# 10988                                                                             BMI_Medium <= 0.5 & BMI_High > 0.5 & Age_Low > 0.5 & SkinThickness_Low <= 0.5 & BloodPressure_High <= 0.5 & SkinThickness_High > 0.5 & Glucose_Low <= 0.5 & BloodPressure_Medium > 0.5
# 11421                                                                                                                               BMI_Low <= 0.5 & Glucose_High > 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_Medium <= 0.5
# 11569                                                                                 BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Age_Medium > 0.5 & BloodPressure_Medium > 0.5 & SkinThickness_Medium <= 0.5 & Glucose_Medium > 0.5 & Pregnancies_High <= 0.5
# 11720                                                                                                                                  BMI_High > 0.5 & Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low <= 0.5 & BloodPressure_High > 0.5
# 11728                                                                                                           Age_Medium <= 0.5 & BMI_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BloodPressure_Medium <= 0.5 & SkinThickness_Medium <= 0.5 & Age_High <= 0.5
#
#          type      coef   support  importance
# 0      linear -0.151962  1.000000    0.072427
# 2      linear  0.305828  1.000000    0.092052
# 3      linear -1.478275  1.000000    0.606849
# 5      linear  1.206659  1.000000    0.475425
# 12     linear -1.041453  1.000000    0.489083
# 13     linear  0.020003  1.000000    0.009961
# 15     linear -0.394431  1.000000    0.189549
# 18     linear -0.297883  1.000000    0.138185
# 19     linear  0.244737  1.000000    0.104064
# 228      rule  0.099318  0.029412    0.016780
# 320      rule  0.053266  0.023599    0.008086
# 435      rule -0.378048  0.023952    0.057804
# 1362     rule -0.023270  0.045181    0.004833
# 1507     rule  0.217247  0.017341    0.028359
# 1797     rule  0.494396  0.045455    0.102982
# 4563     rule -0.082598  0.056213    0.019025
# 4642     rule  0.121238  0.035191    0.022340
# 6484     rule -0.346755  0.026706    0.055905
# 6783     rule -0.040625  0.142857    0.014216
# 8510     rule -0.558627  0.048193    0.119643
# 9362     rule  0.020502  0.029412    0.003464
# 9494     rule -0.008856  0.048851    0.001909
# 9514     rule  0.086454  0.014793    0.010437
# 10988    rule -0.017055  0.011561    0.001823
# 11421    rule  0.359963  0.031884    0.063242
# 11569    rule  0.094449  0.017647    0.012436
# 11720    rule  0.226243  0.014706    0.027234
# 11728    rule -0.807257  0.138973    0.279245

# %%
# src に入れたい

class ArrangeRules:
    def __init__(self, rules_df, feature_names=None, conclusion_name=None):
        self.rules_df = rules_df
        self.feature_names = feature_names

        if not conclusion_name:
            self.conclusion_name = 'Outcome'
        else:
            self.conclusion_name = conclusion_name

        self.rules_extracted = None
        self.rules_additional = None
        self.KB = None

    def extract_rules_from_df(self):
        rules_list = self.rules_df['rule'].to_list()
        coef_list  = self.rules_df['coef'].to_list()

        rules_list = [rule.split(' ') for rule in rules_list]

        self.rules_extracted = []
        for rule, coef in zip(rules_list, coef_list):

            # '&' を目印にして複数のリストに分割する
            sublists = []
            current_sublist = []
            for item in rule:
                if item != '&':
                    current_sublist.append(item)
                else:
                    sublists.append(current_sublist)
                    current_sublist = []

            # ループ終了後に最後のサブリストを追加
            sublists.append(current_sublist)

            rule_new = []
            cnt = 0
            for sublist in sublists:
                if len(sublist) <= 1:
                    rule_new.append(sublist[0])
                else:
                    if sublist[1] in ['<', '<=']:
                        rule_new.append('¬')
                        rule_new.append(sublist[0])
                    else:
                        rule_new.append(sublist[0])
                
                cnt +=1
                if cnt < len(sublists):
                    rule_new.append('⊗')
                else:
                    rule_new.append('→')

                    # coef == 0 の rule は除外されているため
                    if coef > 0:
                        rule_new.append(self.conclusion_name)
                    elif coef < 0:
                        rule_new.append('¬')
                        rule_new.append(self.conclusion_name)

            self.rules_extracted.append(rule_new)

        return self.rules_extracted

    def generate_rules_from_df(self):
        if self.feature_names:
            tmp_dict = {}
            for item in self.feature_names:
                key, value = item.rsplit('_', 1)
                if key not in tmp_dict:
                    tmp_dict[key] = []

                tmp_dict[key].append(item)
            
            self.rules_additional = list(tmp_dict.values())
            self.rules_additional = [' ⊕ '.join(rule) for rule in self.rules_additional]
            self.rules_additional = [rule.split(' ') for rule in self.rules_additional]

            return self.rules_additional

        else:
            return []


    def construct_KB(self):
        rules_extracted = self.extract_rules_from_df()
        rules_additional = self.generate_rules_from_df()

        self.KB = rules_extracted + rules_additional
        return self.KB
    
    def save_KB_as_txt(self, file_name):
        if self.KB:
            rules = [' '.join(rule) for rule in self.KB]

        with open(file_name, 'w') as file:
            for item in rules:
                file.write("%s\n" % item)

# %%
rule_processor = ArrangeRules(rules_df, 
                              feature_names=feature_names, 
                              conclusion_name="Outcome")
KB = rule_processor.construct_KB()
rule_processor.save_KB_as_txt("./data/rules_2.txt")

# %%
for rule in KB:
    print(rule)
# Out:
# ['Pregnancies_Low', '→', '¬', 'Outcome']
# ['Pregnancies_High', '→', 'Outcome']
# ['Glucose_Low', '→', '¬', 'Outcome']
# ['Glucose_High', '→', 'Outcome']
# ['BMI_Low', '→', '¬', 'Outcome']
# ['BMI_Medium', '→', 'Outcome']
# ['DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['Age_Low', '→', '¬', 'Outcome']
# ['Age_Medium', '→', 'Outcome']
# ['¬', 'Pregnancies_Medium', '⊗', 'Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '⊗', 'BMI_Medium', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '⊗', 'Age_Medium', '⊗', 'BloodPressure_Medium', '⊗', '¬', 'BMI_Low', '⊗', 'Glucose_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'Pregnancies_High', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'BloodPressure_Medium', '⊗', '¬', 'BloodPressure_Low', '⊗', '¬', 'Age_Low', '⊗', '¬', 'SkinThickness_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'Glucose_Medium', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'SkinThickness_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'BloodPressure_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'BloodPressure_Low', '⊗', 'Pregnancies_Low', '⊗', 'SkinThickness_Medium', '→', '¬', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'DiabetesPedigreeFunction_High', '⊗', 'BloodPressure_High', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['BMI_Medium', '⊗', 'Glucose_High', '⊗', '¬', 'BloodPressure_Medium', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Glucose_Medium', '⊗', '¬', 'BloodPressure_Medium', '⊗', '¬', 'Pregnancies_Medium', '⊗', '¬', 'Age_Medium', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_Low', '⊗', 'Glucose_Medium', '⊗', 'BloodPressure_High', '⊗', 'Pregnancies_Medium', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BMI_Low', '⊗', 'Age_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', 'Pregnancies_Low', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', '¬', 'Glucose_Low', '⊗', 'BMI_Medium', '⊗', '¬', 'Pregnancies_High', '⊗', 'Glucose_Medium', '⊗', '¬', 'Pregnancies_Medium', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'SkinThickness_Low', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['Pregnancies_High', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'BloodPressure_High', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'Age_Low', '⊗', 'Pregnancies_High', '→', 'Outcome']
# ['¬', 'BMI_Medium', '⊗', 'BMI_High', '⊗', 'Age_Low', '⊗', '¬', 'SkinThickness_Low', '⊗', '¬', 'BloodPressure_High', '⊗', 'SkinThickness_High', '⊗', '¬', 'Glucose_Low', '⊗', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'BloodPressure_Medium', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', 'Age_Medium', '⊗', 'BloodPressure_Medium', '⊗', '¬', 'SkinThickness_Medium', '⊗', 'Glucose_Medium', '⊗', '¬', 'Pregnancies_High', '→', 'Outcome']
# ['BMI_High', '⊗', '¬', 'Pregnancies_Medium', '⊗', '¬', 'DiabetesPedigreeFunction_High', '⊗', '¬', 'Glucose_Low', '⊗', 'BloodPressure_High', '→', 'Outcome']
# ['¬', 'Age_Medium', '⊗', '¬', 'BMI_High', '⊗', '¬', 'DiabetesPedigreeFunction_High', '⊗', '¬', 'BloodPressure_Medium', '⊗', '¬', 'SkinThickness_Medium', '⊗', '¬', 'Age_High', '→', '¬', 'Outcome']
# ['Pregnancies_Low', '⊕', 'Pregnancies_Medium', '⊕', 'Pregnancies_High']
# ['Glucose_Low', '⊕', 'Glucose_Medium', '⊕', 'Glucose_High']
# ['BloodPressure_Low', '⊕', 'BloodPressure_Medium', '⊕', 'BloodPressure_High']
# ['SkinThickness_Low', '⊕', 'SkinThickness_Medium', '⊕', 'SkinThickness_High']
# ['BMI_Low', '⊕', 'BMI_Medium', '⊕', 'BMI_High']
# ['DiabetesPedigreeFunction_Low', '⊕', 'DiabetesPedigreeFunction_Medium', '⊕', 'DiabetesPedigreeFunction_High']
# ['Age_Low', '⊕', 'Age_Medium', '⊕', 'Age_High']

# %% [markdown]
# # max_iter=50 としたものも採用して比較してみる

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(max_rules=50,
                       rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)
display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(max_rules=50, random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=13,
#                                                         random_state=54))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7761194029850746
#
#
# Confusion Matrix:
#  [[73 17]
#  [13 31]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        90
#            1       0.65      0.70      0.67        44
#
#     accuracy                           0.78       134
#    macro avg       0.75      0.76      0.75       134
# weighted avg       0.78      0.78      0.78       134

# %%
rules_df = rf.get_rules(exclude_zero_coef=True)
rules_df
# Out:
#                                                                                              rule  \
# 1                                                                              Pregnancies_Medium
# 2                                                                                Pregnancies_High
# 3                                                                                     Glucose_Low
# 5                                                                                    Glucose_High
# 7                                                                            BloodPressure_Medium
# 8                                                                              BloodPressure_High
# 11                                                                             SkinThickness_High
# 12                                                                                        BMI_Low
# 13                                                                                     BMI_Medium
# 15                                                                   DiabetesPedigreeFunction_Low
# 17                                                                  DiabetesPedigreeFunction_High
# 21                                                                            Glucose_High <= 0.5
# 22                                                                             Glucose_High > 0.5
# 23                                   BMI_High <= 0.5 & Pregnancies_Low <= 0.5 & BMI_Medium <= 0.5
# 26                   BMI_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5 & Glucose_Low <= 0.5
# 29                                 BMI_High > 0.5 & Glucose_Low <= 0.5 & BloodPressure_High > 0.5
# 30                                                             BMI_High > 0.5 & Glucose_Low > 0.5
# 32                              Glucose_High <= 0.5 & Age_Medium <= 0.5 & BloodPressure_Low > 0.5
# 36                                                                  Age_Low > 0.5 & BMI_Low > 0.5
# 40                                                                                  BMI_Low > 0.5
# 42                                  Age_Low <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low > 0.5
# 43                                                       Age_Low <= 0.5 & SkinThickness_Low > 0.5
# 44                      Age_Low > 0.5 & DiabetesPedigreeFunction_Low <= 0.5 & Glucose_High <= 0.5
# 48                                                              Age_Low > 0.5 & Glucose_Low > 0.5
# 50                    BMI_Low <= 0.5 & DiabetesPedigreeFunction_Medium > 0.5 & Glucose_Low <= 0.5
# 52                                                                              Age_Medium <= 0.5
# 57                       BMI_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5
# 58                                                                BMI_High <= 0.5 & BMI_Low > 0.5
# 60  BMI_High > 0.5 & BloodPressure_High <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Low <= 0.5
# 63                                           Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5
# 65                                     Glucose_Low <= 0.5 & Age_Low > 0.5 & Glucose_Medium <= 0.5
# 67                                                                              Glucose_Low > 0.5
#
#       type      coef   support  importance
# 1   linear -0.481035  1.000000    0.207774
# 2   linear  0.136026  1.000000    0.040943
# 3   linear -0.187261  1.000000    0.076873
# 5   linear  0.181535  1.000000    0.071525
# 7   linear  0.124705  1.000000    0.059211
# 8   linear -0.205998  1.000000    0.077339
# 11  linear -0.186036  1.000000    0.053121
# 12  linear -0.091690  1.000000    0.043059
# 13  linear  0.174153  1.000000    0.086727
# 15  linear -0.367591  1.000000    0.176650
# 17  linear  0.281324  1.000000    0.079569
# 21    rule -0.206923  0.804094    0.082127
# 22    rule  1.024102  0.195906    0.406463
# 23    rule  0.636929  0.105422    0.195599
# 26    rule -0.962730  0.340361    0.456171
# 29    rule  0.889653  0.021084    0.127813
# 30    rule -0.595959  0.024096    0.091389
# 32    rule -0.232689  0.129909    0.078231
# 36    rule -0.281861  0.244957    0.121217
# 40    rule -0.582851  0.297059    0.266341
# 42    rule  0.079174  0.023256    0.011933
# 43    rule -0.378200  0.165698    0.140618
# 44    rule -0.101686  0.209302    0.041367
# 48    rule -1.069032  0.166667    0.398405
# 50    rule  0.460576  0.166154    0.171435
# 52    rule -0.030684  0.762463    0.013058
# 57    rule  0.129468  0.272455    0.057642
# 58    rule -0.163340  0.344311    0.077610
# 60    rule -0.996665  0.047904    0.212851
# 63    rule  0.720004  0.211144    0.293848
# 65    rule  0.257249  0.090909    0.073954
# 67    rule -0.986815  0.231672    0.416337

# %%
rule_processor = ArrangeRules(rules_df, 
                              feature_names=feature_names, 
                              conclusion_name="Outcome")
KB = rule_processor.construct_KB()
rule_processor.save_KB_as_txt("./data/rules_max_50.txt")

for rule in KB:
    print(rule)
# Out:
# ['Pregnancies_Medium', '→', '¬', 'Outcome']
# ['Pregnancies_High', '→', 'Outcome']
# ['Glucose_Low', '→', '¬', 'Outcome']
# ['Glucose_High', '→', 'Outcome']
# ['BloodPressure_Medium', '→', 'Outcome']
# ['BloodPressure_High', '→', '¬', 'Outcome']
# ['SkinThickness_High', '→', '¬', 'Outcome']
# ['BMI_Low', '→', '¬', 'Outcome']
# ['BMI_Medium', '→', 'Outcome']
# ['DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['DiabetesPedigreeFunction_High', '→', 'Outcome']
# ['¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['Glucose_High', '→', 'Outcome']
# ['¬', 'BMI_High', '⊗', '¬', 'Pregnancies_Low', '⊗', '¬', 'BMI_Medium', '→', 'Outcome']
# ['¬', 'BMI_High', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '⊗', '¬', 'Glucose_Low', '→', '¬', 'Outcome']
# ['BMI_High', '⊗', '¬', 'Glucose_Low', '⊗', 'BloodPressure_High', '→', 'Outcome']
# ['BMI_High', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Medium', '⊗', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['BMI_Low', '→', '¬', 'Outcome']
# ['¬', 'Age_Low', '⊗', '¬', 'SkinThickness_Low', '⊗', 'Glucose_Low', '→', 'Outcome']
# ['¬', 'Age_Low', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'Glucose_Low', '→', 'Outcome']
# ['¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_High', '⊗', '¬', 'BMI_Low', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '→', 'Outcome']
# ['¬', 'BMI_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['BMI_High', '⊗', '¬', 'BloodPressure_High', '⊗', 'Pregnancies_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Age_Low', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', 'Age_Low', '⊗', '¬', 'Glucose_Medium', '→', 'Outcome']
# ['Glucose_Low', '→', '¬', 'Outcome']
# ['Pregnancies_Low', '⊕', 'Pregnancies_Medium', '⊕', 'Pregnancies_High']
# ['Glucose_Low', '⊕', 'Glucose_Medium', '⊕', 'Glucose_High']
# ['BloodPressure_Low', '⊕', 'BloodPressure_Medium', '⊕', 'BloodPressure_High']
# ['SkinThickness_Low', '⊕', 'SkinThickness_Medium', '⊕', 'SkinThickness_High']
# ['BMI_Low', '⊕', 'BMI_Medium', '⊕', 'BMI_High']
# ['DiabetesPedigreeFunction_Low', '⊕', 'DiabetesPedigreeFunction_Medium', '⊕', 'DiabetesPedigreeFunction_High']
# ['Age_Low', '⊕', 'Age_Medium', '⊕', 'Age_High']
