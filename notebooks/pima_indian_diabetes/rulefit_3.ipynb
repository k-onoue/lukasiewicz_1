# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from rulefit import RuleFit

# %%
data_cleaned = pd.read_csv("./data/diabetes_cleaned.csv", index_col=0)
data_discretized = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

X_cleaned = data_cleaned.drop(["Outcome"], axis=1)
y_cleaned = data_cleaned["Outcome"]
X_discretized = data_discretized.drop(["Outcome"], axis=1)
y_discretized = data_discretized["Outcome"]


random_state = 42
test_size = 0.2
    
X1_train, X1_test, y1_train, y1_test = train_test_split(X_cleaned, y_cleaned, 
                                                        test_size=test_size, 
                                                        random_state=random_state)
X2_train, X2_test, y2_train, y2_test = train_test_split(X_discretized, y_discretized, 
                                                        test_size=test_size, 
                                                        random_state=random_state)

# %%
# Import the RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# Create and train the random forest model using the cleaned data
rf_model = RandomForestClassifier(random_state=random_state)
rf_model.fit(X1_train, y1_train)

# Make predictions using the trained model
y1_pred = rf_model.predict(X1_test)

# Calculate accuracy
accuracy = accuracy_score(y1_test, y1_pred)

# Generate confusion matrix
conf_matrix = confusion_matrix(y1_test, y1_pred)

# Generate classification report
class_report = classification_report(y1_test, y1_pred)

# Print the results
print("元データ（cleaning 済み）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# 元データ（cleaning 済み）
# ---------------------------
#
# Accuracy: 0.8059701492537313
#
#
# Confusion Matrix:
#  [[74 16]
#  [10 34]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85        90
#            1       0.68      0.77      0.72        44
#
#     accuracy                           0.81       134
#    macro avg       0.78      0.80      0.79       134
# weighted avg       0.81      0.81      0.81       134

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=random_state)
rf_model.fit(X2_train, y2_train)

y2_pred = rf_model.predict(X2_test)

accuracy = accuracy_score(y2_test, y2_pred)

conf_matrix = confusion_matrix(y2_test, y2_pred)

class_report = classification_report(y2_test, y2_pred)

print("離散データ")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# 離散データ
# ---------------------------
#
# Accuracy: 0.753731343283582
#
#
# Confusion Matrix:
#  [[72 18]
#  [15 29]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.80      0.81        90
#            1       0.62      0.66      0.64        44
#
#     accuracy                           0.75       134
#    macro avg       0.72      0.73      0.73       134
# weighted avg       0.76      0.75      0.76       134

# %% [markdown]
# # RuleFit

# %%
data_cleaned = pd.read_csv("./data/diabetes_cleaned.csv", index_col=0)
data_discretized = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

X_cleaned = data_cleaned.drop(["Outcome"], axis=1)
y_cleaned = data_cleaned["Outcome"]
X_discretized = data_discretized.drop(["Outcome"], axis=1)
y_discretized = data_discretized["Outcome"]


random_state = 42
test_size = 0.2
    
X1_train, X1_test, y1_train, y1_test = train_test_split(X_cleaned, y_cleaned, 
                                                        test_size=test_size, 
                                                        random_state=random_state)
X2_train, X2_test, y2_train, y2_test = train_test_split(X_discretized, y_discretized, 
                                                        test_size=test_size, 
                                                        random_state=random_state)

# %%
feature_names = data_cleaned.columns
feature_names
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
from rulefit import RuleFitClassifier

X1_train = np.array(X1_train)
y1_train = np.array(y1_train)
X1_test = np.array(X1_test)
y1_test = np.array(y1_test)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(rfmode=rfmode,
                       tree_generator=tree_generator,
                       random_state=random_state)
rf.fit(X1_train, y1_train, feature_names=feature_names)

display(rf)

y1_pred = rf.predict(X1_test)

# Calculate accuracy
accuracy = accuracy_score(y1_test, y1_pred)

# Generate confusion matrix
conf_matrix = confusion_matrix(y1_test, y1_pred)

# Generate classification report
class_report = classification_report(y1_test, y1_pred)

# Print the results
print("元データ（cleaning 済み）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=552,
#                                                         random_state=593))
# 元データ（cleaning 済み）
# ---------------------------
#
# Accuracy: 0.7164179104477612
#
#
# Confusion Matrix:
#  [[69 21]
#  [17 27]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.77      0.78        90
#            1       0.56      0.61      0.59        44
#
#     accuracy                           0.72       134
#    macro avg       0.68      0.69      0.69       134
# weighted avg       0.72      0.72      0.72       134

# %%
rules_1 = rf.get_rules()
rules_1.to_csv("./data/rulefit_original.csv")
display(rules_1)
# Out:
#                                                    rule    type      coef  \
# 0                                           Pregnancies  linear -0.002143
# 1                                               Glucose  linear  0.000164
# 2                                         BloodPressure  linear  0.000911
# 3                                         SkinThickness  linear -0.001175
# 4                                                   BMI  linear  0.001253
# ...                                                 ...     ...       ...
# 1479                  Glucose > 124.5 & Glucose > 180.5    rule  0.035398
# 1480  BMI > 27.84999942779541 & Pregnancies <= 6.5 &...    rule  0.746782
# 1481  BMI > 27.84999942779541 & Pregnancies <= 6.5 &...    rule -0.479987
# 1482  BMI > 27.84999942779541 & Pregnancies <= 6.5 &...    rule -0.230056
# 1483        BMI > 27.84999942779541 & Pregnancies > 6.5    rule  0.006112
#
#        support  importance
# 0     1.000000    0.006682
# 1     1.000000    0.004737
# 2     1.000000    0.009835
# 3     1.000000    0.017821
# 4     1.000000    0.007869
# ...        ...         ...
# 1479  0.047478    0.007528
# 1480  0.117647    0.240606
# 1481  0.367647    0.231433
# 1482  0.076471    0.061137
# 1483  0.155882    0.002217
#
# [1484 rows x 5 columns]

# %%
from itertools import compress
import re

def arrange_conditions(rules, feature_names, n_round=3):
    """
    ルールを整理する関数    
    """
    rule_output = []
    num = re.compile(r'[+-]?(?:\d+\.?\d*|\.\d+)')

    for rule in rules:    #個別の決定規則について
        conds = rule.split(' & ') #決定規則を個別の条件に分ける

        #まとめられる条件の整理
        for f in feature_names:
            f_index = [f in s for s in conds] #特定の特徴量が登場する要素番号の特定
            while sum(f_index) >= 2:    #決定規則内に同じ特徴量名が2度以上登場するとき（整理の余地があるとき）
                redundancy = list(compress(conds, f_index))
                le_index = ['<=' in s for s in redundancy]
                gt_index = ['>' in s for s in redundancy]

                if sum(le_index) >= 2:    #「<=」の条件が重複するとき
                    th = []
                    for cond in list(compress(redundancy, le_index)):
                        th.append(float(num.findall(cond)[0]))
                        conds.remove(cond)
                    min_th = min(th)
                    conds.insert(le_index[0], f+' <= '+str(min_th))
                if sum(gt_index) >= 2:    #「>」の条件が重複するとき
                    th = []
                    for cond in list(compress(redundancy, gt_index)):
                        th.append(float(num.findall(cond)[0]))
                        conds.remove(cond)
                    max_th = max(th)
                    conds.insert(gt_index[0], f+' > '+str(max_th))
                if sum(le_index) == 1 and sum(gt_index) == 1: #「<=」と「>」があるとき
                    le_cond = list(compress(redundancy, le_index))[0]
                    gt_cond = list(compress(redundancy, gt_index))[0]
                    min_th = float(num.findall(gt_cond)[0])
                    max_th = float(num.findall(le_cond)[0])
                    conds.remove(le_cond)
                    conds.remove(gt_cond)
                    conds.insert(min(le_index[0], gt_index[0]), str(min_th)+' < '+f+' <= '+str(max_th))

                f_index = [f in s for s in conds] #特徴量が登場する要素番号の更新

        #閾値の丸め
        for i,cond in enumerate(conds):
            elem = cond.split(' ')
            for j,s in enumerate(elem):
                try:
                    elem[j] = str(round(float(s),n_round))
                except:
                    pass                    
            conds[i] = ' '.join(elem)

        rule_output.append(' & '.join(conds))
    return rule_output

# # ルールを整理
# rules.rule = arrange_conditions(rules.rule, features, n_round=3)
# rules.head(10)

# %%
rules_1_arranged = arrange_conditions(rules_1.rule, feature_names, n_round=3)
display(rules_1_arranged)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'BMI <= 29.6',
#  'BMI > 29.6',
#  'BMI <= 27.45',
#  'BMI > 27.45 & Glucose <= 94.5 & Pregnancies <= 6.5',
#  '27.45 < BMI <= 31.1 & 94.5 < Glucose <= 157.5 & Pregnancies <= 6.5',
#  '31.1 < BMI <= 32.35 & 94.5 < Glucose <= 157.5 & Pregnancies <= 6.5',
#  '94.5 < Glucose <= 157.5 & BMI > 32.35 & Pregnancies <= 6.5 & DiabetesPedigreeFunction <= 0.219',
#  '94.5 < Glucose <= 157.5 & BMI > 32.35 & Pregnancies <= 6.5 & DiabetesPedigreeFunction > 0.219',
#  'BMI > 27.45 & Pregnancies <= 6.5 & Glucose > 157.5',
#  'BMI > 27.45 & Pregnancies > 6.5',
#  'Age <= 26.5 & Glucose <= 133.0',
#  'Age <= 26.5 & Glucose > 133.0 & Pregnancies <= 1.5',
#  'Age <= 26.5 & Glucose > 133.0 & Pregnancies > 1.5',
#  'Age > 26.5',
#  'BMI <= 30.05',
#  'BMI > 30.05 & Age <= 30.5',
#  'BMI > 30.05 & Age > 30.5',
#  'BMI > 30.05',
#  'Glucose <= 139.5',
#  'Glucose > 139.5',
#  'Age <= 28.5',
#  'Age > 28.5',
#  'BMI <= 30.05 & Glucose <= 161.5',
#  'BMI <= 30.05 & Glucose > 161.5',
#  'BMI > 30.05 & Glucose <= 137.5 & Age <= 28.5 & BloodPressure <= 53.0',
#  'BMI > 30.05 & Glucose <= 137.5 & Age <= 28.5 & BloodPressure > 53.0',
#  'BMI > 30.05 & Glucose <= 137.5 & Age > 28.5',
#  'BMI > 30.05 & Glucose > 137.5',
#  'Pregnancies <= 2.5',
#  'Pregnancies > 2.5 & Glucose <= 124.5',
#  'Pregnancies > 2.5 & Glucose > 124.5',
#  'Pregnancies <= 6.5 & BMI <= 29.85',
#  'Pregnancies <= 6.5 & BMI > 29.85 & Glucose <= 157.5',
#  'Pregnancies <= 6.5 & BMI > 29.85 & Glucose > 157.5',
#  'Pregnancies > 6.5',
#  'Glucose <= 144.5',
#  'Glucose > 144.5',
#  'Glucose <= 154.5 & Pregnancies <= 8.5 & Age <= 39.5 & SkinThickness <= 4.0',
#  '4.0 < SkinThickness <= 31.5 & Glucose <= 154.5 & Pregnancies <= 8.5 & Age <= 39.5',
#  'Glucose <= 154.5 & SkinThickness > 31.5 & Pregnancies <= 8.5 & Age <= 39.5 & BMI <= 44.55',
#  'Glucose <= 154.5 & SkinThickness > 31.5 & Pregnancies <= 8.5 & Age <= 39.5 & BMI > 44.55',
#  'Glucose <= 154.5 & Pregnancies <= 8.5 & Age > 39.5 & BMI <= 27.85',
#  '39.5 < Age <= 62.5 & Glucose <= 154.5 & Pregnancies <= 8.5 & BMI > 27.85',
#  'Glucose <= 154.5 & Age > 62.5 & Pregnancies <= 8.5 & BMI > 27.85',
#  'Glucose <= 154.5 & Pregnancies > 8.5',
#  'Glucose > 154.5',
#  'SkinThickness <= 31.5 & Glucose <= 122.5',
#  'SkinThickness <= 31.5 & Glucose > 122.5 & Age <= 24.5',
#  'SkinThickness <= 31.5 & Glucose > 122.5 & Age > 24.5 & BMI <= 30.05',
#  'SkinThickness <= 31.5 & Glucose > 122.5 & Age > 24.5 & BMI > 30.05',
#  'SkinThickness > 31.5',
#  'Glucose <= 159.5',
#  'Glucose > 159.5',
#  'Age <= 30.5',
#  'Age > 30.5',
#  'Glucose <= 122.5',
#  'Glucose > 122.5',
#  'Pregnancies <= 6.5',
#  'SkinThickness <= 32.5 & Age <= 30.5',
#  'SkinThickness <= 32.5 & Age > 30.5',
#  'SkinThickness > 32.5',
#  'Age > 28.5 & BMI <= 30.05',
#  'Age > 28.5 & BMI > 30.05',
#  'Age <= 28.5 & SkinThickness <= 34.5',
#  'Age <= 28.5 & SkinThickness > 34.5',
#  'DiabetesPedigreeFunction <= 0.533',
#  'DiabetesPedigreeFunction > 0.533',
#  'Age <= 27.5',
#  'Age > 27.5',
#  'Age <= 31.5',
#  'Age > 31.5',
#  'Pregnancies <= 6.5 & BMI <= 27.85',
#  'Pregnancies <= 6.5 & BMI > 27.85',
#  'BMI <= 28.85',
#  'BMI > 28.85 & DiabetesPedigreeFunction <= 0.512 & Glucose <= 158.5',
#  'BMI > 28.85 & DiabetesPedigreeFunction <= 0.512 & Glucose > 158.5',
#  'BMI > 28.85 & DiabetesPedigreeFunction > 0.512 & Pregnancies <= 6.5',
#  'BMI > 28.85 & DiabetesPedigreeFunction > 0.512 & Pregnancies > 6.5',
#  'Glucose <= 142.5',
#  'Glucose > 142.5',
#  'Glucose <= 154.5 & Age <= 28.5',
#  'Glucose <= 154.5 & Age > 28.5',
#  'BloodPressure <= 83.0 & Glucose <= 112.5',
#  'BloodPressure <= 83.0 & Glucose > 112.5',
#  'BloodPressure > 83.0',
#  'Glucose <= 129.5',
#  'Glucose > 129.5',
#  'Pregnancies <= 6.5 & Glucose <= 123.5',
#  'Pregnancies <= 6.5 & Glucose > 123.5',
#  'SkinThickness <= 33.5',
#  'SkinThickness > 33.5',
#  'DiabetesPedigreeFunction <= 0.537',
#  'DiabetesPedigreeFunction > 0.537',
#  'Glucose <= 143.5 & BMI <= 26.95',
#  'Glucose <= 143.5 & BMI > 26.95 & Age <= 30.5 & DiabetesPedigreeFunction <= 0.512',
#  'Glucose <= 143.5 & BMI > 26.95 & Age <= 30.5 & DiabetesPedigreeFunction > 0.512',
#  'BMI > 26.95 & Glucose <= 100.5 & Age > 30.5',
#  '100.5 < Glucose <= 143.5 & BMI > 26.95 & Age > 30.5',
#  'Glucose > 143.5 & DiabetesPedigreeFunction <= 0.3',
#  'Glucose > 143.5 & DiabetesPedigreeFunction > 0.3',
#  'Glucose <= 124.5 & Pregnancies <= 10.5 & Age <= 32.5',
#  'Glucose <= 124.5 & Pregnancies <= 10.5 & Age > 32.5',
#  'Glucose <= 124.5 & Pregnancies > 10.5',
#  'Glucose > 124.5 & Pregnancies <= 12.5 & BMI <= 30.0 & DiabetesPedigreeFunction <= 0.992',
#  'Glucose > 124.5 & Pregnancies <= 12.5 & BMI <= 30.0 & DiabetesPedigreeFunction > 0.992',
#  'Glucose > 124.5 & Pregnancies <= 12.5 & BMI > 30.0 & Age <= 28.5',
#  'Glucose > 124.5 & Pregnancies <= 12.5 & BMI > 30.0 & Age > 28.5',
#  'Glucose > 124.5 & Pregnancies > 12.5',
#  'Age <= 30.5 & Glucose <= 130.5',
#  'Age <= 30.5 & Glucose > 130.5',
#  'Age > 30.5 & DiabetesPedigreeFunction <= 0.769 & Glucose <= 158.5',
#  'Age > 30.5 & DiabetesPedigreeFunction <= 0.769 & Glucose > 158.5',
#  'Age > 30.5 & DiabetesPedigreeFunction > 0.769',
#  'Glucose <= 143.5',
#  'Glucose > 143.5',
#  'Glucose <= 101.5',
#  '101.5 < Glucose <= 144.5 & BMI <= 26.45',
#  '101.5 < Glucose <= 144.5 & BMI > 26.45',
#  'Pregnancies <= 6.5 & Glucose <= 161.5',
#  'Pregnancies <= 6.5 & Glucose > 161.5',
#  'Pregnancies <= 5.5',
#  'Pregnancies > 5.5',
#  'Age > 27.5 & Glucose <= 157.5',
#  'Age > 27.5 & Glucose > 157.5',
#  'BMI <= 29.65',
#  'BMI > 29.65',
#  'BMI <= 30.2 & Age <= 28.5',
#  'BMI <= 30.2 & Age > 28.5',
#  'BMI > 30.2 & Glucose <= 141.5 & Pregnancies <= 5.5',
#  'BMI > 30.2 & Glucose <= 141.5 & Pregnancies > 5.5 & DiabetesPedigreeFunction <= 0.276',
#  'BMI > 30.2 & Glucose <= 141.5 & Pregnancies > 5.5 & DiabetesPedigreeFunction > 0.276',
#  'BMI > 30.2 & Glucose > 141.5',
#  'SkinThickness <= 26.5 & Glucose <= 153.0',
#  'SkinThickness <= 26.5 & Glucose > 153.0',
#  'SkinThickness > 26.5 & BMI <= 30.85',
#  'SkinThickness > 26.5 & BMI > 30.85',
#  'Glucose <= 132.5',
#  'Glucose > 132.5',
#  'Age <= 30.5 & Glucose <= 159.5',
#  'Age <= 30.5 & Glucose > 159.5',
#  'BMI <= 27.35',
#  'BMI > 27.35 & Age <= 30.5',
#  'BMI > 27.35 & Age > 30.5',
#  'SkinThickness <= 31.5',
#  'BMI <= 30.2 & Glucose <= 145.5',
#  'BMI <= 30.2 & Glucose > 145.5',
#  'BMI > 30.2 & Glucose <= 141.5 & DiabetesPedigreeFunction <= 0.509 & SkinThickness <= 7.5',
#  'BMI > 30.2 & Glucose <= 141.5 & DiabetesPedigreeFunction <= 0.509 & SkinThickness > 7.5',
#  'BMI > 30.2 & Glucose <= 107.5 & DiabetesPedigreeFunction > 0.509 & Pregnancies <= 9.0',
#  'BMI > 30.2 & Glucose <= 107.5 & DiabetesPedigreeFunction > 0.509 & Pregnancies > 9.0',
#  '107.5 < Glucose <= 141.5 & BMI > 30.2 & DiabetesPedigreeFunction > 0.509',
#  'BloodPressure <= 69.0 & Age <= 35.5',
#  'BloodPressure <= 69.0 & Age > 35.5',
#  'BloodPressure > 69.0 & DiabetesPedigreeFunction <= 0.776',
#  'BloodPressure > 69.0 & DiabetesPedigreeFunction > 0.776',
#  'Glucose <= 133.5 & BMI <= 26.45',
#  'Glucose <= 133.5 & BMI > 26.45',
#  'Glucose > 133.5 & Age <= 40.5 & DiabetesPedigreeFunction <= 0.341',
#  '133.5 < Glucose <= 156.5 & Age <= 40.5 & DiabetesPedigreeFunction > 0.341',
#  'Glucose > 156.5 & Age <= 40.5 & DiabetesPedigreeFunction > 0.341',
#  '40.5 < Age <= 56.0 & Glucose > 133.5',
#  'Glucose > 133.5 & Age > 56.0',
#  'Glucose <= 123.5 & Age <= 28.5',
#  'Glucose <= 123.5 & Age > 28.5',
#  'Glucose > 123.5 & DiabetesPedigreeFunction <= 0.319 & BMI <= 30.1 & Age <= 41.0',
#  'Glucose > 123.5 & DiabetesPedigreeFunction <= 0.319 & BMI <= 30.1 & Age > 41.0',
#  'Glucose > 123.5 & DiabetesPedigreeFunction <= 0.319 & BMI > 30.1',
#  'Glucose > 123.5 & DiabetesPedigreeFunction > 0.319',
#  'BMI <= 28.25',
#  'BMI > 28.25 & DiabetesPedigreeFunction <= 0.204',
#  'BMI > 28.25 & DiabetesPedigreeFunction > 0.204',
#  'BMI <= 30.2 & Pregnancies <= 5.5',
#  'BMI <= 30.2 & Pregnancies > 5.5',
#  '30.2 < BMI <= 40.9 & Glucose <= 141.5 & Age <= 51.5',
#  'Glucose <= 141.5 & BMI > 40.9 & Age <= 51.5 & BloodPressure <= 82.0',
#  'Glucose <= 141.5 & BMI > 40.9 & Age <= 51.5 & BloodPressure > 82.0',
#  'BMI > 30.2 & Glucose <= 141.5 & Age > 51.5',
#  'Glucose <= 160.0',
#  'Glucose > 160.0',
#  'Age <= 26.5',
#  'DiabetesPedigreeFunction <= 0.333 & Glucose <= 159.5',
#  'DiabetesPedigreeFunction <= 0.333 & Glucose > 159.5',
#  'DiabetesPedigreeFunction > 0.333 & SkinThickness <= 30.5 & BMI <= 29.85',
#  'DiabetesPedigreeFunction > 0.333 & SkinThickness <= 30.5 & BMI > 29.85',
#  'DiabetesPedigreeFunction > 0.333 & SkinThickness > 30.5',
#  'Glucose <= 107.5',
#  '107.5 < Glucose <= 137.5',
#  'Glucose > 137.5',
#  'Glucose <= 141.5',
#  'Glucose > 141.5',
#  'SkinThickness <= 28.5 & Pregnancies <= 6.5',
#  'SkinThickness <= 28.5 & Pregnancies > 6.5',
#  'SkinThickness > 28.5 & Glucose <= 157.5 & Age <= 42.5',
#  'SkinThickness > 28.5 & Glucose <= 157.5 & Age > 42.5',
#  'SkinThickness > 28.5 & Glucose > 157.5',
#  'BMI <= 29.4',
#  'BMI > 29.4',
#  'Glucose <= 143.5 & Age <= 26.5',
#  '26.5 < Age <= 56.5 & Glucose <= 143.5',
#  'Glucose <= 143.5 & Age > 56.5',
#  'Glucose > 143.5 & BloodPressure <= 65.0 & DiabetesPedigreeFunction <= 0.311',
#  'Glucose > 143.5 & BloodPressure <= 65.0 & DiabetesPedigreeFunction > 0.311',
#  '143.5 < Glucose <= 162.5 & Age <= 28.5 & BloodPressure > 65.0',
#  '28.5 < Age <= 63.0 & 143.5 < Glucose <= 161.5 & BloodPressure > 65.0',
#  '28.5 < Age <= 63.0 & 161.5 < Glucose <= 162.5 & BloodPressure > 65.0',
#  'BloodPressure > 65.0 & Glucose > 162.5 & Age <= 63.0',
#  'Glucose > 143.5 & BloodPressure > 65.0 & Age > 63.0',
#  'Glucose <= 145.5 & Age <= 28.5',
#  'Glucose <= 145.5 & Age > 28.5 & DiabetesPedigreeFunction <= 0.71',
#  'Glucose <= 145.5 & Age > 28.5 & DiabetesPedigreeFunction > 0.71',
#  'Glucose > 145.5',
#  'Glucose <= 154.5',
#  'BMI <= 26.45',
#  'BMI > 26.45',
#  'Glucose <= 154.5 & BloodPressure <= 93.0 & Age <= 42.5 & BMI <= 45.35',
#  'Glucose <= 154.5 & BloodPressure <= 93.0 & Age <= 42.5 & BMI > 45.35',
#  'Glucose <= 154.5 & BloodPressure <= 93.0 & Age > 42.5',
#  'Glucose <= 154.5 & BloodPressure > 93.0',
#  'Glucose <= 154.5 & Age <= 28.5 & BMI <= 41.8',
#  'Glucose <= 154.5 & Age <= 28.5 & BMI > 41.8',
#  'Age <= 28.5 & SkinThickness <= 32.5',
#  'Age <= 28.5 & SkinThickness > 32.5',
#  'Age > 28.5 & BMI <= 29.65',
#  'Age > 28.5 & BMI > 29.65',
#  'Glucose <= 142.5 & BMI <= 27.35',
#  'Glucose <= 142.5 & BMI > 27.35',
#  'Glucose > 142.5 & BMI <= 30.25',
#  'Glucose > 142.5 & BMI > 30.25',
#  'BMI > 27.35',
#  'Age <= 27.5 & SkinThickness <= 28.5',
#  'Age <= 27.5 & SkinThickness > 28.5',
#  'Age > 27.5 & DiabetesPedigreeFunction <= 0.734 & Glucose <= 144.5',
#  'Age > 27.5 & DiabetesPedigreeFunction <= 0.734 & Glucose > 144.5',
#  'Age > 27.5 & DiabetesPedigreeFunction > 0.734',
#  'Glucose <= 114.5',
#  '114.5 < Glucose <= 154.5',
#  'Glucose > 154.5',
#  'Glucose <= 127.0',
#  'Glucose > 127.0',
#  'DiabetesPedigreeFunction <= 0.325',
#  'DiabetesPedigreeFunction > 0.325',
#  'Pregnancies <= 4.5',
#  'Pregnancies > 4.5',
#  'SkinThickness <= 32.5 & BMI <= 26.95',
#  'SkinThickness <= 32.5 & BMI > 26.95',
#  'SkinThickness > 32.5 & DiabetesPedigreeFunction <= 0.321',
#  'SkinThickness > 32.5 & DiabetesPedigreeFunction > 0.321',
#  'Age > 27.5 & DiabetesPedigreeFunction <= 0.514',
#  'Age > 27.5 & DiabetesPedigreeFunction > 0.514 & SkinThickness <= 27.0',
#  'Age > 27.5 & DiabetesPedigreeFunction > 0.514 & SkinThickness > 27.0',
#  'BMI <= 27.35 & Glucose <= 153.0',
#  'BMI <= 27.35 & Glucose > 153.0',
#  'BMI > 27.35 & Glucose <= 99.5',
#  'BMI > 27.35 & Glucose > 99.5 & DiabetesPedigreeFunction <= 0.22',
#  'BMI > 27.35 & Glucose > 99.5 & DiabetesPedigreeFunction > 0.22 & Age <= 26.5',
#  'BMI > 27.35 & Glucose > 99.5 & DiabetesPedigreeFunction > 0.22 & Age > 26.5',
#  'Age <= 33.5',
#  'Age > 33.5 & Glucose <= 163.5',
#  'Age > 33.5 & Glucose > 163.5',
#  'Glucose <= 123.5 & DiabetesPedigreeFunction <= 0.634 & Age <= 28.5',
#  'Glucose <= 123.5 & DiabetesPedigreeFunction <= 0.634 & Age > 28.5',
#  'Glucose <= 123.5 & DiabetesPedigreeFunction > 0.634',
#  'Glucose > 123.5',
#  'BMI <= 27.85',
#  'BMI > 27.85 & Glucose <= 108.0',
#  'BMI > 27.85 & Glucose > 108.0 & Age <= 39.5',
#  'BMI > 27.85 & Glucose > 108.0 & Age > 39.5',
#  'Age <= 28.5 & Glucose <= 130.5',
#  'Age <= 28.5 & Glucose > 130.5',
#  'Glucose > 132.5 & Pregnancies <= 7.5 & BMI <= 30.25',
#  'Glucose > 132.5 & Pregnancies <= 7.5 & BMI > 30.25',
#  'Glucose > 132.5 & Pregnancies > 7.5',
#  'Age <= 30.5 & Glucose <= 132.5',
#  'Age <= 30.5 & Glucose > 132.5',
#  'BMI <= 29.55',
#  '29.55 < BMI <= 31.8',
#  'BMI > 31.8',
#  'Glucose <= 133.5 & BMI <= 27.35',
#  'Glucose <= 133.5 & BMI > 27.35',
#  'Glucose > 133.5',
#  'BMI <= 29.85',
#  'BMI > 29.85',
#  'Age <= 24.5',
#  'Age > 24.5',
#  'Pregnancies <= 5.5 & Age <= 24.5',
#  'Pregnancies <= 5.5 & Age > 24.5',
#  'Pregnancies > 5.5 & BMI <= 27.45',
#  'Pregnancies > 5.5 & BMI > 27.45',
#  'Age <= 28.5 & Glucose <= 124.5',
#  'Age <= 28.5 & Glucose > 124.5',
#  'Pregnancies <= 6.5 & Glucose <= 111.5',
#  'Pregnancies > 6.5 & Glucose <= 111.5',
#  '111.5 < Glucose <= 159.5 & DiabetesPedigreeFunction <= 0.528 & BMI <= 27.9',
#  '111.5 < Glucose <= 159.5 & DiabetesPedigreeFunction <= 0.528 & BMI > 27.9',
#  '111.5 < Glucose <= 159.5 & DiabetesPedigreeFunction > 0.528',
#  'BMI > 28.85',
#  'BMI <= 28.8',
#  'BMI > 28.8 & Glucose <= 123.5',
#  'BMI > 28.8 & Glucose > 123.5',
#  'BMI > 27.35 & Age <= 27.5',
#  'BMI > 27.35 & Age > 27.5 & Glucose <= 107.5',
#  'BMI > 27.35 & Age > 27.5 & Glucose > 107.5',
#  'BMI > 27.85',
#  'Age > 28.5 & BMI <= 26.35',
#  'Age > 28.5 & BMI > 26.35 & Glucose <= 143.5 & Pregnancies <= 9.5 & BloodPressure <= 85.0',
#  'Age > 28.5 & BMI > 26.35 & Glucose <= 143.5 & Pregnancies <= 9.5 & BloodPressure > 85.0',
#  'Age > 28.5 & BMI > 26.35 & Glucose <= 143.5 & Pregnancies > 9.5',
#  'Age > 28.5 & BMI > 26.35 & Glucose > 143.5',
#  'SkinThickness <= 28.5 & Glucose <= 151.5 & BloodPressure <= 69.0',
#  'SkinThickness <= 28.5 & Glucose <= 151.5 & BloodPressure > 69.0',
#  'SkinThickness <= 28.5 & Glucose > 151.5',
#  'SkinThickness > 28.5 & BloodPressure <= 83.0',
#  'SkinThickness > 28.5 & BloodPressure > 83.0',
#  'Age <= 28.5 & BMI <= 41.8',
#  'Age <= 28.5 & BMI > 41.8 & Glucose <= 129.0',
#  'Age <= 28.5 & BMI > 41.8 & Glucose > 129.0',
#  'SkinThickness <= 28.5 & Age > 27.5',
#  'SkinThickness > 28.5 & Pregnancies <= 6.5 & DiabetesPedigreeFunction <= 0.192',
#  'SkinThickness > 28.5 & Pregnancies <= 6.5 & DiabetesPedigreeFunction > 0.192 & Glucose <= 156.5',
#  'SkinThickness > 28.5 & Pregnancies <= 6.5 & DiabetesPedigreeFunction > 0.192 & Glucose > 156.5',
#  'SkinThickness > 28.5 & Pregnancies > 6.5',
#  'Age <= 28.5 & DiabetesPedigreeFunction <= 0.509',
#  'Age <= 28.5 & DiabetesPedigreeFunction > 0.509 & Glucose <= 108.5',
#  'Age <= 28.5 & DiabetesPedigreeFunction > 0.509 & Glucose > 108.5',
#  'Age > 28.5 & Glucose <= 146.5',
#  'Age > 28.5 & Glucose > 146.5',
#  'Glucose <= 147.5',
#  'Glucose > 147.5',
#  'Pregnancies <= 2.5 & Age <= 32.5 & Glucose <= 117.5',
#  'Pregnancies <= 2.5 & Age <= 32.5 & Glucose > 117.5',
#  'Pregnancies <= 2.5 & Age > 32.5',
#  'Pregnancies > 2.5 & DiabetesPedigreeFunction <= 0.461',
#  'Pregnancies > 2.5 & DiabetesPedigreeFunction > 0.461 & Glucose <= 124.0',
#  'Pregnancies > 2.5 & DiabetesPedigreeFunction > 0.461 & Glucose > 124.0',
#  'Pregnancies > 6.5 & DiabetesPedigreeFunction <= 0.714',
#  'Pregnancies > 6.5 & DiabetesPedigreeFunction > 0.714',
#  'Age <= 26.5 & SkinThickness <= 29.0',
#  'Age <= 26.5 & SkinThickness > 29.0',
#  '26.5 < Age <= 39.5 & Glucose <= 154.5',
#  '26.5 < Age <= 39.5 & Glucose > 154.5',
#  'Age > 39.5',
#  'BMI > 27.35 & Glucose <= 100.5',
#  '100.5 < Glucose <= 166.0 & BMI > 27.35 & Pregnancies <= 5.5 & Age <= 30.5',
#  '100.5 < Glucose <= 166.0 & BMI > 27.35 & Pregnancies <= 5.5 & Age > 30.5',
#  '100.5 < Glucose <= 166.0 & BMI > 27.35 & Pregnancies > 5.5',
#  'BMI > 27.35 & Glucose > 166.0',
#  'DiabetesPedigreeFunction <= 0.327',
#  'DiabetesPedigreeFunction > 0.327',
#  'Pregnancies > 6.5 & DiabetesPedigreeFunction <= 0.514',
#  'Pregnancies > 6.5 & DiabetesPedigreeFunction > 0.514',
#  'Age > 28.5 & Glucose <= 100.5',
#  '100.5 < Glucose <= 167.5 & Age > 28.5 & Pregnancies <= 6.5',
#  'Age > 28.5 & Glucose > 167.5 & Pregnancies <= 6.5',
#  'Age > 28.5 & Glucose > 100.5 & Pregnancies > 6.5',
#  'Age <= 30.5 & BMI <= 30.85',
#  'Age <= 30.5 & BMI > 30.85',
#  'Age > 30.5 & Glucose <= 108.5',
#  'Age > 30.5 & Glucose > 108.5 & BMI <= 27.85',
#  'Age > 30.5 & Glucose > 108.5 & BMI > 27.85',
#  'Glucose <= 141.5 & BMI <= 28.8',
#  'Glucose <= 141.5 & BMI > 28.8',
#  'Pregnancies > 5.5 & Glucose <= 141.5',
#  'Pregnancies > 5.5 & Glucose > 141.5',
#  'Pregnancies <= 6.5 & DiabetesPedigreeFunction <= 0.344',
#  'Pregnancies <= 6.5 & DiabetesPedigreeFunction > 0.344 & Glucose <= 123.5',
#  '123.5 < Glucose <= 146.5 & DiabetesPedigreeFunction > 0.344 & Pregnancies <= 4.5',
#  'DiabetesPedigreeFunction > 0.344 & Glucose > 146.5 & Pregnancies <= 4.5',
#  '0.344 < DiabetesPedigreeFunction <= 0.39 & 4.5 < Pregnancies <= 6.5 & Glucose > 123.5',
#  '4.5 < Pregnancies <= 6.5 & DiabetesPedigreeFunction > 0.39 & Glucose > 123.5',
#  'DiabetesPedigreeFunction <= 0.509',
#  'DiabetesPedigreeFunction > 0.509',
#  'Age <= 30.5 & SkinThickness > 32.5',
#  'Age > 30.5 & Glucose <= 145.5',
#  'Age > 30.5 & Glucose > 145.5',
#  'Glucose <= 123.5',
#  'Age <= 42.5 & Glucose <= 103.5',
#  'Age > 42.5 & Glucose <= 103.5',
#  '103.5 < Glucose <= 133.5 & BMI <= 26.35',
#  '103.5 < Glucose <= 133.5 & BMI > 26.35 & DiabetesPedigreeFunction <= 0.904 & BloodPressure <= 54.0',
#  '103.5 < Glucose <= 133.5 & BMI > 26.35 & DiabetesPedigreeFunction <= 0.904 & BloodPressure > 54.0 & Age <= 28.5',
#  '103.5 < Glucose <= 133.5 & BMI > 26.35 & DiabetesPedigreeFunction <= 0.904 & BloodPressure > 54.0 & Age > 28.5',
#  '103.5 < Glucose <= 133.5 & BMI > 26.35 & DiabetesPedigreeFunction > 0.904',
#  'Glucose > 133.5 & DiabetesPedigreeFunction <= 0.705',
#  'Glucose > 133.5 & DiabetesPedigreeFunction > 0.705',
#  'Age <= 28.5 & BloodPressure <= 87.0 & BMI <= 30.95',
#  'Age <= 28.5 & BloodPressure <= 87.0 & BMI > 30.95',
#  'Age <= 28.5 & BloodPressure > 87.0 & Glucose <= 138.5',
#  'Age <= 28.5 & BloodPressure > 87.0 & Glucose > 138.5',
#  'Age > 28.5 & DiabetesPedigreeFunction <= 0.343',
#  'Age > 28.5 & DiabetesPedigreeFunction > 0.343 & BMI <= 27.15',
#  'Age > 28.5 & DiabetesPedigreeFunction > 0.343 & BMI > 27.15 & Glucose <= 96.5',
#  'Age > 28.5 & DiabetesPedigreeFunction > 0.343 & BMI > 27.15 & Glucose > 96.5',
#  'Age > 28.5 & BMI <= 29.85',
#  'Age > 28.5 & BMI > 29.85',
#  'Glucose > 127.0 & DiabetesPedigreeFunction <= 0.315',
#  'Glucose > 127.0 & DiabetesPedigreeFunction > 0.315',
#  'Pregnancies <= 6.5 & Glucose <= 112.5',
#  'Pregnancies <= 6.5 & Glucose > 112.5',
#  'Age <= 30.5 & SkinThickness <= 31.5 & Glucose <= 147.5',
#  'Age <= 30.5 & SkinThickness <= 31.5 & Glucose > 147.5',
#  'Age <= 30.5 & SkinThickness > 31.5 & Glucose <= 128.5',
#  'Age <= 30.5 & SkinThickness > 31.5 & Glucose > 128.5',
#  'Age > 30.5 & BMI <= 27.35',
#  'Glucose <= 124.5',
#  'Glucose > 124.5',
#  'BloodPressure <= 83.0',
#  '139.5 < Glucose <= 166.0',
#  'Glucose > 166.0',
#  'Pregnancies <= 5.5 & BMI <= 30.95',
#  'Pregnancies <= 5.5 & Glucose <= 101.0 & BMI > 30.95',
#  '101.0 < Glucose <= 157.5 & Pregnancies <= 5.5 & BMI > 30.95 & DiabetesPedigreeFunction <= 0.632',
#  '101.0 < Glucose <= 157.5 & Pregnancies <= 5.5 & BMI > 30.95 & DiabetesPedigreeFunction > 0.632',
#  'Pregnancies <= 5.5 & BMI > 30.95 & Glucose > 157.5',
#  'Pregnancies > 5.5 & Age <= 47.0 & Glucose <= 138.5 & SkinThickness <= 29.5',
#  'Pregnancies > 5.5 & Age <= 47.0 & Glucose <= 138.5 & SkinThickness > 29.5',
#  '47.0 < Age <= 59.5 & Pregnancies > 5.5 & Glucose <= 138.5',
#  'Pregnancies > 5.5 & Age <= 59.5 & Glucose > 138.5',
#  'Pregnancies > 5.5 & Age > 59.5',
#  'Glucose <= 143.5 & Age <= 30.5',
#  'Age > 30.5 & Glucose <= 89.5',
#  '89.5 < Glucose <= 143.5 & Age > 30.5',
#  '123.5 < Glucose <= 158.5 & DiabetesPedigreeFunction <= 0.319',
#  '123.5 < Glucose <= 158.5 & DiabetesPedigreeFunction > 0.319',
#  'Glucose > 158.5',
#  'BMI <= 30.25',
#  'BMI > 30.25',
#  'Age > 27.5 & Glucose <= 141.5 & DiabetesPedigreeFunction <= 0.252',
#  'Age > 27.5 & Glucose <= 141.5 & DiabetesPedigreeFunction > 0.252',
#  'Age > 27.5 & Glucose > 141.5',
#  'Glucose <= 106.5',
#  'Glucose > 106.5',
#  'Glucose <= 100.5',
#  '100.5 < Glucose <= 112.5',
#  'Glucose > 112.5 & BMI <= 30.05',
#  'Glucose > 112.5 & BMI > 30.05',
#  'Age <= 26.5 & Pregnancies <= 2.5',
#  'Age <= 26.5 & Pregnancies > 2.5 & SkinThickness <= 31.5',
#  'Age <= 26.5 & Pregnancies > 2.5 & SkinThickness > 31.5',
#  'DiabetesPedigreeFunction <= 0.718 & BMI <= 30.05',
#  'DiabetesPedigreeFunction <= 0.718 & BMI > 30.05',
#  'DiabetesPedigreeFunction > 0.718',
#  'BMI > 28.25 & DiabetesPedigreeFunction <= 0.319',
#  'BMI > 28.25 & DiabetesPedigreeFunction > 0.319 & Glucose <= 124.0 & Pregnancies <= 12.5',
#  'BMI > 28.25 & DiabetesPedigreeFunction > 0.319 & Glucose <= 124.0 & Pregnancies > 12.5',
#  'BMI > 28.25 & DiabetesPedigreeFunction > 0.319 & Glucose > 124.0',
#  'SkinThickness <= 31.5 & Age <= 30.5',
#  'SkinThickness <= 31.5 & Age > 30.5',
#  'Glucose <= 141.5 & BMI <= 27.35',
#  'Glucose <= 141.5 & BMI > 27.35 & DiabetesPedigreeFunction <= 0.533',
#  'Glucose <= 141.5 & BMI > 27.35 & DiabetesPedigreeFunction > 0.533',
#  'SkinThickness <= 32.5',
#  'DiabetesPedigreeFunction <= 0.71 & BMI <= 30.05',
#  'DiabetesPedigreeFunction <= 0.71 & BMI > 30.05',
#  'DiabetesPedigreeFunction > 0.71',
#  'BMI <= 26.55',
#  'BMI > 26.55 & Age <= 30.5 & DiabetesPedigreeFunction <= 0.344',
#  'BMI > 26.55 & Age <= 30.5 & DiabetesPedigreeFunction > 0.344',
#  'BMI > 26.55 & Age > 30.5',
#  'DiabetesPedigreeFunction <= 0.592',
#  'DiabetesPedigreeFunction > 0.592',
#  'DiabetesPedigreeFunction <= 0.238 & Glucose <= 159.0',
#  'DiabetesPedigreeFunction <= 0.238 & Glucose > 159.0',
#  'DiabetesPedigreeFunction > 0.238 & Glucose <= 129.5',
#  'DiabetesPedigreeFunction > 0.238 & Glucose > 129.5',
#  'DiabetesPedigreeFunction <= 0.499',
#  'DiabetesPedigreeFunction > 0.499',
#  'Age <= 30.5 & Pregnancies <= 2.5',
#  '2.5 < Pregnancies <= 6.5 & Age <= 30.5',
#  'Pregnancies <= 6.5 & Age > 30.5',
#  'Pregnancies > 6.5 & BMI <= 24.7',
#  'Pregnancies > 6.5 & BMI > 24.7 & Glucose <= 102.0',
#  'Pregnancies > 6.5 & BMI > 24.7 & Glucose > 102.0 & Age <= 58.0',
#  'Pregnancies > 6.5 & BMI > 24.7 & Glucose > 102.0 & Age > 58.0',
#  'Glucose <= 111.5',
#  'Glucose > 111.5',
#  '28.5 < Age <= 40.5 & Glucose <= 154.5 & BloodPressure <= 64.5',
#  '28.5 < Age <= 40.5 & Glucose <= 154.5 & BloodPressure > 64.5',
#  '40.5 < Age <= 54.0 & Glucose <= 101.0',
#  '40.5 < Age <= 54.0 & 101.0 < Glucose <= 154.5',
#  'Glucose <= 154.5 & Age > 54.0',
#  'SkinThickness <= 29.5 & DiabetesPedigreeFunction <= 0.348',
#  '0.348 < DiabetesPedigreeFunction <= 0.72 & SkinThickness <= 8.5 & Glucose <= 133.5',
#  'SkinThickness <= 8.5 & DiabetesPedigreeFunction > 0.72 & Glucose <= 133.5',
#  'DiabetesPedigreeFunction > 0.348 & SkinThickness <= 8.5 & Glucose > 133.5',
#  '8.5 < SkinThickness <= 29.5 & DiabetesPedigreeFunction > 0.348',
#  'SkinThickness > 29.5',
#  'SkinThickness <= 31.5 & BMI <= 29.85',
#  'SkinThickness <= 31.5 & BMI > 29.85 & Age <= 26.5',
#  'SkinThickness <= 31.5 & BMI > 29.85 & Age > 26.5',
#  'Age <= 30.5 & BMI > 30.85 & Glucose <= 133.5',
#  'Age <= 30.5 & BMI > 30.85 & Glucose > 133.5',
#  'Age > 30.5 & BloodPressure <= 101.0',
#  'Age > 30.5 & BloodPressure > 101.0',
#  'Age <= 35.5 & DiabetesPedigreeFunction <= 0.327',
#  'Age <= 35.5 & DiabetesPedigreeFunction > 0.327',
#  'Age > 35.5',
#  'Age <= 28.5 & SkinThickness <= 28.5',
#  'Age <= 28.5 & BloodPressure <= 69.0 & SkinThickness > 28.5 & DiabetesPedigreeFunction <= 0.612',
#  '69.0 < BloodPressure <= 83.0 & Age <= 28.5 & SkinThickness > 28.5 & DiabetesPedigreeFunction <= 0.612',
#  'Age <= 28.5 & SkinThickness > 28.5 & DiabetesPedigreeFunction <= 0.612 & BloodPressure > 83.0',
#  'Age <= 28.5 & SkinThickness > 28.5 & DiabetesPedigreeFunction > 0.612',
#  'Pregnancies <= 6.5 & Glucose <= 123.5 & DiabetesPedigreeFunction <= 0.504',
#  'Pregnancies <= 6.5 & Glucose <= 123.5 & DiabetesPedigreeFunction > 0.504 & SkinThickness <= 28.5',
#  'Pregnancies <= 6.5 & Glucose <= 123.5 & DiabetesPedigreeFunction > 0.504 & SkinThickness > 28.5',
#  'Pregnancies <= 6.5 & Glucose > 123.5 & BMI <= 29.95',
#  'Pregnancies <= 6.5 & Glucose > 123.5 & BMI > 29.95',
#  'Glucose <= 104.5',
#  'Glucose > 104.5 & Pregnancies <= 2.5 & DiabetesPedigreeFunction <= 0.327',
#  'Glucose > 104.5 & Pregnancies <= 2.5 & DiabetesPedigreeFunction > 0.327',
#  'Glucose > 104.5 & Pregnancies > 2.5',
#  'BMI <= 30.2',
#  'BMI > 30.2',
#  'Glucose <= 137.5',
#  'DiabetesPedigreeFunction <= 0.689 & Glucose <= 144.5',
#  'DiabetesPedigreeFunction <= 0.689 & Glucose > 144.5',
#  'DiabetesPedigreeFunction > 0.689 & Glucose <= 144.0',
#  'DiabetesPedigreeFunction > 0.689 & Glucose > 144.0',
#  'DiabetesPedigreeFunction <= 0.501 & Age <= 32.5',
#  'DiabetesPedigreeFunction <= 0.501 & Age > 32.5 & BloodPressure <= 59.0',
#  'DiabetesPedigreeFunction <= 0.501 & Glucose <= 107.0 & Age > 32.5 & BloodPressure > 59.0',
#  '107.0 < Glucose <= 155.0 & DiabetesPedigreeFunction <= 0.501 & Age > 32.5 & BloodPressure > 59.0',
#  'DiabetesPedigreeFunction <= 0.501 & Age > 32.5 & BloodPressure > 59.0 & Glucose > 155.0',
#  'DiabetesPedigreeFunction > 0.501',
#  'Age <= 27.5 & DiabetesPedigreeFunction <= 0.418 & Glucose <= 138.0',
#  'Age <= 27.5 & DiabetesPedigreeFunction <= 0.418 & Glucose > 138.0',
#  'Age <= 27.5 & DiabetesPedigreeFunction > 0.418',
#  'Age > 27.5 & Pregnancies <= 6.5 & Glucose <= 129.5',
#  'Age > 27.5 & Pregnancies <= 6.5 & Glucose > 129.5',
#  'Age > 27.5 & Pregnancies > 6.5',
#  'Pregnancies <= 6.5 & Age <= 43.5 & BMI <= 29.8',
#  'Pregnancies <= 6.5 & Age <= 43.5 & BMI > 29.8',
#  'Pregnancies <= 6.5 & Age > 43.5',
#  'Pregnancies > 6.5 & BMI <= 28.9',
#  'Pregnancies > 6.5 & BMI > 28.9',
#  'SkinThickness <= 33.5 & DiabetesPedigreeFunction <= 1.141',
#  'SkinThickness <= 33.5 & DiabetesPedigreeFunction > 1.141',
#  'SkinThickness > 33.5 & DiabetesPedigreeFunction <= 0.219',
#  'SkinThickness > 33.5 & DiabetesPedigreeFunction > 0.219',
#  'BMI <= 26.95 & Glucose <= 153.0',
#  'BMI <= 26.95 & Glucose > 153.0',
#  'BMI > 26.95 & Glucose <= 133.5 & Age <= 28.5',
#  'BMI > 26.95 & Glucose <= 89.5 & Age > 28.5',
#  '89.5 < Glucose <= 133.5 & BMI > 26.95 & Age > 28.5',
#  'BMI > 26.95 & Glucose > 133.5',
#  'BMI > 26.45 & DiabetesPedigreeFunction <= 0.319',
#  'BMI > 26.45 & DiabetesPedigreeFunction > 0.319',
#  'BMI > 29.55',
#  'Glucose <= 143.5 & DiabetesPedigreeFunction <= 0.219',
#  'Glucose <= 143.5 & DiabetesPedigreeFunction > 0.219 & BMI <= 27.55',
#  'Glucose <= 143.5 & DiabetesPedigreeFunction > 0.219 & BMI > 27.55',
#  'SkinThickness <= 28.5',
#  'SkinThickness > 28.5',
#  'BMI > 27.35 & Age > 27.5',
#  'Glucose <= 146.5 & Age <= 34.5',
#  'Glucose <= 146.5 & Age > 34.5',
#  '146.5 < Glucose <= 166.5',
#  'Glucose > 166.5',
#  'BMI > 29.55 & DiabetesPedigreeFunction <= 0.74 & Glucose <= 127.0',
#  'BMI > 29.55 & DiabetesPedigreeFunction <= 0.74 & Glucose > 127.0',
#  'BMI > 29.55 & DiabetesPedigreeFunction > 0.74',
#  'Pregnancies > 5.5 & DiabetesPedigreeFunction <= 0.325',
#  'Pregnancies > 5.5 & DiabetesPedigreeFunction > 0.325 & Glucose <= 123.5',
#  'Pregnancies > 5.5 & DiabetesPedigreeFunction > 0.325 & Glucose > 123.5',
#  'Glucose <= 130.5 & SkinThickness <= 34.5',
#  'Glucose <= 130.5 & SkinThickness > 34.5',
#  'Glucose > 130.5 & Age <= 59.5',
#  'Glucose > 130.5 & Age > 59.5',
#  'Pregnancies <= 6.5 & BMI <= 28.8',
#  'Pregnancies <= 6.5 & BMI > 28.8',
#  'Pregnancies > 6.5 & Glucose <= 142.5',
#  'Pregnancies > 6.5 & Glucose > 142.5',
#  'BMI > 28.85 & Age <= 30.5',
#  'BMI > 28.85 & Age > 30.5 & DiabetesPedigreeFunction <= 0.326',
#  'BMI > 28.85 & Age > 30.5 & DiabetesPedigreeFunction > 0.326 & Glucose <= 96.5',
#  'BMI > 28.85 & Age > 30.5 & DiabetesPedigreeFunction > 0.326 & Glucose > 96.5',
#  'Pregnancies <= 6.5 & Age <= 30.5',
#  'Pregnancies > 6.5 & Age <= 56.5',
#  'Pregnancies > 6.5 & Age > 56.5',
#  'Glucose > 137.5 & BMI <= 30.2',
#  'Glucose > 137.5 & BMI > 30.2',
#  'DiabetesPedigreeFunction <= 0.729',
#  'DiabetesPedigreeFunction > 0.729',
#  '27.35 < BMI <= 27.55 & DiabetesPedigreeFunction <= 0.326',
#  'DiabetesPedigreeFunction <= 0.326 & BMI > 27.55 & Pregnancies <= 6.5 & Glucose <= 154.5',
#  'DiabetesPedigreeFunction <= 0.326 & BMI > 27.55 & Pregnancies <= 6.5 & Glucose > 154.5',
#  '6.5 < Pregnancies <= 9.5 & BMI > 27.55 & DiabetesPedigreeFunction <= 0.326',
#  'Pregnancies > 9.5 & BMI > 27.55 & DiabetesPedigreeFunction <= 0.326',
#  'BMI > 27.35 & DiabetesPedigreeFunction > 0.326 & BloodPressure <= 57.0',
#  'BMI > 27.35 & DiabetesPedigreeFunction > 0.326 & BloodPressure > 57.0 & Age <= 39.5',
#  'BMI > 27.35 & DiabetesPedigreeFunction > 0.326 & BloodPressure > 57.0 & Age > 39.5',
#  'SkinThickness <= 29.5 & Age <= 26.5',
#  'SkinThickness <= 29.5 & Age > 26.5',
#  '29.5 < SkinThickness <= 49.5 & DiabetesPedigreeFunction <= 0.499 & Glucose <= 127.5',
#  '29.5 < SkinThickness <= 49.5 & DiabetesPedigreeFunction <= 0.499 & Glucose > 127.5',
#  '29.5 < SkinThickness <= 49.5 & DiabetesPedigreeFunction > 0.499',
#  'SkinThickness > 49.5',
#  'Glucose <= 137.5 & BMI <= 26.45',
#  'Glucose <= 137.5 & BMI > 26.45',
#  'DiabetesPedigreeFunction <= 0.5 & Pregnancies <= 6.5',
#  'DiabetesPedigreeFunction <= 0.5 & Pregnancies > 6.5',
#  'DiabetesPedigreeFunction > 0.5 & Pregnancies <= 2.5 & BMI <= 31.4',
#  'DiabetesPedigreeFunction > 0.5 & Pregnancies <= 2.5 & BMI > 31.4',
#  'DiabetesPedigreeFunction > 0.5 & Pregnancies > 2.5',
#  'Pregnancies <= 5.5 & Glucose <= 157.5',
#  'Pregnancies <= 5.5 & Glucose > 157.5',
#  'BMI > 29.4 & Pregnancies <= 6.5',
#  'BMI > 29.4 & Pregnancies > 6.5',
#  'BMI > 26.45 & DiabetesPedigreeFunction <= 0.5',
#  'BMI > 26.45 & DiabetesPedigreeFunction > 0.5',
#  'BMI <= 30.05 & Pregnancies <= 5.5',
#  'BMI <= 30.05 & Pregnancies > 5.5',
#  'BMI > 30.05 & BloodPressure <= 89.0',
#  'BMI > 30.05 & BloodPressure > 89.0',
#  'BloodPressure <= 73.0',
#  'BloodPressure > 73.0',
#  'Pregnancies <= 6.5 & BMI <= 28.85',
#  'Pregnancies <= 6.5 & BMI > 28.85 & DiabetesPedigreeFunction <= 0.326',
#  'Pregnancies <= 6.5 & BMI > 28.85 & DiabetesPedigreeFunction > 0.326',
#  'DiabetesPedigreeFunction <= 0.999',
#  'DiabetesPedigreeFunction > 0.999',
#  'DiabetesPedigreeFunction <= 0.501 & Glucose <= 141.5 & Age <= 28.5',
#  'DiabetesPedigreeFunction <= 0.501 & Glucose <= 141.5 & Age > 28.5',
#  'DiabetesPedigreeFunction <= 0.501 & Glucose > 141.5',
#  'DiabetesPedigreeFunction > 0.501 & Pregnancies <= 3.5 & Glucose <= 115.5',
#  'DiabetesPedigreeFunction > 0.501 & Pregnancies <= 3.5 & Glucose > 115.5 & BMI <= 30.85',
#  'DiabetesPedigreeFunction > 0.501 & Pregnancies <= 3.5 & Glucose > 115.5 & BMI > 30.85',
#  'DiabetesPedigreeFunction > 0.501 & Pregnancies > 3.5',
#  'BloodPressure <= 61.5',
#  'BloodPressure > 61.5 & BMI <= 27.45',
#  'BloodPressure > 61.5 & Glucose <= 92.5 & BMI > 27.45 & Pregnancies <= 6.5',
#  '92.5 < Glucose <= 129.5 & BloodPressure > 61.5 & BMI > 27.45 & Pregnancies <= 6.5',
#  'BloodPressure > 61.5 & BMI > 27.45 & Pregnancies <= 6.5 & Glucose > 129.5',
#  'BloodPressure > 61.5 & BMI > 27.45 & Pregnancies > 6.5 & Age <= 49.5',
#  'BloodPressure > 61.5 & BMI > 27.45 & Pregnancies > 6.5 & Age > 49.5 & SkinThickness <= 10.5',
#  'BloodPressure > 61.5 & BMI > 27.45 & Pregnancies > 6.5 & Age > 49.5 & SkinThickness > 10.5',
#  'Pregnancies <= 6.5 & Glucose > 123.5 & DiabetesPedigreeFunction <= 0.314',
#  'Pregnancies <= 6.5 & Glucose > 123.5 & DiabetesPedigreeFunction > 0.314',
#  'Pregnancies > 6.5 & BMI <= 29.45 & Age <= 32.5',
#  'Pregnancies > 6.5 & BMI <= 29.45 & Age > 32.5',
#  'Pregnancies > 6.5 & BMI > 29.45',
#  'DiabetesPedigreeFunction <= 0.325',
#  'DiabetesPedigreeFunction > 0.325',
#  'Glucose <= 101.5',
#  'Glucose > 101.5 & BMI <= 26.45',
#  'Glucose > 101.5 & BMI > 26.45 & Age <= 30.5',
#  '30.5 < Age <= 54.5 & Glucose > 101.5 & BMI > 26.45 & Pregnancies <= 12.5',
#  '30.5 < Age <= 54.5 & Glucose > 101.5 & BMI > 26.45 & Pregnancies > 12.5',
#  'Glucose > 101.5 & Age > 54.5 & BMI > 26.45 & DiabetesPedigreeFunction <= 0.532',
#  'Glucose > 101.5 & Age > 54.5 & BMI > 26.45 & DiabetesPedigreeFunction > 0.532',
#  'Glucose > 137.5 & BMI <= 30.0',
#  'Glucose > 137.5 & BMI > 30.0',
#  'BMI > 29.65 & Age <= 34.5 & Glucose <= 130.0 & BloodPressure <= 53.0',
#  'BMI > 29.65 & Age <= 34.5 & Glucose <= 130.0 & BloodPressure > 53.0',
#  'BMI > 29.65 & Age <= 34.5 & Glucose > 130.0 & DiabetesPedigreeFunction <= 0.196',
#  'BMI > 29.65 & Age <= 34.5 & Glucose > 130.0 & DiabetesPedigreeFunction > 0.196 & BloodPressure <= 77.0',
#  'BMI > 29.65 & Age <= 34.5 & Glucose > 130.0 & DiabetesPedigreeFunction > 0.196 & BloodPressure > 77.0',
#  'BMI > 29.65 & Age > 34.5 & Glucose <= 100.5',
#  'BMI > 29.65 & Age > 34.5 & Glucose > 100.5',
#  'Glucose <= 122.5 & BMI <= 29.55',
#  'BMI > 29.55 & Glucose <= 100.5',
#  '100.5 < Glucose <= 104.5 & BMI > 29.55 & Pregnancies <= 6.5',
#  '29.55 < BMI <= 45.45 & 104.5 < Glucose <= 122.5 & Pregnancies <= 6.5',
#  '104.5 < Glucose <= 122.5 & BMI > 45.45 & Pregnancies <= 6.5',
#  '100.5 < Glucose <= 122.5 & BMI > 29.55 & Pregnancies > 6.5',
#  'Glucose > 122.5 & BMI <= 30.25',
#  'Glucose > 122.5 & BMI > 30.25',
#  'BMI <= 27.35 & Glucose <= 152.5',
#  'BMI <= 27.35 & Glucose > 152.5',
#  'BMI > 27.35 & Glucose <= 99.5',
#  '99.5 < Glucose <= 130.0 & BMI > 27.35',
#  'BMI > 27.35 & Glucose > 130.0',
#  'BloodPressure <= 65.5',
#  'BloodPressure > 65.5',
#  'BMI > 29.65 & DiabetesPedigreeFunction <= 0.332',
#  '0.332 < DiabetesPedigreeFunction <= 0.88 & BMI > 29.65 & Glucose <= 124.0',
#  '0.332 < DiabetesPedigreeFunction <= 0.88 & BMI > 29.65 & Glucose > 124.0',
#  'BMI > 29.65 & DiabetesPedigreeFunction > 0.88',
#  'BMI <= 29.85 & Age <= 41.5',
#  'BMI <= 29.85 & Age > 41.5',
#  'BMI > 29.85 & Age <= 26.5',
#  'BMI > 29.85 & Age > 26.5 & Glucose <= 96.0',
#  '96.0 < Glucose <= 125.5 & BMI > 29.85 & Age > 26.5 & BloodPressure <= 79.0',
#  'BMI > 29.85 & Glucose > 125.5 & Age > 26.5 & BloodPressure <= 79.0',
#  'BMI > 29.85 & Age > 26.5 & Glucose > 96.0 & BloodPressure > 79.0 & DiabetesPedigreeFunction <= 0.352',
#  'BMI > 29.85 & Age > 26.5 & Glucose > 96.0 & BloodPressure > 79.0 & DiabetesPedigreeFunction > 0.352',
#  'Glucose <= 100.5',
#  '100.5 < Glucose <= 139.5',
#  'Glucose > 139.5 & Pregnancies <= 6.5',
#  'Glucose > 139.5 & Pregnancies > 6.5',
#  'BMI > 27.35 & Age <= 24.5',
#  'BMI > 27.35 & Age > 24.5',
#  'Glucose <= 143.5 & BMI <= 27.35',
#  'Glucose <= 143.5 & BMI > 27.35',
#  'Age <= 28.5 & Glucose <= 143.5 & BMI <= 31.2',
#  'Age <= 28.5 & Glucose <= 143.5 & BMI > 31.2 & DiabetesPedigreeFunction <= 0.501',
#  '0.501 < DiabetesPedigreeFunction <= 0.528 & Age <= 28.5 & Glucose <= 106.5 & BMI > 31.2',
#  'Age <= 28.5 & DiabetesPedigreeFunction > 0.528 & Glucose <= 106.5 & BMI > 31.2',
#  '106.5 < Glucose <= 143.5 & Age <= 28.5 & BMI > 31.2 & DiabetesPedigreeFunction > 0.501',
#  'Age <= 28.5 & Glucose > 143.5',
#  '28.5 < Age <= 61.5 & Pregnancies <= 1.5',
#  '28.5 < Age <= 61.5 & Pregnancies > 1.5 & Glucose <= 157.5 & BMI <= 26.25',
#  '28.5 < Age <= 61.5 & Pregnancies > 1.5 & Glucose <= 157.5 & BMI > 26.25',
#  '28.5 < Age <= 61.5 & Pregnancies > 1.5 & Glucose > 157.5',
#  'Age > 61.5',
#  'Glucose <= 111.5',
#  '111.5 < Glucose <= 154.5',
#  'Age <= 28.5 & SkinThickness > 34.5 & BloodPressure <= 69.0',
#  'Age <= 28.5 & SkinThickness > 34.5 & BloodPressure > 69.0',
#  'Age > 28.5 & Pregnancies <= 11.5 & BMI <= 26.95',
#  'Age > 28.5 & Pregnancies <= 11.5 & BMI > 26.95',
#  'Age > 28.5 & Pregnancies > 11.5',
#  'DiabetesPedigreeFunction <= 0.699 & Pregnancies <= 6.5 & Glucose <= 120.5',
#  'DiabetesPedigreeFunction <= 0.699 & Pregnancies <= 6.5 & Glucose > 120.5',
#  'DiabetesPedigreeFunction <= 0.699 & Pregnancies > 6.5',
#  'DiabetesPedigreeFunction > 0.699',
#  'DiabetesPedigreeFunction <= 0.689 & Pregnancies <= 6.5 & Glucose <= 123.5',
#  'DiabetesPedigreeFunction <= 0.689 & Pregnancies <= 6.5 & Glucose > 123.5',
#  'DiabetesPedigreeFunction <= 0.689 & Pregnancies > 6.5',
#  'DiabetesPedigreeFunction > 0.689',
#  'Age <= 28.5 & Glucose <= 154.5 & BMI <= 45.4',
#  'Age <= 28.5 & Glucose <= 154.5 & BMI > 45.4',
#  'Age <= 28.5 & Glucose > 154.5',
#  'BMI <= 29.35',
#  'BMI > 29.35 & Glucose <= 99.5',
#  '29.35 < BMI <= 41.5 & 99.5 < Glucose <= 139.5',
#  '99.5 < Glucose <= 139.5 & BMI > 41.5',
#  'BMI > 29.35 & Glucose > 139.5',
#  'Glucose <= 157.5 & DiabetesPedigreeFunction <= 0.893',
#  'Glucose <= 157.5 & DiabetesPedigreeFunction > 0.893 & Age <= 44.0 & Pregnancies <= 3.0',
#  'Glucose <= 157.5 & DiabetesPedigreeFunction > 0.893 & Age <= 44.0 & Pregnancies > 3.0',
#  'Glucose <= 157.5 & DiabetesPedigreeFunction > 0.893 & Age > 44.0',
#  'Glucose > 157.5',
#  'Glucose <= 103.5',
#  '103.5 < Glucose <= 133.5 & Age <= 28.5',
#  '103.5 < Glucose <= 133.5 & Age > 28.5 & DiabetesPedigreeFunction <= 0.203',
#  '103.5 < Glucose <= 133.5 & Age > 28.5 & DiabetesPedigreeFunction > 0.203',
#  '133.5 < Glucose <= 159.5',
#  'Glucose > 159.5',
#  'Age <= 27.5 & BMI <= 34.25',
#  'Age <= 27.5 & BMI > 34.25 & BloodPressure <= 53.0',
#  'Age <= 27.5 & BMI > 34.25 & BloodPressure > 53.0',
#  'Age > 27.5 & Glucose <= 114.5',
#  '27.5 < Age <= 60.5 & Glucose > 114.5',
#  'Glucose > 114.5 & Age > 60.5',
#  'Glucose <= 139.5 & BMI <= 30.45',
#  'Glucose <= 139.5 & BMI > 30.45',
#  'Pregnancies <= 6.5 & Glucose <= 114.5',
#  'Pregnancies <= 6.5 & Glucose > 114.5',
#  'DiabetesPedigreeFunction <= 0.739 & BMI <= 26.45',
#  'DiabetesPedigreeFunction <= 0.739 & BMI > 26.45 & Age <= 30.5',
#  'DiabetesPedigreeFunction <= 0.739 & BMI > 26.45 & Age > 30.5',
#  'DiabetesPedigreeFunction > 0.739 & BMI <= 31.1',
#  'DiabetesPedigreeFunction > 0.739 & BMI > 31.1',
#  'Glucose <= 143.5 & Age <= 28.5',
#  'Glucose <= 143.5 & Age > 28.5 & BMI <= 27.35',
#  'Glucose <= 143.5 & Age > 28.5 & BMI > 27.35',
#  'Glucose <= 133.5 & Pregnancies <= 5.5',
#  'Glucose <= 133.5 & Pregnancies > 5.5',
#  'Glucose > 133.5 & DiabetesPedigreeFunction <= 0.3',
#  'Glucose > 133.5 & DiabetesPedigreeFunction > 0.3',
#  'Pregnancies > 5.5 & BMI <= 27.2 & DiabetesPedigreeFunction <= 0.133',
#  'Pregnancies > 5.5 & BMI <= 27.2 & DiabetesPedigreeFunction > 0.133',
#  'Pregnancies > 5.5 & BMI > 27.2',
#  'BMI <= 26.95 & Glucose <= 195.0',
#  'BMI <= 26.95 & Glucose > 195.0',
#  'BMI > 26.95 & Age <= 30.5',
#  '30.5 < Age <= 62.0 & BMI > 26.95 & DiabetesPedigreeFunction <= 0.397',
#  '30.5 < Age <= 62.0 & BMI > 26.95 & DiabetesPedigreeFunction > 0.397',
#  'BMI > 26.95 & Age > 62.0',
#  'BMI > 29.85 & Age <= 40.5',
#  'BMI > 29.85 & Age > 40.5',
#  'Glucose <= 101.5',
#  '101.5 < Glucose <= 154.5',
#  'BMI > 28.85 & DiabetesPedigreeFunction <= 0.53',
#  'BMI > 28.85 & DiabetesPedigreeFunction > 0.53',
#  'DiabetesPedigreeFunction <= 0.689 & Age <= 30.5',
#  'DiabetesPedigreeFunction <= 0.689 & Age > 30.5',
#  'BloodPressure <= 75.5',
#  'BloodPressure > 75.5',
#  'BMI <= 30.2 & Glucose <= 166.5',
#  'BMI <= 30.2 & Glucose > 166.5',
#  'BMI > 30.2 & DiabetesPedigreeFunction <= 0.509 & Pregnancies <= 5.5',
#  'BMI > 30.2 & DiabetesPedigreeFunction <= 0.509 & Pregnancies > 5.5',
#  'BMI > 30.2 & DiabetesPedigreeFunction > 0.509',
#  'BloodPressure <= 69.0',
#  'BloodPressure > 69.0 & BMI <= 27.85',
#  'BloodPressure > 69.0 & BMI > 27.85',
#  'Age > 28.5 & Glucose <= 99.5',
#  '99.5 < Glucose <= 163.0 & Age > 28.5',
#  'Age > 28.5 & Glucose > 163.0',
#  'BloodPressure <= 77.0 & BMI <= 29.85',
#  'BloodPressure <= 77.0 & BMI > 29.85',
#  'BloodPressure > 77.0',
#  'BMI <= 28.2',
#  'BMI > 28.2',
#  'DiabetesPedigreeFunction <= 0.5 & Glucose <= 154.5',
#  'DiabetesPedigreeFunction <= 0.5 & Glucose > 154.5',
#  'DiabetesPedigreeFunction > 0.5',
#  'Age <= 28.5 & DiabetesPedigreeFunction <= 0.637',
#  'Age <= 28.5 & DiabetesPedigreeFunction > 0.637',
#  'Glucose <= 143.5 & Age <= 34.5',
#  'Glucose <= 143.5 & Age > 34.5 & BMI <= 26.75',
#  'Glucose <= 143.5 & Age > 34.5 & BMI > 26.75',
#  'Glucose <= 143.5 & Pregnancies <= 5.5',
#  'Glucose <= 143.5 & Pregnancies > 5.5',
#  'Glucose > 143.5 & BMI <= 30.15',
#  'Glucose > 143.5 & BMI > 30.15',
#  'BMI <= 30.2 & Age <= 32.5 & SkinThickness <= 37.0',
#  'BMI <= 30.2 & Age <= 32.5 & SkinThickness > 37.0',
#  'BMI <= 30.2 & Age > 32.5 & BloodPressure <= 85.0',
#  'BMI <= 30.2 & Age > 32.5 & BloodPressure > 85.0',
#  'BMI > 30.2 & Glucose <= 133.5',
#  '133.5 < Glucose <= 166.0 & BMI > 30.2 & DiabetesPedigreeFunction <= 0.298 & Age <= 24.5',
#  '133.5 < Glucose <= 166.0 & BMI > 30.2 & DiabetesPedigreeFunction <= 0.298 & Age > 24.5',
#  '133.5 < Glucose <= 166.0 & BMI > 30.2 & DiabetesPedigreeFunction > 0.298',
#  'BMI > 30.2 & Glucose > 166.0',
#  'SkinThickness <= 31.5 & BMI <= 28.8',
#  'SkinThickness <= 31.5 & BMI > 28.8',
#  'Glucose <= 132.5 & DiabetesPedigreeFunction <= 0.708',
#  'Glucose <= 132.5 & DiabetesPedigreeFunction > 0.708',
#  'Glucose > 132.5 & Age <= 23.5',
#  'Glucose > 132.5 & Age > 23.5 & BMI <= 30.15',
#  'Glucose > 132.5 & Age > 23.5 & BMI > 30.15',
#  'BMI > 29.65 & DiabetesPedigreeFunction <= 0.5',
#  'BMI > 29.65 & DiabetesPedigreeFunction > 0.5',
#  '30.5 < Age <= 41.5 & Glucose <= 144.0 & BMI <= 27.35',
#  '30.5 < Age <= 41.5 & Glucose <= 100.5 & BMI > 27.35',
#  '30.5 < Age <= 41.5 & 100.5 < Glucose <= 144.0 & BMI > 27.35 & BloodPressure <= 67.0',
#  '30.5 < Age <= 41.5 & 100.5 < Glucose <= 144.0 & BMI > 27.35 & BloodPressure > 67.0',
#  '41.5 < Age <= 59.5 & Glucose <= 144.0',
#  '30.5 < Age <= 59.5 & Glucose > 144.0',
#  'Age > 59.5',
#  'Age > 27.5 & Glucose <= 144.5 & BMI <= 26.35',
#  'Age > 27.5 & Glucose <= 94.5 & BMI > 26.35',
#  '94.5 < Glucose <= 144.5 & Age > 27.5 & BMI > 26.35',
#  'Age > 27.5 & Glucose > 144.5',
#  'Glucose <= 130.5 & Pregnancies <= 3.5',
#  'Glucose <= 130.5 & Pregnancies > 3.5',
#  'Glucose > 130.5 & BMI <= 27.85',
#  'Glucose > 130.5 & BMI > 27.85',
#  'BMI > 30.2 & Pregnancies <= 6.5',
#  'BMI > 30.2 & Pregnancies > 6.5',
#  'BMI > 27.35 & Glucose <= 141.5',
#  'BMI > 27.35 & Glucose > 141.5',
#  'Pregnancies <= 5.5 & Glucose <= 161.5',
#  'Pregnancies <= 5.5 & Glucose > 161.5',
#  'Pregnancies > 5.5 & Glucose <= 99.5',
#  'Pregnancies > 5.5 & Glucose > 99.5',
#  'Pregnancies <= 5.5 & Glucose <= 111.5',
#  '111.5 < Glucose <= 161.5 & Pregnancies <= 5.5',
#  'Age <= 34.5',
#  'Age > 34.5',
#  'Age <= 30.5 & DiabetesPedigreeFunction <= 0.5',
#  'Age <= 30.5 & DiabetesPedigreeFunction > 0.5',
#  '30.5 < Age <= 54.5 & Glucose <= 137.5 & BMI <= 27.2',
#  '30.5 < Age <= 54.5 & Glucose <= 137.5 & BMI > 27.2 & DiabetesPedigreeFunction <= 0.521',
#  '30.5 < Age <= 54.5 & Glucose <= 137.5 & BMI > 27.2 & DiabetesPedigreeFunction > 0.521',
#  '30.5 < Age <= 54.5 & Glucose > 137.5 & Pregnancies <= 9.5',
#  '30.5 < Age <= 54.5 & Glucose > 137.5 & Pregnancies > 9.5',
#  'Age > 54.5',
#  'BMI > 27.35 & DiabetesPedigreeFunction <= 0.328',
#  'BMI > 27.35 & DiabetesPedigreeFunction > 0.328 & Glucose <= 103.0',
#  'BMI > 27.35 & DiabetesPedigreeFunction > 0.328 & Glucose > 103.0',
#  'Glucose <= 133.5',
#  'Glucose > 133.5 & Age <= 30.5',
#  'Glucose > 133.5 & Age > 30.5',
#  'DiabetesPedigreeFunction <= 0.431 & Glucose <= 158.5',
#  'DiabetesPedigreeFunction <= 0.431 & Glucose > 158.5',
#  'DiabetesPedigreeFunction > 0.431',
#  'SkinThickness <= 30.5',
#  'SkinThickness > 30.5 & Pregnancies <= 6.5',
#  'SkinThickness > 30.5 & Pregnancies > 6.5',
#  'Glucose <= 154.5 & BMI <= 26.45',
#  'Glucose <= 154.5 & BMI > 26.45 & Pregnancies <= 6.5',
#  'Glucose <= 154.5 & BMI > 26.45 & Pregnancies > 6.5',
#  'BMI <= 26.8',
#  'BMI > 26.8',
#  'Glucose <= 159.0',
#  'Glucose > 159.0',
#  '30.25 < BMI <= 45.4 & Glucose <= 143.5 & Age <= 34.5',
#  '30.25 < BMI <= 45.4 & Glucose <= 143.5 & Age > 34.5',
#  'Glucose <= 143.5 & BMI > 45.4',
#  'BMI > 30.25 & Glucose > 143.5',
#  'Age > 30.5 & BMI <= 27.2',
#  'Age > 30.5 & BMI > 27.2 & SkinThickness <= 18.5',
#  'Age > 30.5 & BMI > 27.2 & SkinThickness > 18.5',
#  '114.5 < Glucose <= 158.5',
#  'Glucose > 158.5',
#  'DiabetesPedigreeFunction <= 0.219',
#  'DiabetesPedigreeFunction > 0.219',
#  'Age > 28.5 & BMI <= 28.85',
#  'Age > 28.5 & BMI > 28.85',
#  'DiabetesPedigreeFunction <= 0.528 & BMI <= 29.35',
#  'DiabetesPedigreeFunction <= 0.528 & BMI > 29.35',
#  'DiabetesPedigreeFunction > 0.528',
#  'BloodPressure > 69.0',
#  'Glucose <= 133.5 & DiabetesPedigreeFunction <= 0.664',
#  'Glucose <= 133.5 & DiabetesPedigreeFunction > 0.664',
#  'Age <= 28.5 & Glucose <= 137.5',
#  'Age <= 28.5 & Glucose > 137.5',
#  'Age <= 27.5 & SkinThickness <= 32.5',
#  'Age <= 27.5 & SkinThickness > 32.5',
#  'Glucose <= 103.5',
#  '103.5 < Glucose <= 143.5 & Age <= 28.5',
#  '103.5 < Glucose <= 143.5 & Age > 28.5',
#  'Pregnancies <= 6.5 & BloodPressure <= 69.0',
#  'Pregnancies <= 6.5 & BloodPressure > 69.0',
#  'Age > 28.5 & BMI <= 27.85',
#  'Age > 28.5 & BMI > 27.85',
#  'Glucose <= 141.5 & Age <= 30.5',
#  'Age > 30.5 & Glucose <= 94.5',
#  '94.5 < Glucose <= 141.5 & Age > 30.5',
#  'Glucose > 141.5 & DiabetesPedigreeFunction <= 0.312',
#  'Glucose > 141.5 & DiabetesPedigreeFunction > 0.312',
#  '30.95 < BMI <= 42.2 & Pregnancies <= 5.5',
#  'Pregnancies <= 5.5 & BMI > 42.2',
#  'SkinThickness <= 32.5 & Age > 27.5 & Glucose <= 110.5',
#  'SkinThickness <= 32.5 & Age > 27.5 & Glucose > 110.5',
#  'Age <= 39.5',
#  'Age > 39.5',
#  'BMI <= 30.25 & Age <= 28.5',
#  'BMI <= 30.25 & Age > 28.5',
#  'Glucose <= 137.5 & Age <= 30.5 & BMI <= 28.95',
#  'Glucose <= 137.5 & Age <= 30.5 & BMI > 28.95',
#  'Glucose <= 137.5 & Age > 30.5',
#  '137.5 < Glucose <= 152.5 & SkinThickness <= 22.5',
#  'SkinThickness <= 22.5 & Glucose > 152.5 & BMI <= 29.85',
#  'SkinThickness <= 22.5 & Glucose > 152.5 & BMI > 29.85',
#  'Glucose > 137.5 & SkinThickness > 22.5',
#  'Glucose <= 142.5 & Age <= 32.5',
#  'Glucose <= 142.5 & Age > 32.5',
#  'BMI > 27.45 & Glucose <= 101.5',
#  '101.5 < Glucose <= 155.5 & BMI > 27.45',
#  'BMI > 27.45 & Glucose > 155.5',
#  'BMI > 30.2 & DiabetesPedigreeFunction <= 0.426',
#  'BMI > 30.2 & DiabetesPedigreeFunction > 0.426',
#  'Glucose <= 143.5 & DiabetesPedigreeFunction <= 0.534 & Age <= 33.5',
#  'Glucose <= 143.5 & DiabetesPedigreeFunction <= 0.534 & Age > 33.5',
#  'Glucose <= 143.5 & DiabetesPedigreeFunction > 0.534 & BMI <= 32.2',
#  'Glucose <= 143.5 & DiabetesPedigreeFunction > 0.534 & BMI > 32.2',
#  'Glucose > 143.5 & Pregnancies <= 12.5 & BMI <= 30.0',
#  'Glucose > 143.5 & Pregnancies <= 12.5 & BMI > 30.0',
#  'Glucose > 143.5 & Pregnancies > 12.5',
#  'Pregnancies <= 6.5 & Age <= 27.5 & Glucose <= 130.0',
#  'Pregnancies <= 6.5 & Age <= 27.5 & Glucose > 130.0',
#  'Pregnancies <= 6.5 & Age > 27.5 & DiabetesPedigreeFunction <= 0.318',
#  'Pregnancies <= 6.5 & SkinThickness <= 21.5 & Age > 27.5 & DiabetesPedigreeFunction > 0.318 & BMI <= 28.65',
#  'Pregnancies <= 6.5 & SkinThickness <= 21.5 & Age > 27.5 & DiabetesPedigreeFunction > 0.318 & BMI > 28.65',
#  '21.5 < SkinThickness <= 46.5 & Pregnancies <= 6.5 & Age > 27.5 & DiabetesPedigreeFunction > 0.318',
#  'Pregnancies <= 6.5 & Age > 27.5 & DiabetesPedigreeFunction > 0.318 & SkinThickness > 46.5',
#  'Glucose <= 129.5 & BMI <= 42.2',
#  'Glucose <= 129.5 & BMI > 42.2',
#  '129.5 < Glucose <= 157.5 & Age <= 61.5 & BMI <= 27.8',
#  '129.5 < Glucose <= 157.5 & Age <= 61.5 & BMI > 27.8',
#  'Age <= 61.5 & Glucose > 157.5',
#  'Glucose > 129.5 & Age > 61.5',
#  'DiabetesPedigreeFunction <= 0.634 & Glucose <= 143.5 & Age <= 35.5',
#  'DiabetesPedigreeFunction <= 0.634 & Glucose <= 143.5 & Age > 35.5',
#  'DiabetesPedigreeFunction <= 0.634 & Glucose > 143.5',
#  'DiabetesPedigreeFunction > 0.634',
#  'Pregnancies <= 6.5 & Glucose <= 166.0 & DiabetesPedigreeFunction <= 1.141 & BMI <= 31.1',
#  'Pregnancies <= 6.5 & Glucose <= 166.0 & DiabetesPedigreeFunction <= 1.141 & BMI > 31.1',
#  'Pregnancies <= 6.5 & Glucose <= 166.0 & DiabetesPedigreeFunction > 1.141',
#  'Pregnancies <= 6.5 & Glucose > 166.0',
#  'Glucose <= 137.5 & Age <= 39.5',
#  'Glucose <= 137.5 & Age > 39.5 & BMI <= 38.95',
#  'Glucose <= 137.5 & Age > 39.5 & BMI > 38.95',
#  '137.5 < Glucose <= 158.5',
#  'Glucose > 158.5',
#  'DiabetesPedigreeFunction <= 0.227',
#  'DiabetesPedigreeFunction > 0.227',
#  '30.5 < Age <= 60.0',
#  'Age > 60.0',
#  'Age > 28.5 & Glucose <= 143.5',
#  'Age > 28.5 & Glucose > 143.5',
#  'BMI > 28.85 & BloodPressure <= 81.0 & Age <= 25.5',
#  'BMI > 28.85 & BloodPressure <= 81.0 & Age > 25.5 & DiabetesPedigreeFunction <= 0.201',
#  '0.201 < DiabetesPedigreeFunction <= 0.249 & BMI > 28.85 & BloodPressure <= 81.0 & Age > 25.5',
#  'BMI > 28.85 & DiabetesPedigreeFunction > 0.249 & BloodPressure <= 81.0 & Age > 25.5',
#  'BMI > 28.85 & BloodPressure > 81.0',
#  'Age <= 30.5 & Glucose <= 133.0',
#  'Age <= 30.5 & Glucose > 133.0 & BloodPressure <= 65.0',
#  'Age <= 30.5 & Glucose > 133.0 & BloodPressure > 65.0',
#  'BMI <= 27.85 & Glucose <= 153.0',
#  'BMI <= 27.85 & Glucose > 153.0',
#  'BMI > 27.85 & Pregnancies > 6.5 & Glucose <= 107.0',
#  'BMI > 27.85 & Pregnancies > 6.5 & Glucose > 107.0',
#  'Glucose <= 141.5 & SkinThickness <= 31.5 & BMI <= 26.45',
#  'Glucose <= 141.5 & SkinThickness <= 31.5 & BMI > 26.45',
#  'Glucose <= 141.5 & SkinThickness > 31.5',
#  'Glucose <= 154.5 & BMI > 26.45 & BloodPressure <= 61.0',
#  'Glucose <= 154.5 & BMI > 26.45 & BloodPressure > 61.0 & Age <= 30.5',
#  'Glucose <= 154.5 & BMI > 26.45 & BloodPressure > 61.0 & Age > 30.5',
#  ...]

# %%
rules.rule
# Out:
# 0                                             Pregnancies
# 1                                                 Glucose
# 2                                           BloodPressure
# 3                                           SkinThickness
# 4                                                     BMI
#                               ...
# 1479                    Glucose > 124.5 & Glucose > 180.5
# 1480    BMI > 27.84999942779541 & Pregnancies <= 6.5 &...
# 1481    BMI > 27.84999942779541 & Pregnancies <= 6.5 &...
# 1482    BMI > 27.84999942779541 & Pregnancies <= 6.5 &...
# 1483          BMI > 27.84999942779541 & Pregnancies > 6.5
# Name: rule, Length: 1484, dtype: object

# %%
from rulefit import RuleFitClassifier

X2_train = np.array(X2_train)
y2_train = np.array(y2_train)
X2_test = np.array(X2_test)
y2_test = np.array(y2_test)

rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(rfmode=rfmode,
                       tree_generator=tree_generator,
                       random_state=random_state)
rf.fit(X2_train, y2_train, feature_names=feature_names)

display(rf)

y2_pred = rf.predict(X2_test)

# Calculate accuracy
accuracy = accuracy_score(y2_test, y2_pred)

# Generate confusion matrix
conf_matrix = confusion_matrix(y2_test, y2_pred)

# Generate classification report
class_report = classification_report(y2_test, y2_pred)

# Print the results
print("離散データ")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=552,
#                                                         random_state=593))
# 離散データ
# ---------------------------
#
# Accuracy: 0.7611940298507462
#
#
# Confusion Matrix:
#  [[72 18]
#  [14 30]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.80      0.82        90
#            1       0.62      0.68      0.65        44
#
#     accuracy                           0.76       134
#    macro avg       0.73      0.74      0.74       134
# weighted avg       0.77      0.76      0.76       134

# %%
rules = rf.get_rules()
rules.to_csv('./data/rulefit_discrete.csv')
