# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

import numpy as np
import pandas as pd

from rulefit import RuleFit

# # 何故か最新バージョンには rules を取得する関数が存在しなかった
# ! cp ./rulefit.py /home/onoue/ws/lukasiewicz_1/myenv/lib/python3.10/site-packages/rulefit/rulefit.py

# %%
df = pd.read_csv("./data/diabetes.csv")
display(df)
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
import numpy as np
import pandas as pd
from rulefit import RuleFit



## Create artificial data set with
n = 10000
x1 = np.random.normal(scale=1, size=n)
x2 = np.random.normal(loc=0, scale=1, size=n)
x3 = np.random.normal(size=n)
x4 = np.random.normal(size=n)

eps = np.random.normal(loc=0, scale=0.1, size=n)

y = 5 * ((x1 > 1).astype(int) * (x2 <  -1).astype(int)) + 0.3 * x4 + eps


X = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4})



rf = RuleFit(max_iter=100)
rf.fit(X.values, y, X.columns)


rules = rf.get_rules(exclude_zero_coef=True)

print(rules.sort_values('importance', ascending=False))
# Out:
# /home/onoue/ws/lukasiewicz_1/myenv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.49604216106865806, tolerance: 0.4942193403794032
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/onoue/ws/lukasiewicz_1/myenv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.730896133103613, tolerance: 0.4942193403794032
#   model = cd_fast.enet_coordinate_descent_gram(
# /home/onoue/ws/lukasiewicz_1/myenv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8175297493934295, tolerance: 0.4942193403794032
#   model = cd_fast.enet_coordinate_descent_gram(
# ...

# %%
pd.set_option("display.max_colwidth", 999) #ruleが長すぎて表示が省略される場合用
pd.set_option("display.max_rows", 999) 
display(rules)
# Out:
#                                                                                                                                     rule  ...    importance
# 3                                                                                                                                     x4  ...  2.502856e-01
# 5                                                                                    x2 <= -1.2640789151191711 & x1 > 0.9988590478897095  ...  7.732085e-02
# 12                                                                                    x2 <= -1.011508285999298 & x1 > 1.0068801939487457  ...  1.714918e-01
# 17                                                          x2 > -1.011508285999298 & x4 > 0.18361596018075943 & x4 > 1.0891956686973572  ...  8.871731e-04
# 19                                                                                     x2 <= -1.2190400958061218 & x1 > 0.96170374751091  ...  2.858236e-02
# ...
