# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from rulefit import RuleFit

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

# feature_names = data.columns.to_list()

X = data.drop(["Outcome"], axis=1)
y = data["Outcome"]

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)


from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=random_state)
rf_model.fit(X_train, y_train)

y_pred = rf_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.746268656716418
#
#
# Confusion Matrix:
#  [[72 18]
#  [16 28]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        90
#            1       0.61      0.64      0.62        44
#
#     accuracy                           0.75       134
#    macro avg       0.71      0.72      0.72       134
# weighted avg       0.75      0.75      0.75       134

# %%
import shap

explainer = shap.TreeExplainer(rf_model, data=X_train)
shap_values = explainer.shap_values(X_train)
# Out:
#  94%|=================== | 1009/1072 [00:14<00:00]

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel="linear", random_state=random_state)
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7761194029850746
#
#
# Confusion Matrix:
#  [[82  8]
#  [22 22]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85        90
#            1       0.73      0.50      0.59        44
#
#     accuracy                           0.78       134
#    macro avg       0.76      0.71      0.72       134
# weighted avg       0.77      0.78      0.76       134

# %%
from sklearn.svm import SVC

svm_model = SVC(kernel="rbf", random_state=random_state)
svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7835820895522388
#
#
# Confusion Matrix:
#  [[79 11]
#  [18 26]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84        90
#            1       0.70      0.59      0.64        44
#
#     accuracy                           0.78       134
#    macro avg       0.76      0.73      0.74       134
# weighted avg       0.78      0.78      0.78       134

# %% [markdown]
# # RuleFit

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)

feature_names = data.columns.to_list()[1:]

X = np.array(data.drop(["Outcome"], axis=1))
y = np.array(data["Outcome"])

random_state = 42
test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=test_size,
                                                    random_state=random_state)

# %%
feature_names
# Out:
# ['Pregnancies_Low',
#  'Pregnancies_Medium',
#  'Pregnancies_High',
#  'Glucose_Low',
#  'Glucose_Medium',
#  'Glucose_High',
#  'BloodPressure_Low',
#  'BloodPressure_Medium',
#  'BloodPressure_High',
#  'SkinThickness_Low',
#  'SkinThickness_Medium',
#  'SkinThickness_High',
#  'BMI_Low',
#  'BMI_Medium',
#  'BMI_High',
#  'DiabetesPedigreeFunction_Low',
#  'DiabetesPedigreeFunction_Medium',
#  'DiabetesPedigreeFunction_High',
#  'Age_Low',
#  'Age_Medium',
#  'Age_High']

# %%
from rulefit import RuleFitClassifier
from sklearn.ensemble import RandomForestClassifier


rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)

display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=552,
#                                                         random_state=593))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7388059701492538
#
#
# Confusion Matrix:
#  [[72 18]
#  [17 27]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.80      0.80        90
#            1       0.60      0.61      0.61        44
#
#     accuracy                           0.74       134
#    macro avg       0.70      0.71      0.71       134
# weighted avg       0.74      0.74      0.74       134

# %%
rules = rf.get_rules(exclude_zero_coef=True)

# %%
pd.set_option("display.max_colwidth", 999) #ruleが長すぎて表示が省略される場合用
pd.set_option("display.max_rows", 999) 
rules
# Out:
#                                                                                                                                                             rule  \
# 63                                                                                                          Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5
# 126                                                                                                 Glucose_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5
# 129                                                                                                                      Pregnancies_High <= 0.5 & Age_Low > 0.5
# 146                                                                                                                          Glucose_High <= 0.5 & BMI_Low > 0.5
# 173                                                                                                     DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low > 0.5
# 174  Glucose_High <= 0.5 & Age_Medium <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_Low <= 0.5
# 185                                                                                              Glucose_High <= 0.5 & Age_Low <= 0.5 & Pregnancies_Medium > 0.5
# 189                                                                                              Age_Medium <= 0.5 & BMI_Low > 0.5 & BloodPressure_Medium <= 0.5
# 259                                                                                    BMI_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 301                                    Glucose_Low <= 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BMI_High <= 0.5 & Age_Medium <= 0.5
# 389                                                                                                       DiabetesPedigreeFunction_Low <= 0.5 & BMI_Medium > 0.5
# 394                                                                                         Glucose_High <= 0.5 & BloodPressure_Medium > 0.5 & Age_Medium <= 0.5
# 425                                                                                       Age_Low <= 0.5 & BloodPressure_Low <= 0.5 & SkinThickness_Medium > 0.5
# 452                                                                                                                Glucose_High <= 0.5 & Pregnancies_High <= 0.5
# 460                                                                                              Glucose_High <= 0.5 & SkinThickness_High <= 0.5 & Age_Low > 0.5
# 465                                                                                            BMI_Low <= 0.5 & Glucose_High > 0.5 & BloodPressure_Medium <= 0.5
# 500                                                                                                       Age_Medium <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 513                                                                                              Age_Low > 0.5 & Glucose_High <= 0.5 & Pregnancies_Medium <= 0.5
# 518                                                                                                                   BMI_Low <= 0.5 & Pregnancies_Medium <= 0.5
# 520                                                                                          BMI_Medium <= 0.5 & Glucose_Low <= 0.5 & SkinThickness_Medium > 0.5
# 555                                                                                              Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 567                                                                 BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Glucose_Low <= 0.5 & BMI_Medium <= 0.5
# 571                                                                                                      BMI_Low > 0.5 & Pregnancies_Low > 0.5 & Age_High <= 0.5
# 587                                                                                     Glucose_High <= 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Low <= 0.5
# 589                                                                                                                          BMI_Low <= 0.5 & Glucose_Low <= 0.5
# 600                                                                             BMI_Medium > 0.5 & DiabetesPedigreeFunction_Low > 0.5 & SkinThickness_Low <= 0.5
# 624                                                                                                                     Age_Low > 0.5 & SkinThickness_Low <= 0.5
# 641                    Glucose_Low <= 0.5 & Glucose_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Medium <= 0.5 & SkinThickness_Low > 0.5
# 657                                                                                          BloodPressure_High <= 0.5 & BMI_Medium <= 0.5 & Glucose_High <= 0.5
# 700                                                                                          Glucose_High <= 0.5 & BMI_High <= 0.5 & BloodPressure_Medium <= 0.5
# 709                                                                                                BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5
# 711                                                                                                            BloodPressure_Low > 0.5 & SkinThickness_Low > 0.5
# 824                                                                                              Glucose_High > 0.5 & BMI_Low <= 0.5 & SkinThickness_High <= 0.5
# 833                                                                  BMI_Low <= 0.5 & Pregnancies_High <= 0.5 & SkinThickness_Medium > 0.5 & Glucose_High <= 0.5
# 859                                                                                    Age_Medium <= 0.5 & BloodPressure_Low <= 0.5 & BloodPressure_Medium > 0.5
# 947                                                                                               BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5
# 949                                                                                                  Glucose_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5
#
#      type      coef   support  importance
# 63   rule  0.074327  0.211144    0.030334
# 126  rule -0.186842  0.603499    0.091398
# 129  rule -0.052975  0.645533    0.025341
# 146  rule -0.094062  0.296830    0.042973
# 173  rule -1.055865  0.211765    0.431383
# 174  rule -0.089146  0.127536    0.029737
# 185  rule -0.099373  0.093567    0.028940
# 189  rule -0.050964  0.134328    0.017379
# 259  rule  0.030736  0.242604    0.013175
# 301  rule -0.050065  0.468208    0.024982
# 389  rule  0.273651  0.228070    0.114821
# 394  rule -0.030814  0.404692    0.015124
# 425  rule  0.090458  0.151335    0.032418
# 452  rule -0.279134  0.727536    0.124278
# 460  rule -0.021046  0.540936    0.010487
# 465  rule  0.809047  0.054217    0.183205
# 500  rule -0.074181  0.471976    0.037032
# 513  rule -0.056767  0.500000    0.028384
# 518  rule  0.119064  0.441441    0.059122
# 520  rule  0.370562  0.103245    0.112754
# 555  rule  0.079403  0.288690    0.035982
# 567  rule  0.024025  0.050746    0.005273
# 571  rule -0.198370  0.205970    0.080222
# 587  rule -0.168124  0.561960    0.083414
# 589  rule  0.696725  0.557185    0.346077
# 600  rule -0.068590  0.215569    0.028205
# 624  rule -0.032944  0.386905    0.016045
# 641  rule  0.035472  0.087719    0.010035
# 657  rule -0.415719  0.328402    0.195235
# 700  rule -0.729959  0.245562    0.314189
# 709  rule -0.061908  0.527778    0.030906
# 711  rule -0.122190  0.105556    0.037545
# 824  rule  0.042496  0.139942    0.014743
# 833  rule -0.044515  0.228070    0.018678
# 859  rule -0.098976  0.494186    0.049485
# 947  rule  0.021328  0.285303    0.009631
# 949  rule -0.739694  0.524781    0.369392

# %%
rules['rule'].to_list()
# Out:
# ['Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5',
#  'Glucose_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5',
#  'Pregnancies_High <= 0.5 & Age_Low > 0.5',
#  'Glucose_High <= 0.5 & BMI_Low > 0.5',
#  'DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low > 0.5',
#  'Glucose_High <= 0.5 & Age_Medium <= 0.5 & SkinThickness_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5 & BloodPressure_Low <= 0.5',
#  'Glucose_High <= 0.5 & Age_Low <= 0.5 & Pregnancies_Medium > 0.5',
#  'Age_Medium <= 0.5 & BMI_Low > 0.5 & BloodPressure_Medium <= 0.5',
#  'BMI_Low <= 0.5 & Glucose_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5',
#  'Glucose_Low <= 0.5 & Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & BMI_High <= 0.5 & Age_Medium <= 0.5',
#  'DiabetesPedigreeFunction_Low <= 0.5 & BMI_Medium > 0.5',
#  'Glucose_High <= 0.5 & BloodPressure_Medium > 0.5 & Age_Medium <= 0.5',
#  'Age_Low <= 0.5 & BloodPressure_Low <= 0.5 & SkinThickness_Medium > 0.5',
#  'Glucose_High <= 0.5 & Pregnancies_High <= 0.5',
#  'Glucose_High <= 0.5 & SkinThickness_High <= 0.5 & Age_Low > 0.5',
#  'BMI_Low <= 0.5 & Glucose_High > 0.5 & BloodPressure_Medium <= 0.5',
#  'Age_Medium <= 0.5 & DiabetesPedigreeFunction_Low > 0.5',
#  'Age_Low > 0.5 & Glucose_High <= 0.5 & Pregnancies_Medium <= 0.5',
#  'BMI_Low <= 0.5 & Pregnancies_Medium <= 0.5',
#  'BMI_Medium <= 0.5 & Glucose_Low <= 0.5 & SkinThickness_Medium > 0.5',
#  'Pregnancies_Medium <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5',
#  'BMI_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Glucose_Low <= 0.5 & BMI_Medium <= 0.5',
#  'BMI_Low > 0.5 & Pregnancies_Low > 0.5 & Age_High <= 0.5',
#  'Glucose_High <= 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Low <= 0.5',
#  'BMI_Low <= 0.5 & Glucose_Low <= 0.5',
#  'BMI_Medium > 0.5 & DiabetesPedigreeFunction_Low > 0.5 & SkinThickness_Low <= 0.5',
#  'Age_Low > 0.5 & SkinThickness_Low <= 0.5',
#  'Glucose_Low <= 0.5 & Glucose_High <= 0.5 & BMI_Low <= 0.5 & Pregnancies_Low > 0.5 & SkinThickness_Medium <= 0.5 & SkinThickness_Low > 0.5',
#  'BloodPressure_High <= 0.5 & BMI_Medium <= 0.5 & Glucose_High <= 0.5',
#  'Glucose_High <= 0.5 & BMI_High <= 0.5 & BloodPressure_Medium <= 0.5',
#  'BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low > 0.5',
#  'BloodPressure_Low > 0.5 & SkinThickness_Low > 0.5',
#  'Glucose_High > 0.5 & BMI_Low <= 0.5 & SkinThickness_High <= 0.5',
#  'BMI_Low <= 0.5 & Pregnancies_High <= 0.5 & SkinThickness_Medium > 0.5 & Glucose_High <= 0.5',
#  'Age_Medium <= 0.5 & BloodPressure_Low <= 0.5 & BloodPressure_Medium > 0.5',
#  'BloodPressure_Low <= 0.5 & DiabetesPedigreeFunction_Low <= 0.5',
#  'Glucose_High <= 0.5 & Pregnancies_Low > 0.5 & Age_Low > 0.5']

# %%
rules['coef'].to_list()
# Out:
# [0.07432722672293267,
#  -0.18684215948425859,
#  -0.052974770117989955,
#  -0.09406229566792239,
#  -1.0558648104402797,
#  -0.08914640574339584,
#  -0.0993733116859669,
#  -0.05096406706986821,
#  0.030736386193210674,
#  -0.05006538633615083,
#  0.27365126739682,
#  -0.030813612958937246,
#  0.09045800299717027,
#  -0.2791335078579396,
#  -0.021045513076233577,
#  0.8090469488003349,
#  -0.07418099769686855,
#  -0.056767355647081894,
#  0.11906372196269616,
#  0.3705618840863954,
#  0.0794033818877824,
#  0.0240249388830329,
#  -0.19836962168805894,
#  -0.1681239593980275,
#  0.6967254651076645,
#  -0.06858991635501352,
#  -0.032943579544958815,
#  0.03547211148941087,
#  -0.41571863133509973,
#  -0.7299594159634366,
#  -0.06190759866656954,
#  -0.1221896449369362,
#  0.04249586885041769,
#  -0.044515460772968266,
#  -0.09897582432101674,
#  0.02132803536052671,
#  -0.7396936654470444]

# %%
# rules_from_RuleFit = ['Glucose_Low <= 0.5 & Age_Low <= 0.5 & BMI_Low <= 0.5',
#                       'Glucose_High <= 0.5 & DiabetesPedigreeFunction_Medium <= 0.5',
#                       'Pregnancies_High <= 0.5 & Age_Low > 0.5',
#                       'Glucose_High <= 0.5 & BMI_Low > 0.5',
#                       'DiabetesPedigreeFunction_High <= 0.5 & Glucose_Low > 0.5']
rules_from_RuleFit = rules['rule'].to_list()
coefs_from_RuleFit = rules['coef'].to_list()

rules_list = [rule.split(' ') for rule in rules_from_RuleFit]

rules_list_new = []

for rule, coef in zip(rules_list, coefs_from_RuleFit):

    # '&' を目印にして複数のリストに分割する
    sublists = []
    current_sublist = []
    for item in rule:
        if item != '&':
            current_sublist.append(item)
        else:
            sublists.append(current_sublist)
            current_sublist = []

    # ループ終了後に最後のサブリストを追加
    sublists.append(current_sublist)

    rule_new = []
    cnt = 0
    for sublist in sublists:
        if len(sublist) <= 1:
            rule_new.append(sublist[0])
        else:
            if sublist[1] in ['<', '<=']:
                rule_new.append('¬')
                rule_new.append(sublist[0])
            else:
                rule_new.append(sublist[0])
        
        cnt +=1
        if cnt < len(sublists):
            rule_new.append('⊗')
        else:
            rule_new.append('→')

            # coef == 0 の rule は除外されているため
            if coef > 0:
                rule_new.append('Outcome')
            elif coef < 0:
                rule_new.append('¬')
                rule_new.append('Outcome')

    
    rules_list_new.append(rule_new)



for rule in rules_list_new:
    print(rule)
# Out:
# ['¬', 'Glucose_Low', '⊗', '¬', 'Age_Low', '⊗', '¬', 'BMI_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '→', '¬', 'Outcome']
# ['¬', 'Pregnancies_High', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BMI_Low', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_High', '⊗', 'Glucose_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Medium', '⊗', '¬', 'SkinThickness_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Medium', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Age_Low', '⊗', 'Pregnancies_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'BMI_Low', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'DiabetesPedigreeFunction_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'DiabetesPedigreeFunction_Low', '⊗', 'BMI_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'BloodPressure_Medium', '⊗', '¬', 'Age_Medium', '→', '¬', 'Outcome']
# ['¬', 'Age_Low', '⊗', '¬', 'BloodPressure_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'SkinThickness_High', '⊗', 'Age_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'Glucose_High', '⊗', '¬', 'BloodPressure_Medium', '→', 'Outcome']
# ['¬', 'Age_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_Medium', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_Medium', '→', 'Outcome']
# ['¬', 'BMI_Medium', '⊗', '¬', 'Glucose_Low', '⊗', 'SkinThickness_Medium', '→', 'Outcome']
# ['¬', 'Pregnancies_Medium', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'Glucose_Low', '⊗', '¬', 'BMI_Medium', '→', 'Outcome']
# ['BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'Age_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'Pregnancies_High', '⊗', '¬', 'BloodPressure_Low', '→', '¬', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Glucose_Low', '→', 'Outcome']
# ['BMI_Medium', '⊗', 'DiabetesPedigreeFunction_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Age_Low', '⊗', '¬', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['¬', 'Glucose_Low', '⊗', '¬', 'Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', 'Pregnancies_Low', '⊗', '¬', 'SkinThickness_Medium', '⊗', 'SkinThickness_Low', '→', 'Outcome']
# ['¬', 'BloodPressure_High', '⊗', '¬', 'BMI_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Glucose_High', '⊗', '¬', 'BMI_High', '⊗', '¬', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', 'DiabetesPedigreeFunction_Low', '→', '¬', 'Outcome']
# ['BloodPressure_Low', '⊗', 'SkinThickness_Low', '→', '¬', 'Outcome']
# ['Glucose_High', '⊗', '¬', 'BMI_Low', '⊗', '¬', 'SkinThickness_High', '→', 'Outcome']
# ['¬', 'BMI_Low', '⊗', '¬', 'Pregnancies_High', '⊗', 'SkinThickness_Medium', '⊗', '¬', 'Glucose_High', '→', '¬', 'Outcome']
# ['¬', 'Age_Medium', '⊗', '¬', 'BloodPressure_Low', '⊗', 'BloodPressure_Medium', '→', '¬', 'Outcome']
# ['¬', 'BloodPressure_Low', '⊗', '¬', 'DiabetesPedigreeFunction_Low', '→', 'Outcome']
# ['¬', 'Glucose_High', '⊗', 'Pregnancies_Low', '⊗', 'Age_Low', '→', '¬', 'Outcome']

# %%
rules_generated = []

for rule in rules_list_new[:10]:
    rules_generated.append(' '.join(rule))

rules_generated
# Out:
# ['¬ Glucose_Low ⊗ ¬ Age_Low ⊗ ¬ BMI_Low → Outcome',
#  '¬ Glucose_High ⊗ ¬ DiabetesPedigreeFunction_Medium → ¬ Outcome',
#  '¬ Pregnancies_High ⊗ Age_Low → ¬ Outcome',
#  '¬ Glucose_High ⊗ BMI_Low → ¬ Outcome',
#  '¬ DiabetesPedigreeFunction_High ⊗ Glucose_Low → ¬ Outcome',
#  '¬ Glucose_High ⊗ ¬ Age_Medium ⊗ ¬ SkinThickness_Low ⊗ ¬ Glucose_Low ⊗ ¬ DiabetesPedigreeFunction_Medium ⊗ ¬ BloodPressure_Low → ¬ Outcome',
#  '¬ Glucose_High ⊗ ¬ Age_Low ⊗ Pregnancies_Medium → ¬ Outcome',
#  '¬ Age_Medium ⊗ BMI_Low ⊗ ¬ BloodPressure_Medium → ¬ Outcome',
#  '¬ BMI_Low ⊗ ¬ Glucose_Low ⊗ ¬ DiabetesPedigreeFunction_Low → Outcome',
#  '¬ Glucose_Low ⊗ ¬ Pregnancies_High ⊗ ¬ DiabetesPedigreeFunction_High ⊗ ¬ BMI_High ⊗ ¬ Age_Medium → ¬ Outcome']

# %%
print(feature_names)
print()

tmp_dict = {}

for item in feature_names:
    key, value = item.rsplit('_', 1)
    if key not in tmp_dict:
        tmp_dict[key] = []
    
    tmp_dict[key].append(item)
    

rules_additional = list(tmp_dict.values())
rules_additional = [' ⊕ '.join(rule) for rule in rules_additional]


for rule in rules_additional:
    print(rule)
# Out:
# ['Pregnancies_Low', 'Pregnancies_Medium', 'Pregnancies_High', 'Glucose_Low', 'Glucose_Medium', 'Glucose_High', 'BloodPressure_Low', 'BloodPressure_Medium', 'BloodPressure_High', 'SkinThickness_Low', 'SkinThickness_Medium', 'SkinThickness_High', 'BMI_Low', 'BMI_Medium', 'BMI_High', 'DiabetesPedigreeFunction_Low', 'DiabetesPedigreeFunction_Medium', 'DiabetesPedigreeFunction_High', 'Age_Low', 'Age_Medium', 'Age_High']
#
# Pregnancies_Low ⊕ Pregnancies_Medium ⊕ Pregnancies_High
# Glucose_Low ⊕ Glucose_Medium ⊕ Glucose_High
# BloodPressure_Low ⊕ BloodPressure_Medium ⊕ BloodPressure_High
# SkinThickness_Low ⊕ SkinThickness_Medium ⊕ SkinThickness_High
# BMI_Low ⊕ BMI_Medium ⊕ BMI_High
# DiabetesPedigreeFunction_Low ⊕ DiabetesPedigreeFunction_Medium ⊕ DiabetesPedigreeFunction_High
# Age_Low ⊕ Age_Medium ⊕ Age_High

# %%
rules_generated + rules_additional
# Out:
# ['¬ Glucose_Low ⊗ ¬ Age_Low ⊗ ¬ BMI_Low → Outcome',
#  '¬ Glucose_High ⊗ ¬ DiabetesPedigreeFunction_Medium → ¬ Outcome',
#  '¬ Pregnancies_High ⊗ Age_Low → ¬ Outcome',
#  '¬ Glucose_High ⊗ BMI_Low → ¬ Outcome',
#  '¬ DiabetesPedigreeFunction_High ⊗ Glucose_Low → ¬ Outcome',
#  '¬ Glucose_High ⊗ ¬ Age_Medium ⊗ ¬ SkinThickness_Low ⊗ ¬ Glucose_Low ⊗ ¬ DiabetesPedigreeFunction_Medium ⊗ ¬ BloodPressure_Low → ¬ Outcome',
#  '¬ Glucose_High ⊗ ¬ Age_Low ⊗ Pregnancies_Medium → ¬ Outcome',
#  '¬ Age_Medium ⊗ BMI_Low ⊗ ¬ BloodPressure_Medium → ¬ Outcome',
#  '¬ BMI_Low ⊗ ¬ Glucose_Low ⊗ ¬ DiabetesPedigreeFunction_Low → Outcome',
#  '¬ Glucose_Low ⊗ ¬ Pregnancies_High ⊗ ¬ DiabetesPedigreeFunction_High ⊗ ¬ BMI_High ⊗ ¬ Age_Medium → ¬ Outcome',
#  'Pregnancies_Low ⊕ Pregnancies_Medium ⊕ Pregnancies_High',
#  'Glucose_Low ⊕ Glucose_Medium ⊕ Glucose_High',
#  'BloodPressure_Low ⊕ BloodPressure_Medium ⊕ BloodPressure_High',
#  'SkinThickness_Low ⊕ SkinThickness_Medium ⊕ SkinThickness_High',
#  'BMI_Low ⊕ BMI_Medium ⊕ BMI_High',
#  'DiabetesPedigreeFunction_Low ⊕ DiabetesPedigreeFunction_Medium ⊕ DiabetesPedigreeFunction_High',
#  'Age_Low ⊕ Age_Medium ⊕ Age_High']

# %%
len(rules_generated + rules_additional)
# Out:
# 17

# %%
# ファイル名
file_name = './data/rules.txt'

# リストをtxtファイルに書き込む
with open(file_name, 'w') as file:
    for item in rules_generated + rules_additional:
        file.write("%s\n" % item)

# %%
from rulefit import RuleFitClassifier
from sklearn.ensemble import RandomForestClassifier


rfmode = 'classify'
tree_generator = RandomForestClassifier(random_state=random_state)

rf = RuleFitClassifier(max_rules=50,
                       rfmode=rfmode,
                       tree_generator=RandomForestClassifier(),
                       random_state=random_state)

rf.fit(X_train, y_train, feature_names=feature_names)

display(rf)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
class_report = classification_report(y_test, y_pred)

# Print the results
print("離散データ（one-hot encoding）")
print("---------------------------")
print()
print("Accuracy:", accuracy)
print()
print()
print("Confusion Matrix:\n", conf_matrix)
print()
print()
print("Classification Report:\n", class_report)
# Out:
# RuleFitClassifier(max_rules=50, random_state=42,
#                   tree_generator=RandomForestClassifier(max_leaf_nodes=5,
#                                                         n_estimators=13,
#                                                         random_state=54))
# 離散データ（one-hot encoding）
# ---------------------------
#
# Accuracy: 0.7761194029850746
#
#
# Confusion Matrix:
#  [[73 17]
#  [13 31]]
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83        90
#            1       0.65      0.70      0.67        44
#
#     accuracy                           0.78       134
#    macro avg       0.75      0.76      0.75       134
# weighted avg       0.78      0.78      0.78       134

# %%
feature_names
# Out:
# ['Outcome',
#  'Pregnancies_Low',
#  'Pregnancies_Medium',
#  'Pregnancies_High',
#  'Glucose_Low',
#  'Glucose_Medium',
#  'Glucose_High',
#  'BloodPressure_Low',
#  'BloodPressure_Medium',
#  'BloodPressure_High',
#  'SkinThickness_Low',
#  'SkinThickness_Medium',
#  'SkinThickness_High',
#  'BMI_Low',
#  'BMI_Medium',
#  'BMI_High',
#  'DiabetesPedigreeFunction_Low',
#  'DiabetesPedigreeFunction_Medium',
#  'DiabetesPedigreeFunction_High',
#  'Age_Low',
#  'Age_Medium',
#  'Age_High']

# %%
rules = rf.get_rules(exclude_zero_coef=True)
rules
# Out:
#                                                                                                    rule  \
# 1                                                                                       Pregnancies_Low
# 2                                                                                    Pregnancies_Medium
# 3                                                                                      Pregnancies_High
# 5                                                                                        Glucose_Medium
# 7                                                                                     BloodPressure_Low
# 8                                                                                  BloodPressure_Medium
# 11                                                                                 SkinThickness_Medium
# 12                                                                                   SkinThickness_High
# 13                                                                                              BMI_Low
# 15                                                                                             BMI_High
# 17                                                                      DiabetesPedigreeFunction_Medium
# 21                                                                                Glucose_Medium <= 0.5
# 22                                                                                 Glucose_Medium > 0.5
# 23                                                  BMI_Medium <= 0.5 & Outcome <= 0.5 & BMI_Low <= 0.5
# 26    BMI_Medium <= 0.5 & Outcome > 0.5 & DiabetesPedigreeFunction_High > 0.5 & Pregnancies_High <= 0.5
# 29                              BMI_Medium > 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Medium > 0.5
# 30                                                            BMI_Medium > 0.5 & Pregnancies_High > 0.5
# 32                                          Glucose_Medium <= 0.5 & Age_Low <= 0.5 & Glucose_High > 0.5
# 36                                       DiabetesPedigreeFunction_High > 0.5 & SkinThickness_High > 0.5
# 40                                                                             SkinThickness_High > 0.5
# 42            DiabetesPedigreeFunction_High <= 0.5 & BloodPressure_High <= 0.5 & Pregnancies_High > 0.5
# 43                                      DiabetesPedigreeFunction_High <= 0.5 & BloodPressure_High > 0.5
# 44                        DiabetesPedigreeFunction_High > 0.5 & BMI_High <= 0.5 & Glucose_Medium <= 0.5
# 48                                         DiabetesPedigreeFunction_High > 0.5 & Pregnancies_High > 0.5
# 50             SkinThickness_High <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Pregnancies_High <= 0.5
# 52                                                                                       Age_Low <= 0.5
# 57  BMI_Medium <= 0.5 & SkinThickness_High <= 0.5 & Outcome > 0.5 & DiabetesPedigreeFunction_High > 0.5
# 58                                                         BMI_Medium <= 0.5 & SkinThickness_High > 0.5
# 60           BMI_Medium > 0.5 & BloodPressure_Medium <= 0.5 & Outcome > 0.5 & BloodPressure_High <= 0.5
# 63           Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & SkinThickness_High <= 0.5
# 65                   Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High > 0.5 & Glucose_Low <= 0.5
# 67                                                                               Pregnancies_High > 0.5
#
#       type      coef   support  importance
# 1   linear -0.481035  1.000000    0.207774
# 2   linear  0.136026  1.000000    0.040943
# 3   linear -0.187261  1.000000    0.076873
# 5   linear  0.181535  1.000000    0.071525
# 7   linear  0.124705  1.000000    0.059211
# 8   linear -0.205998  1.000000    0.077339
# 11  linear -0.186036  1.000000    0.053121
# 12  linear -0.091690  1.000000    0.043059
# 13  linear  0.174153  1.000000    0.086727
# 15  linear -0.367591  1.000000    0.176650
# 17  linear  0.281324  1.000000    0.079569
# 21    rule -0.206923  0.804094    0.082127
# 22    rule  1.024102  0.195906    0.406463
# 23    rule  0.636929  0.105422    0.195599
# 26    rule -0.962730  0.340361    0.456171
# 29    rule  0.889653  0.021084    0.127813
# 30    rule -0.595959  0.024096    0.091389
# 32    rule -0.232689  0.129909    0.078231
# 36    rule -0.281861  0.244957    0.121217
# 40    rule -0.582851  0.297059    0.266341
# 42    rule  0.079174  0.023256    0.011933
# 43    rule -0.378200  0.165698    0.140618
# 44    rule -0.101686  0.209302    0.041367
# 48    rule -1.069032  0.166667    0.398405
# 50    rule  0.460576  0.166154    0.171435
# 52    rule -0.030684  0.762463    0.013058
# 57    rule  0.129468  0.272455    0.057642
# 58    rule -0.163340  0.344311    0.077610
# 60    rule -0.996665  0.047904    0.212851
# 63    rule  0.720004  0.211144    0.293848
# 65    rule  0.257249  0.090909    0.073954
# 67    rule -0.986815  0.231672    0.416337

# %%
rules.sort_values(by="importance", ascending=False)
# Out:
#                                                                                                    rule  \
# 26    BMI_Medium <= 0.5 & Outcome > 0.5 & DiabetesPedigreeFunction_High > 0.5 & Pregnancies_High <= 0.5
# 67                                                                               Pregnancies_High > 0.5
# 22                                                                                 Glucose_Medium > 0.5
# 48                                         DiabetesPedigreeFunction_High > 0.5 & Pregnancies_High > 0.5
# 63           Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High <= 0.5 & SkinThickness_High <= 0.5
# 40                                                                             SkinThickness_High > 0.5
# 60           BMI_Medium > 0.5 & BloodPressure_Medium <= 0.5 & Outcome > 0.5 & BloodPressure_High <= 0.5
# 1                                                                                       Pregnancies_Low
# 23                                                  BMI_Medium <= 0.5 & Outcome <= 0.5 & BMI_Low <= 0.5
# 15                                                                                             BMI_High
# 50             SkinThickness_High <= 0.5 & DiabetesPedigreeFunction_Low > 0.5 & Pregnancies_High <= 0.5
# 43                                      DiabetesPedigreeFunction_High <= 0.5 & BloodPressure_High > 0.5
# 29                              BMI_Medium > 0.5 & Pregnancies_High <= 0.5 & BloodPressure_Medium > 0.5
# 36                                       DiabetesPedigreeFunction_High > 0.5 & SkinThickness_High > 0.5
# 30                                                            BMI_Medium > 0.5 & Pregnancies_High > 0.5
# 13                                                                                              BMI_Low
# 21                                                                                Glucose_Medium <= 0.5
# 17                                                                      DiabetesPedigreeFunction_Medium
# 32                                          Glucose_Medium <= 0.5 & Age_Low <= 0.5 & Glucose_High > 0.5
# 58                                                         BMI_Medium <= 0.5 & SkinThickness_High > 0.5
# 8                                                                                  BloodPressure_Medium
# 3                                                                                      Pregnancies_High
# 65                   Pregnancies_High <= 0.5 & DiabetesPedigreeFunction_High > 0.5 & Glucose_Low <= 0.5
# 5                                                                                        Glucose_Medium
# 7                                                                                     BloodPressure_Low
# 57  BMI_Medium <= 0.5 & SkinThickness_High <= 0.5 & Outcome > 0.5 & DiabetesPedigreeFunction_High > 0.5
# 11                                                                                 SkinThickness_Medium
# 12                                                                                   SkinThickness_High
# 44                        DiabetesPedigreeFunction_High > 0.5 & BMI_High <= 0.5 & Glucose_Medium <= 0.5
# 2                                                                                    Pregnancies_Medium
# 52                                                                                       Age_Low <= 0.5
# 42            DiabetesPedigreeFunction_High <= 0.5 & BloodPressure_High <= 0.5 & Pregnancies_High > 0.5
#
#       type      coef   support  importance
# 26    rule -0.962730  0.340361    0.456171
# 67    rule -0.986815  0.231672    0.416337
# 22    rule  1.024102  0.195906    0.406463
# 48    rule -1.069032  0.166667    0.398405
# 63    rule  0.720004  0.211144    0.293848
# 40    rule -0.582851  0.297059    0.266341
# 60    rule -0.996665  0.047904    0.212851
# 1   linear -0.481035  1.000000    0.207774
# 23    rule  0.636929  0.105422    0.195599
# 15  linear -0.367591  1.000000    0.176650
# 50    rule  0.460576  0.166154    0.171435
# 43    rule -0.378200  0.165698    0.140618
# 29    rule  0.889653  0.021084    0.127813
# 36    rule -0.281861  0.244957    0.121217
# 30    rule -0.595959  0.024096    0.091389
# 13  linear  0.174153  1.000000    0.086727
# 21    rule -0.206923  0.804094    0.082127
# 17  linear  0.281324  1.000000    0.079569
# 32    rule -0.232689  0.129909    0.078231
# 58    rule -0.163340  0.344311    0.077610
# 8   linear -0.205998  1.000000    0.077339
# 3   linear -0.187261  1.000000    0.076873
# 65    rule  0.257249  0.090909    0.073954
# 5   linear  0.181535  1.000000    0.071525
# 7   linear  0.124705  1.000000    0.059211
# 57    rule  0.129468  0.272455    0.057642
# 11  linear -0.186036  1.000000    0.053121
# 12  linear -0.091690  1.000000    0.043059
# 44    rule -0.101686  0.209302    0.041367
# 2   linear  0.136026  1.000000    0.040943
# 52    rule -0.030684  0.762463    0.013058
# 42    rule  0.079174  0.023256    0.011933
