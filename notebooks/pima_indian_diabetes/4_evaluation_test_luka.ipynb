# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
# project_dir_path = '/home/onoue/ws/lukasiewicz_1'
project_dir_path = '/Users/keisukeonoue/ws/lukasiewicz_1/'
sys.path.append(project_dir_path)
import shutil

import pandas as pd
import numpy as np
import cvxpy as cp

from sklearn.model_selection import train_test_split

from src.setup_problem_primal_modular import Setup
from src.objective_function import specimen_construct_objective_function_loss_v3
from src.evaluation import EvaluateModel

# %% [markdown]
# # 提案アルゴリズム用データフォーマット
#
# - 実験設定（seed, その他）
#
# 1. 前処理はすでに終わっているものとする（入力データとして diabetes_discretized.csv をとる）
# 2. seed 値 と train/test の比率を決める
# 3. 教師有りデータ（L_Predicate.csv）と教師無しデータ（U.csv）を作成し，rules.txt と一緒に train ディレクトリに格納
# 4. 最終的に予測を行う Predicate についてのテストデータ（ex. L_Outcome.csv）を作成し test ディレクトリに格納

# %%
data = pd.read_csv("./data/diabetes_discretized.csv", index_col=0)
X = data.drop(["Outcome"], axis=1)
y = data["Outcome"]

random_state = 42
test_size = 0.2

X_train, X_test, _, _ = train_test_split(X, y,
                                         test_size=test_size,
                                         random_state=random_state)

train_index = X_train.index
test_index = X_test.index


train_data = data.loc[train_index, :]
outcome = train_data['Outcome']
features = train_data.drop(['Outcome'], axis=1)
feature_names = list(features.columns)


train_data_dir_path = os.path.join(project_dir_path, 'inputs/pima_indian_diabetes/train')

if not os.path.exists(train_data_dir_path):
    os.mkdir(train_data_dir_path)


df = features.copy()
df['target'] = outcome.replace(0, -1)
display(df)

file_name = "L_" + "Outcome" + '.csv'
file_path = os.path.join(train_data_dir_path, file_name)
df.to_csv(file_path)


for feature_name in feature_names:
    df = features.copy()
    df['target'] = df[feature_name].replace(0, -1)
    # display(df)

    file_name = "L_" + feature_name + '.csv'
    file_path = os.path.join(train_data_dir_path, file_name)
    df.to_csv(file_path)


data_num = 15
data_dim = 21

arr_U = np.random.randint(2, size=(data_num, data_dim))
df_U = pd.DataFrame(arr_U)
df_U.to_csv(os.path.join(train_data_dir_path, 'U.csv'))

# rule.txt
import shutil
source_path = './data/rules.txt'
destination_path = os.path.join(train_data_dir_path, "rules.txt")
shutil.copy(source_path, destination_path)


test_data = data.loc[test_index, :]

outcome = test_data['Outcome']
features = test_data.drop(['Outcome'], axis=1)
feature_names = list(features.columns)


test_data_dir_path = os.path.join(project_dir_path, 'inputs/pima_indian_diabetes/test')

if not os.path.exists(test_data_dir_path):
    os.mkdir(test_data_dir_path)

 
df = features.copy()
df['target'] = outcome.replace(0, -1)
display(df)

file_name = "L_" + "Outcome" + '.csv'
file_path = os.path.join(test_data_dir_path, file_name)
df.to_csv(file_path)
# Out:
#      Pregnancies_Low  Pregnancies_Medium  Pregnancies_High  Glucose_Low  \
# 275                1                   0                 0            0
# 555                0                   1                 0            0
# 699                1                   0                 0            0
# 73                 1                   0                 0            0
# 170                0                   1                 0            0
# ..               ...                 ...               ...          ...
# 87                 1                   0                 0            0
# 128                1                   0                 0            0
# 315                1                   0                 0            0
# 505                0                   0                 1            1
# 122                1                   0                 0            0
#
#      Glucose_Medium  Glucose_High  BloodPressure_Low  BloodPressure_Medium  \
# 275               1             0                  0                     1
# 555               1             0                  0                     1
# 699               1             0                  0                     1
# 73                1             0                  0                     0
# 170               1             0                  0                     1
# ..              ...           ...                ...                   ...
# 87                1             0                  0                     1
# 128               1             0                  0                     0
# 315               1             0                  0                     1
# 505               0             0                  0                     1
# 122               1             0                  0                     1
#
#      BloodPressure_High  SkinThickness_Low  ...  BMI_Low  BMI_Medium  \
# 275                   0                  0  ...        0           0
# 555                   0                  0  ...        1           0
# 699                   0                  1  ...        0           0
# 73                    1                  1  ...        0           1
# 170                   0                  1  ...        0           1
# ..                  ...                ...  ...      ...         ...
# 87                    0                  0  ...        0           1
# 128                   1                  0  ...        0           1
# 315                   0                  0  ...        0           1
# 505                   0                  1  ...        0           1
# 122                   0                  0  ...        0           1
#
#      BMI_High  DiabetesPedigreeFunction_Low  DiabetesPedigreeFunction_Medium  \
# 275         1                             0                                1
# 555         0                             1                                0
# 699         1                             0                                0
# 73          0                             1                                0
# 170         0                             1                                0
# ..        ...                           ...                              ...
# 87          0                             1                                0
# 128         0                             1                                0
# 315         0                             1                                0
# 505         0                             1                                0
# 122         0                             1                                0
#
#      DiabetesPedigreeFunction_High  Age_Low  Age_Medium  Age_High  target
# 275                              0        1           0         0      -1
# 555                              0        0           1         0      -1
# 699                              1        1           0         0      -1
# 73                               0        1           0         0      -1
# 170                              0        1           0         0       1
# ..                             ...      ...         ...       ...     ...
# 87                               0        1           0         0      -1
# 128                              0        0           1         0       1
# 315                              0        1           0         0      -1
# 505                              0        0           1         0      -1
# 122                              0        1           0         0      -1
#
# [536 rows x 22 columns]
#      Pregnancies_Low  Pregnancies_Medium  Pregnancies_High  Glucose_Low  \
# 419                1                   0                 0            0
# 186                0                   1                 0            0
# 556                1                   0                 0            0
# 738                1                   0                 0            0
# 320                1                   0                 0            0
# ..               ...                 ...               ...          ...
# 626                1                   0                 0            0
# 487                1                   0                 0            0
# 638                0                   1                 0            0
# 248                0                   0                 1            0
# 24                 0                   0                 1            0
#
#      Glucose_Medium  Glucose_High  BloodPressure_Low  BloodPressure_Medium  \
# 419               1             0                  0                     1
# 186               0             1                  0                     1
# 556               1             0                  0                     1
# 738               1             0                  1                     0
# 320               1             0                  1                     0
# ..              ...           ...                ...                   ...
# 626               1             0                  0                     1
# 487               0             1                  0                     1
# 638               1             0                  0                     1
# 248               1             0                  0                     1
# 24                1             0                  0                     0
#
#      BloodPressure_High  SkinThickness_Low  ...  BMI_Low  BMI_Medium  \
# 419                   0                  0  ...        1           0
# 186                   0                  0  ...        0           1
# 556                   0                  0  ...        0           1
# 738                   0                  1  ...        0           1
# 320                   0                  1  ...        1           0
# ..                  ...                ...  ...      ...         ...
# 626                   0                  1  ...        1           0
# 487                   0                  0  ...        0           0
# 638                   0                  0  ...        0           0
# 248                   0                  0  ...        0           1
# 24                    1                  0  ...        0           1
#
#      BMI_High  DiabetesPedigreeFunction_Low  DiabetesPedigreeFunction_Medium  \
# 419         0                             1                                0
# 186         0                             0                                1
# 556         0                             1                                0
# 738         0                             0                                1
# 320         0                             0                                1
# ..        ...                           ...                              ...
# 626         0                             1                                0
# 487         1                             0                                0
# 638         1                             0                                0
# 248         0                             1                                0
# 24          0                             1                                0
#
#      DiabetesPedigreeFunction_High  Age_Low  Age_Medium  Age_High  target
# 419                              0        1           0         0       1
# 186                              0        0           0         1       1
# 556                              0        1           0         0      -1
# 738                              0        1           0         0      -1
# 320                              0        1           0         0      -1
# ..                             ...      ...         ...       ...     ...
# 626                              0        1           0         0      -1
# 487                              1        0           0         1      -1
# 638                              1        1           0         0       1
# 248                              0        1           0         0      -1
# 24                               0        0           1         0       1
#
# [134 rows x 22 columns]

# %% [markdown]
# # モデルの訓練

# %%
data_dir_path = os.path.join(project_dir_path, 'inputs/pima_indian_diabetes')
file_list = os.listdir(os.path.join(data_dir_path, 'train'))

L_files = [filename for filename in file_list 
           if filename.startswith('L') and filename.endswith('.csv')]

U_files = [filename for filename in file_list 
           if filename.startswith('U') and filename.endswith('.csv')]

file_names_dict = {
    'supervised': L_files,
    'unsupervised': U_files,
    'rule': ['rules.txt']
}

constraints_flag_dict = {
    'pointwise': False,
    'logical': False,
    'consistency': True
}

problem_instance = Setup(data_dir_path, file_names_dict, 
                         specimen_construct_objective_function_loss_v3)
objective, constraints = problem_instance.main(c1=10, c2=10, 
                                               constraints_flag_dict=constraints_flag_dict)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)
# Out:
# load_data took 0.03740215301513672 seconds!
# load_rules took 0.0002570152282714844 seconds!
# specimen_construct_objective_function_loss_v3 took 0.17067384719848633 seconds!
# consistency constraints
# __call__ took 1.5344328880310059 seconds!
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# /Users/keisukeonoue/ws/lukasiewicz_1/myenv/lib/python3.11/site-packages/cvxpy/problems/problem.py:157: UserWarning: Objective contains too many subexpressions. Consider vectorizing your CVXPY code to speed up compilation.
#   warnings.warn("Objective contains too many subexpressions. "
# (CVXPY) Jan 04 03:27:36 PM: Your problem has 484 variables, 24244 constraints, and 0 parameters.
# (CVXPY) Jan 04 03:27:36 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 04 03:27:36 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 04 03:27:36 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 04 03:27:37 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Jan 04 03:27:37 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Jan 04 03:27:37 PM: Applying reduction Dcp2Cone
# (CVXPY) Jan 04 03:27:40 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 04 03:27:40 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jan 04 03:27:56 PM: Applying reduction ECOS
# (CVXPY) Jan 04 03:27:59 PM: Finished problem compilation (took 2.288e+01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 04 03:27:59 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +0.000e+00  -2.682e+04  +1e+05  6e-01  1e+00  1e+00  1e+00    ---    ---    0  0  - |  -  -
#  1  -6.044e+04  -8.361e+04  +3e+04  5e-01  8e-01  3e+00  3e-01  0.7433  3e-02   2  2  2 |  0  0
#  2  -1.010e+05  -1.184e+05  +1e+04  4e-01  6e-01  3e+00  1e-01  0.9791  4e-01   2  2  2 |  0  0
#  3  -8.991e+04  -1.006e+05  +5e+03  2e-01  4e-01  2e+00  5e-02  0.6431  2e-01   2  2  2 |  0  1
#  4  -5.317e+04  -5.984e+04  +2e+03  2e-01  2e-01  2e+00  3e-02  0.6227  3e-01   2  2  2 |  3  2
#  5  -3.312e+04  -3.835e+04  +2e+03  1e-01  2e-01  1e+00  2e-02  0.9791  8e-01   2  2  2 |  8  0
#  6  -2.594e+04  -2.993e+04  +1e+03  9e-02  1e-01  9e-01  1e-02  0.5013  5e-01   2  2  2 |  5  3
#  7  -2.171e+04  -2.499e+04  +1e+03  8e-02  1e-01  8e-01  1e-02  0.9791  8e-01   2  2  2 | 10  0
#  8  -1.662e+04  -1.916e+04  +8e+02  6e-02  9e-02  6e-01  8e-03  0.6266  6e-01   2  2  2 |  7  2
#  9  -1.635e+04  -1.884e+04  +7e+02  6e-02  9e-02  6e-01  8e-03  0.9791  1e+00   2  2  2 | 19  0
# 10  -1.165e+04  -1.350e+04  +5e+02  4e-02  6e-02  5e-01  6e-03  0.5013  5e-01   2  2  2 |  5  3
# 11  -1.082e+04  -1.255e+04  +5e+02  4e-02  6e-02  4e-01  5e-03  0.9791  9e-01   2  2  2 | 15  0
# 12  -7.304e+03  -8.575e+03  +4e+02  3e-02  4e-02  3e-01  4e-03  0.5013  4e-01   2  2  2 |  5  3
# 13  -7.038e+03  -8.268e+03  +3e+02  3e-02  4e-02  3e-01  3e-03  0.9791  1e+00   2  2  2 | 18  0
# 14  -4.003e+03  -4.842e+03  +2e+02  2e-02  3e-02  2e-01  2e-03  0.5013  3e-01   2  2  3 |  4  3
# 15  -2.706e+03  -3.377e+03  +2e+02  2e-02  2e-02  2e-01  2e-03  0.9791  8e-01   2  2  2 | 10  0
# 16  -1.195e+03  -1.676e+03  +1e+02  1e-02  2e-02  1e-01  1e-03  0.5013  4e-01   2  3  3 |  5  3
# 17  -1.976e+02  -5.509e+02  +9e+01  8e-03  1e-02  1e-01  9e-04  0.9791  7e-01   2  3  2 |  9  0
# 18  +1.030e+03  +8.308e+02  +5e+01  5e-03  7e-03  6e-02  5e-04  0.5696  2e-01   2  3  3 |  3  2
# 19  +1.571e+03  +1.441e+03  +3e+01  3e-03  5e-03  4e-02  3e-04  0.9791  6e-01   2  3  2 |  6  0
# 20  +2.052e+03  +1.982e+03  +2e+01  2e-03  2e-03  2e-02  2e-04  0.5583  2e-01   2  2  2 |  2  2
# 21  +2.279e+03  +2.238e+03  +1e+01  9e-04  1e-03  1e-02  1e-04  0.9791  6e-01   2  2  2 |  6  0
# 22  +2.469e+03  +2.451e+03  +4e+00  4e-04  6e-04  5e-03  4e-05  0.6413  8e-02   2  2  2 |  1  1
# 23  +2.501e+03  +2.489e+03  +3e+00  3e-04  4e-04  4e-03  3e-05  0.9791  7e-01   2  2  2 |  8  0
# 24  +2.580e+03  +2.577e+03  +6e-01  5e-05  9e-05  8e-04  6e-06  0.8201  2e-02   2  2  2 |  0  0
# 25  +2.591e+03  +2.590e+03  +2e-01  2e-05  3e-05  3e-04  2e-06  0.7833  2e-01   2  2  2 |  0  1
# 26  +2.597e+03  +2.596e+03  +5e-02  4e-06  8e-06  7e-05  5e-07  0.8436  8e-02   2  1  2 |  0  0
# 27  +2.598e+03  +2.598e+03  +2e-02  1e-06  3e-06  2e-05  2e-07  0.8705  2e-01   2  1  1 |  0  0
# 28  +2.598e+03  +2.598e+03  +6e-03  5e-07  1e-06  8e-06  6e-08  0.7907  2e-01   1  2  2 |  0  0
# 29  +2.598e+03  +2.598e+03  +2e-03  2e-07  3e-07  3e-06  2e-08  0.7829  1e-01   2  2  2 |  0  1
# 30  +2.598e+03  +2.598e+03  +6e-04  5e-08  9e-08  8e-07  6e-09  0.7541  4e-02   2  1  1 |  1  1
# 31  +2.598e+03  +2.598e+03  +2e-04  1e-08  3e-08  2e-07  2e-09  0.7443  3e-02   1  1  1 |  1  1
# 32  +2.598e+03  +2.598e+03  +4e-05  4e-09  7e-09  6e-08  4e-10  0.7409  4e-02   1  1  1 |  1  1
# 33  +2.598e+03  +2.598e+03  +1e-05  1e-09  2e-09  2e-08  1e-10  0.7358  4e-02   2  1  2 |  1  1
#
# OPTIMAL (within feastol=2.1e-09, reltol=4.9e-09, abstol=1.3e-05).
# Runtime: 2.086248 seconds.
#
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 04 03:28:01 PM: Problem status: optimal
# (CVXPY) Jan 04 03:28:01 PM: Optimal value: nan
# (CVXPY) Jan 04 03:28:01 PM: Compilation took 2.288e+01 seconds
# (CVXPY) Jan 04 03:28:01 PM: Solver (including time spent in interface) took 2.089e+00 seconds
# /Users/keisukeonoue/ws/lukasiewicz_1/myenv/lib/python3.11/site-packages/cvxpy/atoms/elementwise/log.py:35: RuntimeWarning: invalid value encountered in log
#   return np.log(values[0])

# %% [markdown]
# # モデルの評価

# %%
from src.evaluation import EvaluateModel

evaluate_model = EvaluateModel(problem_instance)
evaluate_model.evaluate('./result.json')
# Out:
#      0
# 419 -1
# 186  1
# 556 -1
# 738 -1
# 320 -1
# ..  ..
# 626 -1
# 487  1
# 638 -1
# 248 -1
# 24  -1
#
# [134 rows x 1 columns]
# outcome: 1
# condition: Glucose_Low == 0 & Age_Low == 0 & BMI_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & DiabetesPedigreeFunction_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Pregnancies_High == 0 & Age_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & BMI_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: DiabetesPedigreeFunction_High == 0 & Glucose_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & Age_Medium == 0 & SkinThickness_Low == 0 & Glucose_Low == 0 & DiabetesPedigreeFunction_Medium == 0 & BloodPressure_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & Age_Low == 0 & Pregnancies_Medium == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Age_Medium == 0 & BMI_Low == 1 & BloodPressure_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: BMI_Low == 0 & Glucose_Low == 0 & DiabetesPedigreeFunction_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_Low == 0 & Pregnancies_High == 0 & DiabetesPedigreeFunction_High == 0 & BMI_High == 0 & Age_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: DiabetesPedigreeFunction_Low == 0 & BMI_Medium == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & BloodPressure_Medium == 1 & Age_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: Age_Low == 0 & BloodPressure_Low == 0 & SkinThickness_Medium == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & Pregnancies_High == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & SkinThickness_High == 0 & Age_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: BMI_Low == 0 & Glucose_High == 1 & BloodPressure_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Age_Medium == 0 & DiabetesPedigreeFunction_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: Age_Low == 0 & Glucose_Low == 0 & BloodPressure_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: BMI_Low == 0 & Pregnancies_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: BMI_Medium == 0 & Glucose_Low == 0 & SkinThickness_Medium == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & BMI_High == 0 & BMI_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: Pregnancies_Medium == 0 & DiabetesPedigreeFunction_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: BMI_Low == 0 & DiabetesPedigreeFunction_Low == 1 & Glucose_Low == 0 & BMI_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: BMI_Low == 1 & Pregnancies_Low == 1 & Age_High == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & BMI_Medium == 0 & BMI_High == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & Pregnancies_High == 0 & BloodPressure_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: BMI_Low == 0 & Glucose_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: BMI_Medium == 1 & DiabetesPedigreeFunction_Low == 1 & SkinThickness_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Age_Low == 1 & SkinThickness_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: Glucose_Low == 0 & Glucose_High == 0 & BMI_Low == 0 & Pregnancies_Low == 1 & SkinThickness_Medium == 0 & SkinThickness_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: BloodPressure_High == 0 & BMI_Medium == 0 & Glucose_High == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & BMI_High == 0 & BloodPressure_Medium == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: BloodPressure_Low == 0 & DiabetesPedigreeFunction_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: BloodPressure_Low == 1 & SkinThickness_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: Glucose_High == 1 & BMI_Low == 0 & SkinThickness_High == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: BMI_Low == 0 & Pregnancies_High == 0 & SkinThickness_Medium == 1 & Glucose_High == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Age_Medium == 0 & BloodPressure_Low == 0 & BloodPressure_Medium == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: 1
# condition: BloodPressure_Low == 0 & DiabetesPedigreeFunction_Low == 0
# type of tmp: <class 'pandas.core.frame.DataFrame'>
# outcome: -1
# condition: Glucose_High == 0 & Pregnancies_Low == 1 & Age_Low == 1
# type of tmp: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # 表埋め 手順
#
# - 元データファイル： diabetes_cleaned.csv, diabetes_discretized.csv

# %%
file_path = os.path.join(data_dir_path, "test", "L_Outcome.csv")

test_data = pd.read_csv(file_path, index_col=0)
X_test = test_data.drop(['target'], axis=1)
y_test = test_data['target']

p = problem_instance.predicates_dict['Outcome']
y_pred = p(X_test).value
y_pred_interpreted = np.where(y_pred >= 0.5, 1, -1)

# %%
X_test
# Out:
#      Pregnancies_Low  Pregnancies_Medium  Pregnancies_High  Glucose_Low  \
# 419                1                   0                 0            0
# 186                0                   1                 0            0
# 556                1                   0                 0            0
# 738                1                   0                 0            0
# 320                1                   0                 0            0
# ..               ...                 ...               ...          ...
# 626                1                   0                 0            0
# 487                1                   0                 0            0
# 638                0                   1                 0            0
# 248                0                   0                 1            0
# 24                 0                   0                 1            0
#
#      Glucose_Medium  Glucose_High  BloodPressure_Low  BloodPressure_Medium  \
# 419               1             0                  0                     1
# 186               0             1                  0                     1
# 556               1             0                  0                     1
# 738               1             0                  1                     0
# 320               1             0                  1                     0
# ..              ...           ...                ...                   ...
# 626               1             0                  0                     1
# 487               0             1                  0                     1
# 638               1             0                  0                     1
# 248               1             0                  0                     1
# 24                1             0                  0                     0
#
#      BloodPressure_High  SkinThickness_Low  ...  SkinThickness_High  BMI_Low  \
# 419                   0                  0  ...                   0        1
# 186                   0                  0  ...                   0        0
# 556                   0                  0  ...                   0        0
# 738                   0                  1  ...                   0        0
# 320                   0                  1  ...                   0        1
# ..                  ...                ...  ...                 ...      ...
# 626                   0                  1  ...                   0        1
# 487                   0                  0  ...                   0        0
# 638                   0                  0  ...                   0        0
# 248                   0                  0  ...                   0        0
# 24                    1                  0  ...                   0        0
#
#      BMI_Medium  BMI_High  DiabetesPedigreeFunction_Low  \
# 419           0         0                             1
# 186           1         0                             0
# 556           1         0                             1
# 738           1         0                             0
# 320           0         0                             0
# ..          ...       ...                           ...
# 626           0         0                             1
# 487           0         1                             0
# 638           0         1                             0
# 248           1         0                             1
# 24            1         0                             1
#
#      DiabetesPedigreeFunction_Medium  DiabetesPedigreeFunction_High  Age_Low  \
# 419                                0                              0        1
# 186                                1                              0        0
# 556                                0                              0        1
# 738                                1                              0        1
# 320                                1                              0        1
# ..                               ...                            ...      ...
# 626                                0                              0        1
# 487                                0                              1        0
# 638                                0                              1        1
# 248                                0                              0        1
# 24                                 0                              0        0
#
#      Age_Medium  Age_High
# 419           0         0
# 186           0         1
# 556           0         0
# 738           0         0
# 320           0         0
# ..          ...       ...
# 626           0         0
# 487           0         1
# 638           0         0
# 248           0         0
# 24            1         0
#
# [134 rows x 21 columns]

# %% [markdown]
# ## ルール違反 カウント
#
# - 「→ Outcome」or「→ ¬ Outcome」が残るようにしたい
#
# - 例えば「¬ Glucose_Low ⊗ ¬ Age_Low ⊗ ¬ BMI_Low → Outcome」ならば，「Glucose_Low == 0, Age_Low == 0, BMI_Low == 0」の X_test の要素について，Outcome(x_test) == 0 ならばルール違反となる
#
# 1. KB_origin から「,'→', 'Outcome']」または「,'→', '¬', 'Outcome']」となっている rule のみ抜き出して，is_symbol(item) == False となる item に対して，直前の要素が '¬' でないならば item == 1 とし，下のような辞書を作成．
#
# {
#     item1: 1,
#     item2: 0,
#     item3: 1，
#     Outcome: 1 （or -1）
# }
#
# 2. 辞書が示す条件を満たすの X_test の要素に対して，対応する y_interpreted を調べ，

# %%
from src.misc import is_symbol

# %%
rules_tmp = []

for rule in problem_instance.KB_origin:
    if "Outcome" in rule:
        tmp = {}
        for idx, item in enumerate(rule):
            if not is_symbol(item):
                if idx == 0 or rule[idx - 1] != '¬':
                    tmp[item] = 1
                elif item != "Outcome":
                    tmp[item] = 0
                else:
                    tmp[item] = -1

        rules_tmp.append(tmp)

idx_tmp = X_test.index
y_pred_interpreted = pd.DataFrame(y_pred_interpreted, index=idx_tmp)

for rule in rules_tmp:
    outcome = rule["Outcome"]
    condition = " & ".join([f"{column} == {value}" for column, value in rule.items() if column != "Outcome"])
    tmp = y_pred_interpreted.loc[X_test.query(condition).index]
    print((tmp == outcome).sum())
    print(tmp.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 18
#      15         rules_tmp.append(tmp)
#      17 idx_tmp = X_test.index
# ---> 18 y_pred_interpreted = pd.DataFrame(y_pred_interpreted, index=idx_tmp)
#      20 for rule in rules_tmp:
#      21     outcome = rule["Outcome"]
#
# NameError: name 'y_pred_interpreted' is not defined
