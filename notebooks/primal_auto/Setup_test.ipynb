# %%
# %load_ext autoreload
# %autoreload 2

import os 
import sys

project_dir_path = '/home/onoue/ws/lukasiewicz_1'
sys.path.append(project_dir_path)

sys.path
# Out:
# ['/home/onoue/ws/lukasiewicz_1/notebooks/primal_auto',
#  '/usr/lib/python311.zip',
#  '/usr/lib/python3.11',
#  '/usr/lib/python3.11/lib-dynload',
#  '',
#  '/home/onoue/ws/lukasiewicz_1/myenv/lib/python3.11/site-packages',
#  '/home/onoue/ws/lukasiewicz_1']

# %%
from src.setup_problem import Setup
from src.misc import visualize_result

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp

from src.misc import *


# %matplotlib inline

# %%
file_names_dict = {
    "supervised": ["L_p1(x)", "L_p2(x)", "L_p3(x)"],
    "unsupervised": ["U"],
    "rule": ["rules"]
}

data_dir_path = './../../inputs/toy_data'

# %%
problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)
# Out:
# Loading data ...
# Done in 0.011373043060302734 seconds!
#
# Loading rules ...
# Done in 0.0001475811004638672 seconds!
#
# Identifying predicates ...
# Done in 0.0005521774291992188 seconds!
#
# Constructing objective function ...
# Done in 0.0037949085235595703 seconds!
#
# Constructing constraints ...
# Done in 0.03846311569213867 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 29 02:36:34 PM: Your problem has 25 variables, 96 constraints, and 0 parameters.
# (CVXPY) Oct 29 02:36:34 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 29 02:36:34 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 29 02:36:34 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 29 02:36:34 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Oct 29 02:36:34 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Oct 29 02:36:34 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 29 02:36:34 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 29 02:36:34 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 29 02:36:34 PM: Applying reduction ECOS
# (CVXPY) Oct 29 02:36:34 PM: Finished problem compilation (took 1.957e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 29 02:36:34 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +2.866e+01  -5.148e+01  +7e+02  5e-01  6e-01  1e+00  6e+00    ---    ---    1  1  - |  -  -
#  1  +1.366e+01  -8.429e+00  +3e+02  1e-01  2e-01  9e-01  2e+00  0.6412  1e-01   1  1  1 |  0  0
#  2  +1.478e+01  -5.326e+00  +3e+02  1e-01  2e-01  1e+00  2e+00  0.2833  7e-01   2  2  2 |  0  0
#  3  +1.418e+01  +6.034e+00  +1e+02  5e-02  6e-02  6e-01  1e+00  0.9890  4e-01   2  2  1 |  0  0
#  4  +1.880e+01  +1.694e+01  +3e+01  1e-02  1e-02  1e-01  2e-01  0.8637  1e-01   2  2  2 |  0  0
#  5  +2.007e+01  +1.980e+01  +4e+00  1e-03  2e-03  2e-02  4e-02  0.9172  7e-02   2  1  2 |  0  0
#  6  +2.032e+01  +2.029e+01  +6e-01  2e-04  2e-04  2e-03  5e-03  0.8804  2e-02   2  1  1 |  0  0
#  7  +2.036e+01  +2.036e+01  +1e-02  4e-06  5e-06  4e-05  1e-04  0.9799  3e-04   2  1  1 |  0  0
#  8  +2.036e+01  +2.036e+01  +4e-04  1e-07  2e-07  1e-06  3e-06  0.9686  1e-04   2  1  1 |  0  0
#  9  +2.036e+01  +2.036e+01  +1e-05  5e-09  6e-09  5e-08  1e-07  0.9625  9e-04   1  1  1 |  0  0
# 10  +2.036e+01  +2.036e+01  +3e-07  9e-11  1e-10  9e-10  2e-09  0.9827  2e-04   2  1  1 |  0  0
# 11  +2.036e+01  +2.036e+01  +5e-09  3e-12  2e-12  2e-11  4e-11  0.9818  1e-04   2  1  1 |  0  0
#
# OPTIMAL (within feastol=2.6e-12, reltol=2.3e-10, abstol=4.7e-09).-------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 29 02:36:34 PM: Problem status: optimal
#
# Runtime: 0.000868 seconds.
#
# (CVXPY) Oct 29 02:36:34 PM: Optimal value: 2.036e+01
# (CVXPY) Oct 29 02:36:34 PM: Compilation took 1.957e-01 seconds
# (CVXPY) Oct 29 02:36:34 PM: Solver (including time spent in interface) took 9.980e-04 seconds

# %%
visualize_result(problem_instance)

# %%
cnt = 0
cnt_violation = 0

for data in problem_instance.S:
    for x in data:
        val = problem_instance.predicates_dict['p_1(x)'](x).value

        if val < 0:
            cnt_violation += 1
        print(val)

        cnt += 1

print(f'\n violations: {cnt_violation} out of {cnt}')
# Out:
# 1.8977408533515927e-10
# 0.02202231900646834
# 0.496573718191177
# 0.672043493676458
# 1.8977408533515927e-10
# 0.3651485803392841
# 0.07317147122933065
# 0.0951937900460248
# 0.014917804416994529
# 0.46034237019553503
# -0.26285027551401136
# 0.12432062345219297
# 0.4454245659683146
# 0.43832005137884067
# 1.8977408533515927e-10
# 0.3651485803392841
# 0.07317147122933065
# 0.0951937900460248
# 0.014917804416994529
# 0.46034237019553503
# -0.2408279566973171
# 0.14634294226888722
# 0.1825742902645291
# 0.46744688478500873
# 1.8977408533515927e-10
# 0.3651485803392841
# 0.07317147122933065
# 0.0951937900460248
# 0.014917804416994529
# 0.46034237019553503
#
#  violations: 2 out of 30

# %%
visualize_result(problem_instance)

# %%
cnt = 0
cnt_violation = 0

for data in problem_instance.S:
    for x in data:
        val = problem_instance.predicates_dict['p_1(x)'](x).value

        if val < 0:
            cnt_violation += 1
        print(val)

        cnt += 1

print(f'\n violations: {cnt_violation} out of {cnt}')
# Out:
# 4.721489865744388e-11
# 0.022021154962016842
# 0.49657378051884904
# 0.6720414568562072
# 4.721489865744388e-11
# 0.36514841401109455
# 0.07316999543620217
# 0.09519115035100412
# 0.014914624317435066
# 0.46033956431488376
# -0.262850732968294
# 0.12431883591038773
# 0.4454249400446637
# 0.4383184094000818
# 4.721489865744388e-11
# 0.36514841401109455
# 0.07316999543620217
# 0.09519115035100412
# 0.014914624317435066
# 0.46033956431488376
# -0.24082957805349203
# 0.14633999082518945
# 0.18257420702915472
# 0.46744609495946543
# 4.721489865744388e-11
# 0.36514841401109455
# 0.07316999543620217
# 0.09519115035100412
# 0.014914624317435066
# 0.46033956431488376
#
#  violations: 2 out of 30

# %%
visualize_result(problem_instance)

# %%
cnt = 0
cnt_violation = 0

for data in problem_instance.S:
    for x in data:
        val = problem_instance.predicates_dict['p_1(x)'](x).value

        if val < 0:
            cnt_violation += 1
        print(val)

        cnt += 1

print(f'\n violations: {cnt_violation} out of {cnt}')
# Out:
# 2.2750690220618708e-12
# 0.025000000000762856
# 0.7499999999990261
# 0.9999999999953904
# 2.2750690220618708e-12
# 0.5499999999996372
# 0.10000000000005493
# 0.1249999999985425
# -1.5543122344752192e-12
# 0.6749999999959044
# -0.3999999999965026
# 0.174999999999347
# 0.674999999999734
# 0.6499999999974171
# 2.2750690220618708e-12
# 0.5499999999996372
# 0.10000000000005493
# 0.1249999999985425
# -1.5543122344752192e-12
# 0.6749999999959044
# -0.37499999999801503
# 0.19999999999783458
# 0.27500000000095626
# 0.6999999999982216
# 2.2750690220618708e-12
# 0.5499999999996372
# 0.10000000000005493
# 0.1249999999985425
# -1.5543122344752192e-12
# 0.6749999999959044
#
#  violations: 5 out of 30

# %%
tmp = [cp.Variable(), '→', 2]
tmp.count(2)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /home/onoue/ws/lukasiewicz_1/notebooks/primal_auto/Setup_test.ipynb セル 15 line 2
#       <a href='vscode-notebook-cell:/home/onoue/ws/lukasiewicz_1/notebooks/primal_auto/Setup_test.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> tmp = [cp.Variable(), '→', 2]
# ----> <a href='vscode-notebook-cell:/home/onoue/ws/lukasiewicz_1/notebooks/primal_auto/Setup_test.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> tmp.count(2)
#
# File ~/ws/lukasiewicz_1/myenv/lib/python3.11/site-packages/cvxpy/constraints/constraint.py:233, in Constraint.__bool__(self)
#     225 def __bool__(self):
#     226     """Raises an exception when called.
#     227
#     228     Python 3 version.
#    (...)
#     231     Raising an error here prevents writing chained constraints.
#     232     """
# --> 233     return self._chain_constraints()
#
# File ~/ws/lukasiewicz_1/myenv/lib/python3.11/site-packages/cvxpy/constraints/constraint.py:220, in Constraint._chain_constraints(self)
#     217 def _chain_constraints(self):
#     218     """Raises an error due to chained constraints.
#     219     """
# --> 220     raise Exception(
#     221         ("Cannot evaluate the truth value of a constraint or "
#     222          "chain constraints, e.g., 1 >= x >= 0.")
#     223     )
#
# Exception: Cannot evaluate the truth value of a constraint or chain constraints, e.g., 1 >= x >= 0.

# %%
# Out:
# 1
