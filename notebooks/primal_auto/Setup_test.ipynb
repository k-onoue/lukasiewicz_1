# %%
# %load_ext autoreload
# %autoreload 2

import os

from .setup_problem import Setup
from misc import visualize_result

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp

from utils.misc import *


# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /home/onoue/ws/lukasiewicz_1/src/experiments/primal_auto/Setup_test.ipynb セル 1 line 6
#       <a href='vscode-notebook-cell:/home/onoue/ws/lukasiewicz_1/src/experiments/primal_auto/Setup_test.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> get_ipython().run_line_magic('autoreload', '2')
#       <a href='vscode-notebook-cell:/home/onoue/ws/lukasiewicz_1/src/experiments/primal_auto/Setup_test.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> import os
# ----> <a href='vscode-notebook-cell:/home/onoue/ws/lukasiewicz_1/src/experiments/primal_auto/Setup_test.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> from .setup_problem import Setup
#       <a href='vscode-notebook-cell:/home/onoue/ws/lukasiewicz_1/src/experiments/primal_auto/Setup_test.ipynb#X20sZmlsZQ%3D%3D?line=6'>7</a> from misc import visualize_result
#       <a href='vscode-notebook-cell:/home/onoue/ws/lukasiewicz_1/src/experiments/primal_auto/Setup_test.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> import pandas as pd
#
# ImportError: attempted relative import with no known parent package

# %%
# %load_ext autoreload
# %autoreload 2

import os

from utils.setup_problem import Setup
from utils.misc import visualize_result

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp

from utils.misc import *


# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file_names_dict = {
    'supervised': ['L1', 'L2', 'L3'],
    'unsupervised': ['U'],
    'rule': ['rules']
}

data_dir_path = './inputs/toy_data'

# %%
problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=2.5, c2=100)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)
# Out:
# Loading data ...
# Done in 0.004592418670654297 seconds!
#
# Loading rules ...
# Done in 9.226799011230469e-05 seconds!
#
# Identifying predicates ...
# Done in 0.00022125244140625 seconds!
#
# Constructing objective function ...
# Done in 0.0017344951629638672 seconds!
#
# Constructing constraints ...
# Done in 0.12037134170532227 seconds!
#
# All done
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 28 02:04:32 PM: Your problem has 25 variables, 96 constraints, and 0 parameters.
# (CVXPY) Oct 28 02:04:32 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 28 02:04:32 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 28 02:04:32 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 28 02:04:32 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Oct 28 02:04:32 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Oct 28 02:04:32 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 28 02:04:32 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 28 02:04:32 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 28 02:04:32 PM: Applying reduction ECOS
# (CVXPY) Oct 28 02:04:32 PM: Finished problem compilation (took 2.158e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 28 02:04:32 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +6.337e+00  -1.788e+02  +2e+03  5e-01  3e-01  1e+00  1e+01    ---    ---    1  1  - |  -  -
#  1  -4.860e+01  -9.370e+01  +6e+02  1e-01  8e-02  7e-01  5e+00  0.6859  5e-02   1  1  1 |  0  0
#  2  +5.987e+00  -1.260e+01  +3e+02  6e-02  2e-02  9e-01  3e+00  0.7985  4e-01   1  1  2 |  0  0
#  3  +8.326e+00  +3.640e+00  +9e+01  1e-02  6e-03  2e-01  7e-01  0.7419  3e-02   1  2  2 |  0  0
#  4  +5.905e+00  +3.421e+00  +5e+01  7e-03  3e-03  1e-01  4e-01  0.9890  5e-01   1  2  1 |  0  0
#  5  +8.911e+00  +8.469e+00  +8e+00  1e-03  5e-04  2e-02  7e-02  0.8793  7e-02   1  2  2 |  0  0
#  6  +9.335e+00  +9.181e+00  +3e+00  4e-04  2e-04  6e-03  2e-02  0.9890  3e-01   1  1  1 |  0  0
#  7  +9.537e+00  +9.513e+00  +4e-01  6e-05  3e-05  1e-03  4e-03  0.8738  3e-02   1  1  1 |  0  0
#  8  +9.564e+00  +9.558e+00  +1e-01  1e-05  7e-06  2e-04  9e-04  0.8639  1e-01   1  1  1 |  0  0
#  9  +9.569e+00  +9.567e+00  +5e-02  6e-06  3e-06  1e-04  4e-04  0.7557  2e-01   1  1  1 |  0  0
# 10  +9.573e+00  +9.572e+00  +5e-03  7e-07  3e-07  1e-05  4e-05  0.9036  2e-02   1  1  1 |  0  0
# 11  +9.573e+00  +9.573e+00  +4e-04  6e-08  3e-08  1e-06  4e-06  0.9890  8e-02   1  1  1 |  0  0
# 12  +9.573e+00  +9.573e+00  +2e-05  2e-09  1e-09  4e-08  2e-07  0.9598  3e-04   1  1  1 |  0  0
# 13  +9.573e+00  +9.573e+00  +2e-06  3e-10  1e-10  4e-09  2e-08  0.8988  4e-04   1  1  1 |  0  0
# 14  +9.573e+00  +9.573e+00  +2e-07  3e-11  1e-11  5e-10  2e-09  0.9890  1e-01   2  1  1 |  0  0
# 15  +9.573e+00  +9.573e+00  +2e-08  3e-11  1e-12  4e-11  2e-10  0.9093  3e-03   2  1  1 |  0  0
#
# OPTIMAL (within feastol=2.6e-11, reltol=2.1e-09, abstol=2.0e-08).-------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 28 02:04:32 PM: Problem status: optimal
#
# Runtime: 0.000885 seconds.
#
# (CVXPY) Oct 28 02:04:32 PM: Optimal value: 9.573e+00
# (CVXPY) Oct 28 02:04:32 PM: Compilation took 2.158e-01 seconds
# (CVXPY) Oct 28 02:04:32 PM: Solver (including time spent in interface) took 1.240e-03 seconds

# %%
visualize_result(problem_instance)

# %%
cnt = 0
cnt_violation = 0

for data in problem_instance.S:
    for x in data:
        val = problem_instance.predicates_dict['p_1(x)'](x).value

        if val < 0:
            cnt_violation += 1
        print(val)

        cnt += 1

print(f'\n violations: {cnt_violation} out of {cnt}')
# Out:
# 1.8977408533515927e-10
# 0.02202231900646834
# 0.496573718191177
# 0.672043493676458
# 1.8977408533515927e-10
# 0.3651485803392841
# 0.07317147122933065
# 0.0951937900460248
# 0.014917804416994529
# 0.46034237019553503
# -0.26285027551401136
# 0.12432062345219297
# 0.4454245659683146
# 0.43832005137884067
# 1.8977408533515927e-10
# 0.3651485803392841
# 0.07317147122933065
# 0.0951937900460248
# 0.014917804416994529
# 0.46034237019553503
# -0.2408279566973171
# 0.14634294226888722
# 0.1825742902645291
# 0.46744688478500873
# 1.8977408533515927e-10
# 0.3651485803392841
# 0.07317147122933065
# 0.0951937900460248
# 0.014917804416994529
# 0.46034237019553503
#
#  violations: 2 out of 30

# %%
visualize_result(problem_instance)

# %%
cnt = 0
cnt_violation = 0

for data in problem_instance.S:
    for x in data:
        val = problem_instance.predicates_dict['p_1(x)'](x).value

        if val < 0:
            cnt_violation += 1
        print(val)

        cnt += 1

print(f'\n violations: {cnt_violation} out of {cnt}')
# Out:
# 4.721489865744388e-11
# 0.022021154962016842
# 0.49657378051884904
# 0.6720414568562072
# 4.721489865744388e-11
# 0.36514841401109455
# 0.07316999543620217
# 0.09519115035100412
# 0.014914624317435066
# 0.46033956431488376
# -0.262850732968294
# 0.12431883591038773
# 0.4454249400446637
# 0.4383184094000818
# 4.721489865744388e-11
# 0.36514841401109455
# 0.07316999543620217
# 0.09519115035100412
# 0.014914624317435066
# 0.46033956431488376
# -0.24082957805349203
# 0.14633999082518945
# 0.18257420702915472
# 0.46744609495946543
# 4.721489865744388e-11
# 0.36514841401109455
# 0.07316999543620217
# 0.09519115035100412
# 0.014914624317435066
# 0.46033956431488376
#
#  violations: 2 out of 30

# %%
visualize_result(problem_instance)

# %%
cnt = 0
cnt_violation = 0

for data in problem_instance.S:
    for x in data:
        val = problem_instance.predicates_dict['p_1(x)'](x).value

        if val < 0:
            cnt_violation += 1
        print(val)

        cnt += 1

print(f'\n violations: {cnt_violation} out of {cnt}')
# Out:
# 2.2750690220618708e-12
# 0.025000000000762856
# 0.7499999999990261
# 0.9999999999953904
# 2.2750690220618708e-12
# 0.5499999999996372
# 0.10000000000005493
# 0.1249999999985425
# -1.5543122344752192e-12
# 0.6749999999959044
# -0.3999999999965026
# 0.174999999999347
# 0.674999999999734
# 0.6499999999974171
# 2.2750690220618708e-12
# 0.5499999999996372
# 0.10000000000005493
# 0.1249999999985425
# -1.5543122344752192e-12
# 0.6749999999959044
# -0.37499999999801503
# 0.19999999999783458
# 0.27500000000095626
# 0.6999999999982216
# 2.2750690220618708e-12
# 0.5499999999996372
# 0.10000000000005493
# 0.1249999999985425
# -1.5543122344752192e-12
# 0.6749999999959044
#
#  violations: 5 out of 30
