# %%
# %load_ext autoreload
# %autoreload 2

import os

from utils.setup_problem import Setup
from utils.misc import visualize_result

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp

from utils.misc import *


# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file_names_dict = {
    'supervised': ['L1', 'L2', 'L3'],
    'unsupervised': ['U'],
    'rule': ['rules']
}

data_dir_path = './inputs/toy_data'

# %%
problem_instance = Setup(data_dir_path, file_names_dict)
problem_instance.load_data()
problem_instance.load_rules()
problem_instance.identify_predicates()

problem_instance._construct_logical_constraints()
# Out:
# before: ['¬', Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: ['¬', Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ()))]

# %%
problem_instance.KB
# Out:
# [['¬', 'p_1(x)', '⊕', 'p_2(x)'], ['¬', 'p_2(x)', '⊕', 'p_3(x)']]

# %%
problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 15 12:53:06 PM: Your problem has 23 variables, 96 constraints, and 0 parameters.
# (CVXPY) Oct 15 12:53:06 PM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 15 12:53:06 PM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 15 12:53:06 PM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 12:53:06 PM: Compiling problem (target solver=ECOS).
# (CVXPY) Oct 15 12:53:06 PM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Oct 15 12:53:06 PM: Applying reduction Dcp2Cone
# (CVXPY) Oct 15 12:53:06 PM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 15 12:53:06 PM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 15 12:53:06 PM: Applying reduction ECOS
# (CVXPY) Oct 15 12:53:06 PM: Finished problem compilation (took 2.170e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 12:53:06 PM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +2.871e+01  -4.881e+01  +6e+02  5e-01  8e-01  1e+00  5e+00    ---    ---    1  1  - |  -  -
#  1  +1.438e+01  -5.647e+00  +3e+02  1e-01  2e-01  9e-01  2e+00  0.6623  1e-01   1  1  1 |  0  0
#  2  +1.554e+01  -3.018e+00  +2e+02  1e-01  2e-01  9e-01  2e+00  0.2606  7e-01   2  2  2 |  0  0
#  3  +1.439e+01  +6.636e+00  +1e+02  5e-02  7e-02  5e-01  9e-01  0.9890  5e-01   2  1  1 |  0  0
#  4  +1.879e+01  +1.699e+01  +3e+01  1e-02  2e-02  1e-01  2e-01  0.8793  1e-01   2  2  2 |  0  0
#  5  +1.970e+01  +1.913e+01  +9e+00  3e-03  5e-03  3e-02  7e-02  0.8808  2e-01   2  2  2 |  0  0
#  6  +2.027e+01  +2.017e+01  +1e+00  5e-04  7e-04  5e-03  1e-02  0.8722  5e-02   2  1  1 |  0  0
#  7  +2.035e+01  +2.034e+01  +1e-01  5e-05  7e-05  4e-04  1e-03  0.9237  3e-02   2  1  1 |  0  0
#  8  +2.036e+01  +2.036e+01  +6e-03  2e-06  3e-06  2e-05  6e-05  0.9748  2e-02   2  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 12:53:06 PM: Problem status: optimal
#  9  +2.036e+01  +2.036e+01  +1e-04  4e-08  5e-08  3e-07  9e-07  0.9843  1e-04   2  1  1 |  0  0
# 10  +2.036e+01  +2.036e+01  +8e-06  3e-09  4e-09  2e-08  7e-08  0.9266  5e-03   2  1  1 |  0  0
# 11  +2.036e+01  +2.036e+01  +1e-07  5e-11  7e-11  4e-10  1e-09  0.9890  7e-03   2  1  1 |  0  0
#
# OPTIMAL (within feastol=7.2e-11, reltol=6.8e-09, abstol=1.4e-07).
# Runtime: 0.000824 seconds.
#
# (CVXPY) Oct 15 12:53:06 PM: Optimal value: 2.036e+01
# (CVXPY) Oct 15 12:53:06 PM: Compilation took 2.170e-01 seconds
# (CVXPY) Oct 15 12:53:06 PM: Solver (including time spent in interface) took 1.640e-03 seconds

# %%
visualize_result(problem_instance)

# %%
problem_instance._construct_logical_constraints()
# Out:
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# before: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# after: [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ())),
#  Inequality(Constant(CONSTANT, ZERO, ())),
#  Inequality(Expression(AFFINE, UNKNOWN, ()))]

# %%
problem_instance.KB_origin
# Out:
# [['p_1(x)', '→', 'p_2(x)'], ['p_2(x)', '→', 'p_3(x)']]

# %%
for formula in problem_instance.KB:
    for item in formula:
        print(item)

    print()
# Out:
# 1.0 + -var12472[0, 0:3][0] @ 0.1 + var12472[0, 0:3][1] @ 0.5 + var12472[0, 0:3][2]
# ⊕
# var12472[1, 0:3][0] @ 0.1 + var12472[1, 0:3][1] @ 0.5 + var12472[1, 0:3][2]
#
# 1.0 + -var12472[1, 0:3][0] @ 0.1 + var12472[1, 0:3][1] @ 0.5 + var12472[1, 0:3][2]
# ⊕
# var12472[2, 0:3][0] @ 0.1 + var12472[2, 0:3][1] @ 0.5 + var12472[2, 0:3][2]

# %%
problem_instance.KB
# Out:
# [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())],
#  [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]

# %%
problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=2.5, c2=2.5)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)
# Out:
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 15 11:43:46 AM: Your problem has 23 variables, 72 constraints, and 0 parameters.
# (CVXPY) Oct 15 11:43:46 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 15 11:43:46 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 15 11:43:46 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 11:43:46 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Oct 15 11:43:46 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Oct 15 11:43:46 AM: Applying reduction Dcp2Cone
# (CVXPY) Oct 15 11:43:46 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 15 11:43:46 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 15 11:43:46 AM: Applying reduction ECOS
# (CVXPY) Oct 15 11:43:46 AM: Finished problem compilation (took 1.656e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 11:43:46 AM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +7.173e+00  -3.467e+01  +3e+02  5e-01  4e-01  1e+00  3e+00    ---    ---    1  1  - |  -  -
#  1  +5.171e+00  -7.066e+00  +1e+02  1e-01  1e-01  1e+00  1e+00  0.5984  2e-01   1  1  1 |  0  0
#  2  +6.936e+00  +2.248e+00  +6e+01  5e-02  4e-02  5e-01  6e-01  0.7679  3e-01   2  2  2 |  0  0
#  3  +7.771e+00  +4.900e+00  +3e+01  3e-02  2e-02  3e-01  4e-01  0.6486  4e-01   2  2  2 |  0  0
#  4  +8.464e+00  +7.777e+00  +8e+00  7e-03  5e-03  4e-02  9e-02  0.9676  2e-01   2  1  1 |  0  0
#  5  +8.842e+00  +8.724e+00  +1e+00  1e-03  8e-04  6e-03  2e-02  0.8825  6e-02   2  1  1 |  0  0
#  6  +8.893e+00  +8.858e+00  +4e-01  4e-04  2e-04  1e-03  5e-03  0.8410  2e-01   2  2  2 |  0  0
#  7  +8.915e+00  +8.912e+00  +3e-02  2e-05  1e-05  8e-05  3e-04  0.9872  5e-02   2  1  1 |  0  0
#  8  +8.916e+00  +8.916e+00  +2e-03  1e-06  8e-07  5e-06  2e-05  0.9431  4e-04   3  1  1 |  0  0
#  9  +8.916e+00  +8.916e+00  +4e-04  3e-07  2e-07  1e-06  4e-06  0.7560  2e-02   2  1  1 |  0  0
# 10  +8.916e+00  +8.916e+00  +2e-04  1e-07  9e-08  5e-07  2e-06  0.7200  2e-01   2  1  1 |  0  0
# 11  +8.916e+00  +8.916e+00  +6e-06  5e-09  3e-09  2e-08  7e-08  0.9649  3e-03   2  1  1 |  0  0
# 12  +8.916e+00  +8.916e+00  +6e-07  5e-10  3e-10  2e-09  7e-09  0.9041  2e-03   2  2  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 11:43:46 AM: Problem status: optimal
# (CVXPY) Oct 15 11:43:46 AM: Optimal value: 8.916e+00
# 13  +8.916e+00  +8.916e+00  +8e-08  7e-11  4e-11  2e-10  8e-10  0.9890  1e-01   2  2  2 |  0  0
#
# OPTIMAL (within feastol=6.5e-11, reltol=8.7e-09, abstol=7.7e-08).
# Runtime: 0.000627 seconds.
#
# (CVXPY) Oct 15 11:43:46 AM: Compilation took 1.656e-01 seconds
# (CVXPY) Oct 15 11:43:46 AM: Solver (including time spent in interface) took 1.036e-03 seconds

# %%
visualize_result(problem_instance)

# %%
problem_instance = Setup(data_dir_path, file_names_dict)
objective, constraints = problem_instance.main(c1=10, c2=10)

problem = cp.Problem(objective, constraints)
result = problem.solve(verbose=True)
# Out:
# KB: [['¬', 'p_1(x)', '⊕', 'p_2(x)'], ['¬', 'p_2(x)', '⊕', 'p_3(x)']]
# ['¬', Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# ['¬', Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# KB: [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# KB: [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# KB: [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# KB: [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# KB: [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]
# [[Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())], [Expression(AFFINE, UNKNOWN, ()), '⊕', Expression(AFFINE, UNKNOWN, ())]]
# ===============================================================================
#                                      CVXPY
#                                      v1.3.2
# ===============================================================================
# (CVXPY) Oct 15 11:48:25 AM: Your problem has 23 variables, 84 constraints, and 0 parameters.
# (CVXPY) Oct 15 11:48:25 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Oct 15 11:48:25 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Oct 15 11:48:25 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 11:48:25 AM: Compiling problem (target solver=ECOS).
# (CVXPY) Oct 15 11:48:25 AM: Reduction chain: Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> ECOS
# (CVXPY) Oct 15 11:48:25 AM: Applying reduction Dcp2Cone
# (CVXPY) Oct 15 11:48:25 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Oct 15 11:48:25 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Oct 15 11:48:25 AM: Applying reduction ECOS
# (CVXPY) Oct 15 11:48:25 AM: Finished problem compilation (took 2.773e-01 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 11:48:25 AM: Invoking solver ECOS  to obtain a solution.
#
# ECOS 2.0.10 - (C) embotech GmbH, Zurich Switzerland, 2012-15. Web: www.embotech.com/ECOS
#
# It     pcost       dcost      gap   pres   dres    k/t    mu     step   sigma     IR    |   BT
#  0  +2.816e+01  -5.954e+01  +6e+02  5e-01  6e-01  1e+00  6e+00    ---    ---    1  1  - |  -  -
#  1  +9.449e+00  -1.257e+01  +3e+02  1e-01  1e-01  9e-01  2e+00  0.6765  1e-01   1  1  1 |  0  0
#  2  +1.149e+01  -7.078e+00  +2e+02  1e-01  1e-01  9e-01  2e+00  0.3942  6e-01   2  2  2 |  0  0
#  3  +1.377e+01  +7.483e+00  +8e+01  3e-02  4e-02  4e-01  8e-01  0.9890  4e-01   2  2  1 |  0  0
#  4  +1.724e+01  +1.451e+01  +4e+01  1e-02  2e-02  2e-01  3e-01  0.7874  3e-01   2  2  2 |  0  0
#  5  +1.908e+01  +1.865e+01  +6e+00  2e-03  2e-03  2e-02  5e-02  0.8824  5e-02   2  2  2 |  0  0
#  6  +1.925e+01  +1.905e+01  +3e+00  9e-04  1e-03  1e-02  3e-02  0.7125  3e-01   2  2  2 |  0  0
#  7  +1.941e+01  +1.938e+01  +4e-01  1e-04  1e-04  1e-03  3e-03  0.8845  2e-02   2  1  1 |  0  0
#  8  +1.944e+01  +1.944e+01  +2e-02  5e-06  6e-06  5e-05  1e-04  0.9814  3e-02   2  1  1 |  0  0
#  9  +1.944e+01  +1.944e+01  +5e-04  2e-07  2e-07  2e-06  5e-06  0.9720  3e-03   2  1  1 |  0  0
# 10  +1.944e+01  +1.944e+01  +1e-05  4e-09  5e-09  4e-08  1e-07  0.9749  1e-04   2  1  1 |  0  0
# 11  +1.944e+01  +1.944e+01  +6e-07  2e-10  2e-10  2e-09  5e-09  0.9562  2e-03   2  1  1 |  0  0
# 12  +1.944e+01  +1.944e+01  +9e-09  3e-12  4e-12  3e-11  9e-11  0.9841  3e-04   2  1  1 |  0  0
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Oct 15 11:48:25 AM: Problem status: optimal
#
# OPTIMAL (within feastol=3.6e-12, reltol=4.6e-10, abstol=9.0e-09).
# Runtime: 0.000834 seconds.
#
# (CVXPY) Oct 15 11:48:25 AM: Optimal value: 1.944e+01
# (CVXPY) Oct 15 11:48:25 AM: Compilation took 2.773e-01 seconds
# (CVXPY) Oct 15 11:48:25 AM: Solver (including time spent in interface) took 1.307e-03 seconds

# %%
visualize_result(problem_instance)
